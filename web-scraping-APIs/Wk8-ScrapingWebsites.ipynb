# %% [markdown]
# # In-Class Activity: Web Scraping with Beautiful Soup
#
# Today we will learn how to:
# * get HTML from a web page
# * parse that data using BeauitfulSoup
# * navigate through the soup
# * deal with some hairy complications
# * put it all together to build a brand new dataset
#
# A very big thank you to Brian Keegan (my advisor!) and the materials in his [Web Data Scraping course](https://github.com/CU-ITSS/Web-Data-Scraping-S2021). Check that out if you want to dig deeper ;)

# %%
# Import packages we've been using all semester long :)
import numpy as np
import pandas as pd

# %% [markdown]
# We'll be using two new packages today, [requests](https://pypi.org/project/requests/) and [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# Try running the two import lines below. They *should* have come bundled with your Anaconda installation. But if they don't work, you may need to first run:
#
#     pip install requests
#     pip install beautifulsoup4
#
# If you can't install the packages, I've created a [Google Collab](https://colab.research.google.com/drive/1JCbFis4D7ZhNpTd3qN-rpf-Ee-Ut5yA9?usp=sharing) of this example you can use to follow along.

# %%
# Requests lets us grab info from a web page
import requests

# BeautifulSoup parses and searches that info
from bs4 import BeautifulSoup

# %% [markdown]
# We'll start with the [Whitman Economics Faculty page](https://www.whitman.edu/academics/majors-and-minors/economics/faculty). Our task will be to get a list of all the faculty and all the information we have about them.
#
# Before we start, go ahead and open this page in your web browser.

# %% [markdown]
# ### Part 1: Getting the HTML and turning it into "Soup"

# %%
# Create a variable called URL
url = "https://www.whitman.edu/academics/majors-and-minors/economics/faculty"

# Use requests.get to grab the html
html = requests.get(url)

# Examine it -- what does it look like? What format is it?
print(html.text)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
#             <!-- Google Tag Manager -->
#             <script>
#                 (function (w, d, s, l, i) {
#                     w[l] = w[l] || []; w[l].push({
#                         'gtm.start':
#                             new Date().getTime(), event: 'gtm.js'
#                     }); var f = d.getElementsByTagName(s)[0],
#                         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                             'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#                 })(window, document, 'script', 'dataLayer', 'GTM-PN449F');</script>
#             <!-- End Google Tag Manager -->
#
#
#
#             <meta name="APIKey" content="SnazzyMap:AIzaSyA8pm3DLjUEic2ds_HPBH_VcDJwT84D6uY" />
#             <meta name="APIKey" content="GoogleMaps:AIzaSyBBuhapIg-2rzMPiPltgp9gGP4rOXSV0B4" />
#             <meta name="APIKey" content="GoogleDrive:AIzaSyANHcgxXdeKV4FZdwwgGx8SnP57eK4Tl-g" />
#     <meta name="SearchURL" content="https://www.whitman.edu/xsd/customsearch4/?q=" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Economics Department Faculty | Whitman College</title>
#     <meta name="robots" content="noodp,noydir" />
#     <link rel="canonical" href="https://www.whitman.edu/academics/majors-and-minors/economics/faculty" />
#     <meta name="description" property="og:description" content="" />
#     <meta name="Model.BaseURL" content="http://www.whitman.edu/" />
#
#     <!-- for facebook and twitter-->
#     <meta name="twitter:card" content="summary" />
#     <meta name="twitter:site" content="@whitmancollege" />
#     <meta name="twitter:creator" content="@whitmancollege" />
#     <meta name="twitter:title" property="og:title" content="Faculty" />
#     <meta name="twitter:description" content="" />
#     <meta name="twitter:image" property="og:image" content="https://www.whitman.edu/images/Global/Thumbnails/Summer-Memorial-Rainbow.jpg" />
#
#     <meta property="og:type" content="article" />
#     <meta property="og:url" content="https://www.whitman.edu/academics/majors-and-minors/economics/faculty" />
#     <meta property="og:site_name" content="Whitman College" />
#     <meta property="fb:admins" content="536191522" />
#
#     <!--for siteimprove-->
#     <meta name="PageID" content="x36447" />
#
#             <base href="https://www.whitman.edu" />
#
#
#     <!-- whitman styles -->
#     <link href="/prebuilt/v9/dist/css/wc-style.css?v=20210310_1" rel="stylesheet" />
#     <link href="/prebuilt/v9/dist/css/wc-style-2019.css?v=20210310_1" rel="stylesheet" />
#
#     <!-- Fonts -->
#     <link href="https://fonts.googleapis.com/css?family=Merriweather:400,400i,&amp;subset=latin-ext" rel="stylesheet">
#     <link href="https://fonts.googleapis.com/css?family=Raleway:300,300i,400,400i,500,500i,700,700i" rel="stylesheet">
#
#
#
#     <!-- jquery -->
#     <script src="/prebuilt/v9/dist/js/jquery.min.js"></script>
#
#
#
#
#     <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#     <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#     <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#     <link rel="manifest" href="/prebuilt/v9/site.webmanifest">
#
#     <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#5bbad5">
#     <meta name="msapplication-TileColor" content="#002868">
#     <meta name="theme-color" content="#ffffff">
#
#
#     <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
#     <!--[if lt IE 9]>
#         <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#         <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
#
# </head>
# <body>
#
#             <!-- Google Tag Manager (noscript) -->
#             <noscript>
#                 <iframe title="Google Tag Manager" src="https://www.googletagmanager.com/ns.html?id=GTM-PN449F"
#                         height="0" width="0" style="display:none;visibility:hidden"></iframe>
#             </noscript>
#             <!-- End Google Tag Manager (noscript) -->
#
#
# 		<a class="wc-skip-to-content-link" href="/academics/majors-and-minors/economics/faculty#wc-reader-content">Skip to main content</a>
#     <!-- Header -->
#     <header class="wc-header" id="wc-site-header">
#         <!-- Header Row 1 -->
#         <div class="wc-header-row1" id="wc-header-row1" role="navigation">
#             <div class="wc-container">
#                 <!-- Logo -->
#                 <a href="/" class="wc-header-logo-link" title="Whitman College home">
#                     <!-- Desktop Logo -->
#                     <img class="wc-desktop-header-logo" alt="Clocktower Logo" src="/prebuilt/v9/images/svg/whitman-logo-header.svg" onerror="this.src='/prebuilt/v9/images/misc/whitman-logo-header.png'" />
#
#                     <!-- Mobile Logo-->
#                     <svg class="wc-mobile-header-logo" viewBox="0 0 180 15">
# 						<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#logo-whitman-nc-flat"></use>
#                     </svg>
#                 </a>
#                 <div class="wc-right-box">
#                     <!-- Constituent Links -->
#                     <div class="wc-constituent-links">
#                                 <ul role="menubar">
# 											<li>
# 												    <a href="/admission-and-aid/applying-to-whitman"  class="wc-clickable"  title="Apply" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - Apply" >
#         Apply</a>
#
# <span class="wc-bullet" aria-hidden="true">&bull;</span>
# 											</li>
# 											<li>
# 												    <a href="/alumni"  class="wc-clickable"  title="Alumni" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - Alumni" >
#         Alumni</a>
#
# <span class="wc-bullet" aria-hidden="true">&bull;</span>
# 											</li>
# 											<li>
# 												    <a href="/campus-life/diversity-and-inclusion"  class="wc-clickable"  title="Diversity" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - Diversity" >
#         Diversity</a>
#
# <span class="wc-bullet" aria-hidden="true">&bull;</span>
# 											</li>
# 											<li>
# 												    <a href="https://library.whitman.edu/"  class="wc-clickable"  title="Library" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - Library" >
#         Library</a>
#
# <span class="wc-bullet" aria-hidden="true">&bull;</span>
# 											</li>
# 											<li>
# 												    <a href="https://my.whitman.edu/"  class="wc-clickable"  title="MyWhitman" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - MyWhitman" >
#         MyWhitman</a>
#
# <span class="wc-bullet" aria-hidden="true">&bull;</span>
# 											</li>
# 											<li>
# 												    <a href="/families"  class="wc-clickable"  title="Families" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - Families" >
#         Families</a>
#
#
# 											</li>
#
#                                 </ul>
#
#                     </div>
#
#     <a href="https://www.givecampus.com/campaigns/7878/donations/new" target="_blank" class="wc-special-button wc-box-button wc-white"  title="Make A Gift"
#          >
#         Make A Gift</a>
#
#
#                     <!-- Quick Links - Button -->
#                     <button class="wc-quick-links-button collapsed" data-toggle="collapse" data-target="#wc-quick-links-links" id="wc-quick-links-button" role="button" aria-haspopup="true" aria-label="Quick Links Menu">
#                             <svg class="wc-svg-box wc-spins" viewbox="0 0 32 32">
#                                 <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-circle-down"></use>
#                             </svg>
#                         <span class="wc-text" id="quicklinks">Quick Links</span>
#                     </button>
#
#                     <!-- Mobile Buttons -->
#                     <button class="wc-toggle wc-mobile-button wc-collapsed" id="wc-mobile-nav-button" aria-label="Menu" aria-expanded="false" >
#                         <svg class="wc-not-toggled-icon" viewbox="0 0 32 32"><use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-menu-mobile-a"></use></svg>
# 						<svg class="wc-toggled-icon" viewbox="0 0 32 32"><use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-menu-mobile-b"></use></svg>
#                     </button>
#                     <button class="wc-toggle wc-mobile-button wc-collapsed" id="wc-mobile-search-button" aria-label="Search" aria-expanded="false" >
#                         <svg class="wc-not-toggled-icon" viewbox="0 0 32 32"><use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-search-mobile-a"></use></svg>
#                         <svg class="wc-toggled-icon" viewbox="0 0 32 32"><use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-search-mobile-b"></use></svg>
#                     </button>
#
#                 </div>
#             </div>
#
#             <!-- Quick Links - Links -->
#             <div class="wc-quick-links-links wc-container collapse" id="wc-quick-links-links" role="navigation" aria-label="Quick Links">
#                 <div class="wc-quick-links-section">
#
#                     <ul class="wc-quick-link-columns-text" aria-labelledby="quicklinks" role="menu">
#                                         <li >    <a href="https://whitman-advocate.symplicity.com/public_report/index.php"    title="Bias Reporting" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Bias Reporting" >
#         Bias Reporting</a>
# </li>
#                                         <li >    <a href="http://bookstore.whitman.edu/home.aspx"    title="Bookstore" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Bookstore" >
#         Bookstore</a>
# </li>
#                                         <li >    <a href="/dean-of-students/care-team"    title="CARE Team" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - CARE Team" >
#         CARE Team</a>
# </li>
#                                         <li >    <a href="/after-whitman/career-and-community-engagement-center/job-and-career-resources"    title="Career Services" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Career Services" >
#         Career Services</a>
# </li>
#                                         <li >    <a href="/communications"    title="Communications" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Communications" >
#         Communications</a>
# </li>
#                                         <li >    <a href="/human-resources"    title="Employment Opportunities" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Employment Opportunities" >
#         Employment Opportunities</a>
# </li>
#                                         <li >    <a href="/giving"    title="Giving" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Giving" >
#         Giving</a>
# </li>
#                                         <li >    <a href="/human-resources/grievance-policy"    title="Grievance Policy" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Grievance Policy" >
#         Grievance Policy</a>
# </li>
#                                         <li >    <a href="/newsroom"    title="Newsroom" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Newsroom" >
#         Newsroom</a>
# </li>
#                                         <li >    <a href="/campus-life/diversity-and-inclusion/nondiscrimination-policy"    title="Nondiscrimination Policy" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Nondiscrimination Policy" >
#         Nondiscrimination Policy</a>
# </li>
#                                         <li >    <a href="/dean-of-students/right-to-know"    title="Right to Know" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Right to Know" >
#         Right to Know</a>
# </li>
#                                         <li >    <a href="/campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct"    title="Sexual Misconduct & Title IX" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Sexual Misconduct & Title IX" >
#         Sexual Misconduct & Title IX</a>
# </li>
#                                         <li >    <a href="/communications/social-media"    title="Social Media " data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Social Media " >
#         Social Media </a>
# </li>
#                                         <li >    <a href="/academics/the-center-for-writing-and-speaking"    title="The Center for Writing and Speaking (COWS)" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - The Center for Writing and Speaking (COWS)" >
#         The Center for Writing and Speaking (COWS)</a>
# </li>
#                                         <li >    <a href="/website-privacy-policy"    title="Website Privacy Policy" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Website Privacy Policy" >
#         Website Privacy Policy</a>
# </li>
#                                         <li >    <a href="/welty-student-health-center"    title="Welty Student Health Center" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Welty Student Health Center" >
#         Welty Student Health Center</a>
# </li>
#
#                     </ul>
#                 </div>
# 						<div class="wc-quick-links-section" role="menubar">
# 									<a class="wc-icon-quick-link" href="a-to-z-index"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - A to Z Index">
# 										<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 											<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-a-to-z"></use>
# 										</svg>
# 										<span class="wc-text">
# 											A to Z Index
#
# 										</span>
# 									</a>
# 									<a class="wc-icon-quick-link" href="campus-map"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Map">
# 										<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 											<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-map-pin"></use>
# 										</svg>
# 										<span class="wc-text">
# 											Map
#
# 										</span>
# 									</a>
# 									<a class="wc-icon-quick-link" href="http://calendar.whitman.edu"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Events Calendar">
# 										<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 											<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-calendar-no-circle"></use>
# 										</svg>
# 										<span class="wc-text">
# 											Events Calendar
#
# 										</span>
# 									</a>
# 									<a class="wc-icon-quick-link" href="https://library.whitman.edu/"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Penrose Library">
# 										<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 											<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-library"></use>
# 										</svg>
# 										<span class="wc-text">
# 											Penrose Library
#
# 										</span>
# 									</a>
# 									<a class="wc-icon-quick-link" href="https://my.whitman.edu"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - myWhitman">
# 										<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 											<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-mywhitman-cog"></use>
# 										</svg>
# 										<span class="wc-text">
# 											myWhitman
# 													<svg class="wc-icon-inline" viewbox="0 0 32 32" aria-hidden="true">
# 														<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-lock"></use>
# 													</svg>
#
# 										</span>
# 									</a>
#
# 						</div>
#
#             </div>
#         </div>
#         <!-- Header Row 2 -->
#         <div class="wc-header-row2" id="wc-header-row2">
#             <div class="wc-container">
#                 <!-- Main Nav-->
#                 <nav class="wc-main-nav wc-sm-collapse" id="wc-main-nav" aria-label="main navigation">
# 							<div class="wc-mobile-only wc-mobile-quick-links" role="menu">
# 										<a class="wc-icon-quick-link" href="a-to-z-index"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - A to Z Index">
# 											<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-a-to-z"></use>
# 											</svg>
# 											<span class="wc-text">
# 												A to Z
#
# 											</span>
# 										</a>
# 										<a class="wc-icon-quick-link" href="campus-map"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Map">
# 											<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-map-pin"></use>
# 											</svg>
# 											<span class="wc-text">
# 												Map
#
# 											</span>
# 										</a>
# 										<a class="wc-icon-quick-link" href="http://calendar.whitman.edu"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Events Calendar">
# 											<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-calendar-no-circle"></use>
# 											</svg>
# 											<span class="wc-text">
# 												Events
#
# 											</span>
# 										</a>
# 										<a class="wc-icon-quick-link" href="https://library.whitman.edu/"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Penrose Library">
# 											<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-library"></use>
# 											</svg>
# 											<span class="wc-text">
# 												Library
#
# 											</span>
# 										</a>
# 										<a class="wc-icon-quick-link" href="https://my.whitman.edu"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - myWhitman">
# 											<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-mywhitman-cog"></use>
# 											</svg>
# 											<span class="wc-text">
# 												myWhitman
# 														<svg class="wc-icon-inline" viewbox="0 0 32 32" aria-hidden="true">
# 															<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-lock"></use>
# 														</svg>
#
# 											</span>
# 										</a>
#
# 							</div>
#
#                     <ul class="wc-main-nav-level-1">
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="about" id="main-1" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="About">About</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-1-box" aria-label="Expand About submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-1-box">
#                                         <ul role="menu" aria-labelledby="main-1">
# 													<li >    <a href="/about/contact-us"    title="Contact Us & Building Hours" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Contact Us & Building Hours" >
#         Contact Us & Building Hours</a>
# </li>
# 													<li >    <a href="/campus-map"    title="Interactive Map" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Interactive Map" >
#         Interactive Map</a>
# </li>
# 													<li >    <a href="/about/leadership-and-organization"    title="Leadership and Organization" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Leadership and Organization" >
#         Leadership and Organization</a>
# </li>
# 													<li >    <a href="/about/mission-constitution-and-bylaws"    title="Mission, Constitution and Bylaws" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Mission, Constitution and Bylaws" >
#         Mission, Constitution and Bylaws</a>
# </li>
# 													<li >    <a href="/newsroom"    title="Newsroom" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Newsroom" >
#         Newsroom</a>
# </li>
# 													<li >    <a href="/president"    title="Office of the President" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Office of the President" >
#         Office of the President</a>
# </li>
# 													<li >    <a href="/about/our-campus"    title="Our Campus" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Our Campus" >
#         Our Campus</a>
# </li>
# 													<li >    <a href="/about/our-community"    title="Our Community" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Our Community" >
#         Our Community</a>
# </li>
# 													<li >    <a href="/about/rankings"    title="Rankings and Top Lists" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Rankings and Top Lists" >
#         Rankings and Top Lists</a>
# </li>
# 													<li >    <a href="/president/strategic-planning"    title="Strategic Planning" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Strategic Planning" >
#         Strategic Planning</a>
# </li>
#
#                                         </ul>
#
#                                     </div>
#                                 </li>
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="academics" id="main-2" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Academics">Academics</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-2-box" aria-label="Expand Academics submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-2-box">
#                                         <ul role="menu" aria-labelledby="main-2">
# 													<li >    <a href="/academics/academic-calendar"    title="Academic Calendar" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Academic Calendar" >
#         Academic Calendar</a>
# </li>
# 													<li >    <a href="/academics/academic-resource-center"    title="Academic Resource Center" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Academic Resource Center" >
#         Academic Resource Center</a>
# </li>
# 													<li >    <a href="/academics/academic-theme"    title="Academic Theme" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Academic Theme" >
#         Academic Theme</a>
# </li>
# 													<li >    <a href="/academics/careers-professions-and-the-liberal-arts"    title="Careers, Professions and the Liberal Arts" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Careers, Professions and the Liberal Arts" >
#         Careers, Professions and the Liberal Arts</a>
# </li>
# 													<li >    <a href="/academics/catalog"    title="Catalog" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Catalog" >
#         Catalog</a>
# </li>
# 													<li >    <a href="/academics/center-for-global-studies"    title="Center for Global Studies" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Center for Global Studies" >
#         Center for Global Studies</a>
# </li>
# 													<li >    <a href="/academics/community-outreach"    title="Community Outreach" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Community Outreach" >
#         Community Outreach</a>
# </li>
# 													<li >    <a href="/after-whitman/fellowships-and-grants"    title="Fellowships and Grants" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Fellowships and Grants" >
#         Fellowships and Grants</a>
# </li>
# 													<li >    <a href="/academics/honor-societies"    title="Honor Societies" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Honor Societies" >
#         Honor Societies</a>
# </li>
# 													<li >    <a href="/academics/majors-and-minors"    title="Majors and Minors" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Majors and Minors" >
#         Majors and Minors</a>
# </li>
# 													<li >    <a href="/academics/maxey-museum"    title="Maxey Museum" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Maxey Museum" >
#         Maxey Museum</a>
# </li>
# 													<li >    <a href="/off-campus-studies"    title="Off-Campus Studies" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Off-Campus Studies" >
#         Off-Campus Studies</a>
# </li>
# 													<li >    <a href="https://library.whitman.edu/"    title="Penrose Library" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Penrose Library" >
#         Penrose Library</a>
# </li>
# 													<li >    <a href="/provost"    title="Provost and Dean of the Faculty" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Provost and Dean of the Faculty" >
#         Provost and Dean of the Faculty</a>
# </li>
# 													<li >    <a href="/registrar"    title="Registrar's Office" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Registrar's Office" >
#         Registrar's Office</a>
# </li>
# 													<li >    <a href="/academics/stem-hub"    title="STEM Hub" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - STEM Hub" >
#         STEM Hub</a>
# </li>
# 													<li >    <a href="/academics/research/whitman-undergraduate-conference"    title="Whitman Undergraduate Conference" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Whitman Undergraduate Conference" >
#         Whitman Undergraduate Conference</a>
# </li>
# 													<li >    <a href="/academics/the-faculty"    title="Whitman's Faculty" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Whitman's Faculty" >
#         Whitman's Faculty</a>
# </li>
#
#                                         </ul>
# 												<div class="wc-feature">
#     <a href="/after-whitman/fellowships-and-grants" >    <img   src="/images/Academics/Fellowships%20%26%20Grants/hunter-conservatory-250.jpg" alt="Fellowships and Grants"  width="150"  />
# </a>
# 														<div class="wc-feature-text">
# 															<p>Learn how to pursue a fellowship, scholarship or grant opportunity.</p>
# 															    <a href="/after-whitman/fellowships-and-grants"  class="wc-box-button wc-bb-more-link wc-white"  title="Fellowships and Grants"
#          >
#         Fellowships and Grants</a>
#
# 														</div>
#
# 												</div>
#
#                                     </div>
#                                 </li>
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="admission-and-aid" id="main-3" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Admission &amp; Aid">Admission &amp; Aid</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-3-box" aria-label="Expand Admission &amp; Aid submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-3-box">
#                                         <ul role="menu" aria-labelledby="main-3">
# 													<li >    <a href="/admission-and-aid/contact-us"    title="Admission & Financial Aid Contacts" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Admission & Financial Aid Contacts" >
#         Admission & Financial Aid Contacts</a>
# </li>
# 													<li >    <a href="/admission-and-aid/applying-to-whitman"    title="Applying to Whitman" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Applying to Whitman" >
#         Applying to Whitman</a>
# </li>
# 													<li >    <a href="/admission-and-aid/applying-to-whitman/early-decision"    title="Early Decision" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Early Decision" >
#         Early Decision</a>
# </li>
# 													<li >    <a href="/admission-and-aid/early-financial-aid-guarantee"    title="Early Financial Aid Guarantee" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Early Financial Aid Guarantee" >
#         Early Financial Aid Guarantee</a>
# </li>
# 													<li >    <a href="/admission-and-aid/financial-aid-and-costs"    title="Financial Aid & Costs" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Financial Aid & Costs" >
#         Financial Aid & Costs</a>
# </li>
# 													<li >    <a href="/admission-and-aid/learn-more-about-whitman"    title="Learn More About Whitman" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Learn More About Whitman" >
#         Learn More About Whitman</a>
# </li>
# 													<li >    <a href="/admission-and-aid/financial-aid-and-costs/merit-and-talent-awards"    title="Merit and Talent Awards" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Merit and Talent Awards" >
#         Merit and Talent Awards</a>
# </li>
# 													<li >    <a href="/admission-and-aid/request-information"    title="Request Information" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Request Information" >
#         Request Information</a>
# </li>
# 													<li >    <a href="/admission-and-aid/virtual-tours"    title="Virtual Tours" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Virtual Tours" >
#         Virtual Tours</a>
# </li>
# 													<li >    <a href="/admission-and-aid/visit-whitman"    title="Visiting Whitman College" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Visiting Whitman College" >
#         Visiting Whitman College</a>
# </li>
# 													<li >    <a href="/admission-and-aid/class-of-2027"    title="Welcome Class of 2027" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Welcome Class of 2027" >
#         Welcome Class of 2027</a>
# </li>
# 													<li >    <a href="/admission-and-aid/whitman-on-the-road"    title="Whitman on the Road" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Whitman on the Road" >
#         Whitman on the Road</a>
# </li>
# 													<li >    <a href="/admission-and-aid/why-whitman"    title="Why Whitman?" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Why Whitman?" >
#         Why Whitman?</a>
# </li>
#
#                                         </ul>
# 												<div class="wc-feature">
#     <a href="/admission-and-aid/visit-whitman" >    <img   src="/images/Admission%20and%20Aid/Thumbnail/campus-fall-250.jpg" alt="Whitman&#39;s campus in the fall"  width="150"  />
# </a>
# 														<div class="wc-feature-text">
# 															<p>Join us on campus to experience the Whitman community in action!</p>
# 															    <a href="/admission-and-aid/visit-whitman"  class="wc-box-button wc-bb-more-link wc-white"  title="Visit Whitman"
#          >
#         Visit Whitman</a>
#
# 														</div>
#
# 												</div>
#
#                                     </div>
#                                 </li>
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="after-whitman" id="main-4" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="After Whitman">After Whitman</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-4-box" aria-label="Expand After Whitman submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-4-box">
#                                         <ul role="menu" aria-labelledby="main-4">
# 													<li >    <a href="/after-whitman/career-and-community-engagement-center"    title="Career and Community Engagement Center" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Career and Community Engagement Center" >
#         Career and Community Engagement Center</a>
# </li>
# 													<li >    <a href="/academics/careers-professions-and-the-liberal-arts"    title="Careers, Professions and the Liberal Arts" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Careers, Professions and the Liberal Arts" >
#         Careers, Professions and the Liberal Arts</a>
# </li>
# 													<li >    <a href="/after-whitman/fellowships-and-grants"    title="Fellowships and Grants" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Fellowships and Grants" >
#         Fellowships and Grants</a>
# </li>
# 													<li >    <a href="/after-whitman/graduate-schools-and-pre-professional-programs"    title="Graduate Schools and Pre-Professional Programs" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Graduate Schools and Pre-Professional Programs" >
#         Graduate Schools and Pre-Professional Programs</a>
# </li>
# 													<li >    <a href="/after-whitman/career-and-community-engagement-center/internships"    title="Internships" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Internships" >
#         Internships</a>
# </li>
# 													<li >    <a href="/after-whitman/life-after-whitman-stories"    title="Life After Whitman Stories" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Life After Whitman Stories" >
#         Life After Whitman Stories</a>
# </li>
# 													<li >    <a href="/academics/research/whitman-undergraduate-conference"    title="Whitman Undergraduate Conference" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Whitman Undergraduate Conference" >
#         Whitman Undergraduate Conference</a>
# </li>
# 													<li >    <a href="/after-whitman/whitties-helping-whitties"    title="Whitties Helping Whitties" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Whitties Helping Whitties" >
#         Whitties Helping Whitties</a>
# </li>
#
#                                         </ul>
#
#                                     </div>
#                                 </li>
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="athletics" id="main-5" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Athletics">Athletics</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-5-box" aria-label="Expand Athletics submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-5-box">
#                                         <ul role="menu" aria-labelledby="main-5">
# 													<li >    <a href="https://athletics.whitman.edu/news/2020/10/6/general-student-access-to-buildings-or-other-campus-resources.aspx"    title="Athletic Facility Hours" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - Athletic Facility Hours" >
#         Athletic Facility Hours</a>
# </li>
# 													<li >    <a href="/athletics/club-sports"    title="Club Sports" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - Club Sports" >
#         Club Sports</a>
# </li>
# 													<li >    <a href="/athletics/intramural-sports"    title="Intramural Sports" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - Intramural Sports" >
#         Intramural Sports</a>
# </li>
# 													<li >    <a href="/academics/majors-and-minors/sports-studies-recreation-and-athletics"    title="Sports Studies, Recreation and Athletics" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - Sports Studies, Recreation and Athletics" >
#         Sports Studies, Recreation and Athletics</a>
# </li>
# 													<li >    <a href="http://athletics.whitman.edu/"    title="Varsity Athletics" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - Varsity Athletics" >
#         Varsity Athletics</a>
# </li>
# 													<li >    <a href="https://athletics.whitman.edu/news/2020/11/30/general-join-the-w-club.aspx"    title="W Club" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - W Club" >
#         W Club</a>
# </li>
#
#                                         </ul>
# 												<div class="wc-feature">
#     <a href="http://athletics2.whitman.edu/calendar.aspx" >    <img   src="/images/About/sort/womens-soccer-250.jpg" alt="Women&#39;s Soccer"  width="150"  />
# </a>
# 														<div class="wc-feature-text">
# 															<p>See when Whitman&#39;s teams are playing this spring.</p>
# 															    <a href="http://athletics2.whitman.edu/calendar.aspx"  class="wc-box-button wc-bb-more-link wc-white"  title="Varsity Athletics Calendar"
#          >
#         Varsity Athletics Calendar</a>
#
# 														</div>
#
# 												</div>
#
#                                     </div>
#                                 </li>
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="campus-life" id="main-6" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Campus Life">Campus Life</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-6-box" aria-label="Expand Campus Life submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-6-box">
#                                         <ul role="menu" aria-labelledby="main-6">
# 													<li >    <a href="/after-whitman/career-and-community-engagement-center"    title="Career and Community Engagement Center" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Career and Community Engagement Center" >
#         Career and Community Engagement Center</a>
# </li>
# 													<li >    <a href="/campus-life/diversity-and-inclusion"    title="Diversity & Inclusion" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Diversity & Inclusion" >
#         Diversity & Inclusion</a>
# </li>
# 													<li >    <a href="/campus-life/international-student-and-scholar-services"    title="International Student & Scholar Services" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - International Student & Scholar Services" >
#         International Student & Scholar Services</a>
# </li>
# 													<li >    <a href="/campus-life/orientation"    title="New Student Orientation" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - New Student Orientation" >
#         New Student Orientation</a>
# </li>
# 													<li >    <a href="/campus-life/outdoor-program"    title="Outdoor Program" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Outdoor Program" >
#         Outdoor Program</a>
# </li>
# 													<li >    <a href="/campus-life/pathways-leadership-program"    title="Pathways Leadership Program" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Pathways Leadership Program" >
#         Pathways Leadership Program</a>
# </li>
# 													<li >    <a href="/campus-life/reid-campus-center"    title="Reid Campus Center" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Reid Campus Center" >
#         Reid Campus Center</a>
# </li>
# 													<li >    <a href="/campus-life/residence-life"    title="Residence Life" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Residence Life" >
#         Residence Life</a>
# </li>
# 													<li >    <a href="/campus-life/sorority-and-fraternity-life"    title="Sorority & Fraternity Life" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Sorority & Fraternity Life" >
#         Sorority & Fraternity Life</a>
# </li>
# 													<li >    <a href="/campus-life/student-activities"    title="Student Activities" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Activities" >
#         Student Activities</a>
# </li>
# 													<li >    <a href="/dean-of-students/student-affairs"    title="Student Affairs" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Affairs" >
#         Student Affairs</a>
# </li>
# 													<li >    <a href="/campus-life/student-employment"    title="Student Employment" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Employment" >
#         Student Employment</a>
# </li>
# 													<li >    <a href="/campus-life/sustainability"    title="Sustainability" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Sustainability" >
#         Sustainability</a>
# </li>
# 													<li >    <a href="/campus-life/student-activities/virtual-campus"    title="Virtual Campus" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Virtual Campus" >
#         Virtual Campus</a>
# </li>
# 													<li >    <a href="https://whitman.presence.io/"    title="WhitLife" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - WhitLife" >
#         WhitLife</a>
# </li>
#
#                                         </ul>
#
#                                     </div>
#                                 </li>
#  <!--end code section-->
#                                     <li class="wc-mobile-only">
# 										<span class="wc-main-nav-primary-category wc-clickable wc-mobile-only">
# 											<span class="wc-center-line">
# 												<span id="mobile-menu-1">Audiences</span>
# 											</span>
# 										</span>
#
#                                         <div class="wc-sub-menu wc-indented">
#                                         <ul aria-labelledby="mobile-menu-1" role="menu">
#                                             <li >
#                                                     <a href="/admission-and-aid/applying-to-whitman"  class="wc-clickable"  title="Apply" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link Mobile - Apply" >
#         Apply</a>
#
#                                             </li>
#                                             <li >
#                                                     <a href="/alumni"  class="wc-clickable"  title="Alumni" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link Mobile - Alumni" >
#         Alumni</a>
#
#                                             </li>
#                                             <li >
#                                                     <a href="/campus-life/diversity-and-inclusion"  class="wc-clickable"  title="Diversity" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link Mobile - Diversity" >
#         Diversity</a>
#
#                                             </li>
#                                             <li >
#                                                     <a href="https://library.whitman.edu/"  class="wc-clickable"  title="Library" data-tracking-category="Header Link"
# ...
#        data-tracking-action="Click" data-tracking-label="Campus Life - Diversity & Inclusion" >
#         Diversity & Inclusion</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/international-student-and-scholar-services"    title="International Student & Scholar Services" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - International Student & Scholar Services" >
#         International Student & Scholar Services</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/orientation"    title="New Student Orientation" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - New Student Orientation" >
#         New Student Orientation</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/outdoor-program"    title="Outdoor Program" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Outdoor Program" >
#         Outdoor Program</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/pathways-leadership-program"    title="Pathways Leadership Program" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Pathways Leadership Program" >
#         Pathways Leadership Program</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/reid-campus-center"    title="Reid Campus Center" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Reid Campus Center" >
#         Reid Campus Center</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/residence-life"    title="Residence Life" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Residence Life" >
#         Residence Life</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/sorority-and-fraternity-life"    title="Sorority & Fraternity Life" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Sorority & Fraternity Life" >
#         Sorority & Fraternity Life</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/student-activities"    title="Student Activities" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Activities" >
#         Student Activities</a>
# </li>
#                                     <li role="menuitem">    <a href="/dean-of-students/student-affairs"    title="Student Affairs" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Affairs" >
#         Student Affairs</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/student-employment"    title="Student Employment" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Employment" >
#         Student Employment</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/sustainability"    title="Sustainability" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Sustainability" >
#         Sustainability</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/student-activities/virtual-campus"    title="Virtual Campus" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Virtual Campus" >
#         Virtual Campus</a>
# </li>
#                                     <li role="menuitem">    <a href="https://whitman.presence.io/"    title="WhitLife" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - WhitLife" >
#         WhitLife</a>
# </li>
#
#                         </ul>
#                     </div>
#                     <div class="wc-footer-list-box">
#                         <h4 class="wc-list-header" id="footer-menu-5">Quick Links</h4>
#                         <ul class="wc-no-style-list" role="menu" aria-labelledby="footer-menu-5">
#                                     <li role="menuitem">    <a href="/a-to-z-index"    title="A to Z Index" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - A to Z Index" >
#         A to Z Index</a>
# </li>
#                                     <li role="menuitem">    <a href="https://whitman-advocate.symplicity.com/public_report/index.php"    title="Bias Reporting" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Bias Reporting" >
#         Bias Reporting</a>
# </li>
#                                     <li role="menuitem">    <a href="http://bookstore.whitman.edu/home.aspx"    title="Bookstore" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Bookstore" >
#         Bookstore</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-map"    title="Campus Map" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Campus Map" >
#         Campus Map</a>
# </li>
#                                     <li role="menuitem">    <a href="/dean-of-students/care-team"    title="CARE Team" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - CARE Team" >
#         CARE Team</a>
# </li>
#                                     <li role="menuitem">    <a href="/after-whitman/career-and-community-engagement-center/job-and-career-resources"    title="Career Services" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Career Services" >
#         Career Services</a>
# </li>
#                                     <li role="menuitem">    <a href="/communications"    title="Communications" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Communications" >
#         Communications</a>
# </li>
#                                     <li role="menuitem">    <a href="/human-resources"    title="Employment Opportunities" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Employment Opportunities" >
#         Employment Opportunities</a>
# </li>
#                                     <li role="menuitem">    <a href="/giving"    title="Giving" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Giving" >
#         Giving</a>
# </li>
#                                     <li role="menuitem">    <a href="/human-resources/grievance-policy"    title="Grievance Policy" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Grievance Policy" >
#         Grievance Policy</a>
# </li>
#                                     <li role="menuitem">    <a href="/newsroom"    title="Newsroom" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Newsroom" >
#         Newsroom</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/diversity-and-inclusion/nondiscrimination-policy"    title="Nondiscrimination Policy" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Nondiscrimination Policy" >
#         Nondiscrimination Policy</a>
# </li>
#                                     <li role="menuitem">    <a href="https://library.whitman.edu/"    title="Penrose Library" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Penrose Library" >
#         Penrose Library</a>
# </li>
#                                     <li role="menuitem">    <a href="/dean-of-students/right-to-know"    title="Right to Know" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Right to Know" >
#         Right to Know</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct"    title="Sexual Misconduct & Title IX" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Sexual Misconduct & Title IX" >
#         Sexual Misconduct & Title IX</a>
# </li>
#                                     <li role="menuitem">    <a href="/communications/social-media"    title="Social Media " data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Social Media " >
#         Social Media </a>
# </li>
#                                     <li role="menuitem">    <a href="/academics/the-center-for-writing-and-speaking"    title="The Center for Writing and Speaking (COWS)" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - The Center for Writing and Speaking (COWS)" >
#         The Center for Writing and Speaking (COWS)</a>
# </li>
#                                     <li role="menuitem">    <a href="/website-privacy-policy"    title="Website Privacy Policy" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Website Privacy Policy" >
#         Website Privacy Policy</a>
# </li>
#                                     <li role="menuitem">    <a href="/welty-student-health-center"    title="Welty Student Health Center" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Welty Student Health Center" >
#         Welty Student Health Center</a>
# </li>
#
#                         </ul>
#                     </div>
#
#
#         </div>
#
#         <!-- Logo -->
#         <div class="wc-row wc-footer-row2" aria-hidden="true">
#             <div class="wc-footer-row2-box-a" itemscope itemtype="http://schema.org/CollegeOrUniversity">
#                 <hr />
#                 <svg class="wc-footer-logo-flat" viewbox="0 0 180 15">
#                     <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#logo-whitman-nc-flat"></use>
#                 </svg>
#                 <svg class="wc-footer-logo-stacked" viewbox="0 0 164 60" aria-hidden="true">
#                     <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#logo-whitman-nc-stacked"></use>
#                 </svg>
#                 <hr />
#             </div>
#         </div>
#
#         <!-- Contact Info -->
#         <div class="wc-row wc-footer-row3" itemscope itemtype="http://schema.org/CollegeOrUniversity">
#             <div class="wc-footer-row3-box-a wc-footer-row3-box" itemprop="address" itemscope itemtype="http://schema.org/PostalAddress">
#
#
#                 <a href="https://www.google.com/maps/place/Whitman+College/@46.0717833,-118.3304355,16z/data=!4m2!3m1!1s0x0000000000000000:0x8704a8d5077eb801" target="_blank" class="wc-street-address">
#                         <svg class="" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-map-pin"></use>
#     </svg>
#
#                     <span class="wc-text">
#                         <span itemprop="streetAddress">345 Boyer Ave. </span>
#                         <span><span itemprop="addressLocality">Walla Walla</span>, <span itemprop="addressRegion">WA</span> <span itemprop="postalCode">99362</span></span>
#                     </span>
#                 </a>
#             </div>
#             <div class="wc-footer-row3-box-b wc-footer-row3-box">
#
#                 <span class="wc-phone-numbers">
#                         <svg class="" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-phone"></use>
#     </svg>
#
#                     <span class="wc-text">
#                             <span>General: <span itemprop="telephone">509-527-5111</span></span>
#                         <span class="wc-bullet">&bull;</span>
#
#                             <span>Admission: <span itemprop="telephone">509-527-5176</span></span>
#                     </span>
#                 </span>
#             </div>
#             <div class="wc-footer-row3-box-c wc-footer-row3-box">
#
#                 <link itemprop="url" href="https://www.whitman.edu">
#                 <link itemprop="sameAs" href="https://en.wikipedia.org/wiki/Whitman_College">
# <a href="https://facebook.com/whitmancollege" class="wc-social-link" title="Whitman College Facebook Page" target="_blank" aria-label="Whitman College Facebook Page">
#         <span class="visually-hidden">visually-hidden text</span>
#             <svg class="wc-icon" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-facebook"></use>
#     </svg>
#
#     </a>
# <a href="https://twitter.com/whitmancollege" class="wc-social-link" title="Whitman College Twitter Page" target="_blank" aria-label="Whitman College Twitter Page">
#         <span class="visually-hidden">visually-hidden text</span>
#             <svg class="wc-icon" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-twitter"></use>
#     </svg>
#
#     </a>
# <a href="https://instagram.com/whitmancollege" class="wc-social-link" title="Whitman College Instagram Page" target="_blank" aria-label="Whitman College Instagram Page">
#         <span class="visually-hidden">visually-hidden text</span>
#             <svg class="wc-icon" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-instagram"></use>
#     </svg>
#
#     </a>
# <a href="https://youtube.com/whitmancollege" class="wc-social-link" title="Whitman College YouTube Page" target="_blank" aria-label="Whitman College YouTube Page">
#         <span class="visually-hidden">visually-hidden text</span>
#             <svg class="wc-icon" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-youtube"></use>
#     </svg>
#
#     </a>
#                         <a title="Social Media at Whitman" class="wc-more-social-links" href="communications/social-media/social-media-links" data-tracking-category="Footer Link" data-tracking-action="Click" data-tracking-label="Social Media at Whitman" aria-label="Social Media at Whitman">
#                                 <svg class="" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-right"></use>
#     </svg>
#
#                         </a>
#
#             </div>
#         </div>
#         <div class="wc-row wc-footer-row4">
#             <div class="wc-footer-row4-box-a" role="contentinfo">
#                 <span class="wc-copyright"></span>
#             </div>
#         </div>
#     </div>
# </footer>
#
#
#
#
#
#
#
#
#     <div class="wc-breakpoint-check-box">
#         <div id="wc-breakpoint-check-lg" class="wc-breakpoint-check"></div>
#         <div id="wc-breakpoint-check-md" class="wc-breakpoint-check"></div>
#         <div id="wc-breakpoint-check-sm" class="wc-breakpoint-check"></div>
#         <div id="wc-breakpoint-check-xs" class="wc-breakpoint-check"></div>
#     </div>
#     <span id="wc-svg-path" data-svg-path="/prebuilt/v9/dist/svg/svg-defs.svg?v=12"></span>
#     <script id="wc-scripts-tag" src="/prebuilt/v9/dist/js/wc-scripts.js?v=20220427_1"></script>
#     <script src="/prebuilt/v9/dist/js/wc-popup.js"></script>
#     <script src="/prebuilt/v9/dist/js/wc-scripts-2019.js"></script>
#
#
# </body>
# </html>

# %%
# Now let's turn it into soup
# The first argument is our HTML, which we can access with .text
# The second argument is our parser -- we can use lxml, html, and there are others...
soup = BeautifulSoup(html.text, 'html')

# %% [markdown]
# ### Part 2: Doing some basic searching with BeautifulSoup
#
# Not very fun for a human to read...So where this gets *really* powerful is that now we can navigate through the soup, programmatically, very easily!

# %% [markdown]
# #### We can use .find to show the first instance of any tag

# %%
# The first link (a tag)
soup.find("a")
# Out:
# <a class="wc-skip-to-content-link" href="/academics/majors-and-minors/economics/faculty#wc-reader-content">Skip to main content</a>

# %%
# The first h1
soup.find("h1")
# Out:
# <h1 class="wc-page-title">Faculty</h1>

# %%
# The first image
soup.find("img")
# Out:
# <img alt="Clocktower Logo" class="wc-desktop-header-logo" onerror="this.src='/prebuilt/v9/images/misc/whitman-logo-header.png'" src="/prebuilt/v9/images/svg/whitman-logo-header.svg"/>

# %%
# The first unordered list
soup.find("ul")
# Out:
# <ul role="menubar">
# <li>
# <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - Apply" href="/admission-and-aid/applying-to-whitman" title="Apply">
#         Apply</a>
# <span aria-hidden="true" class="wc-bullet">•</span>
# </li>
# <li>
# <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - Alumni" href="/alumni" title="Alumni">
#         Alumni</a>
# <span aria-hidden="true" class="wc-bullet">•</span>
# </li>
# <li>
# <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - Diversity" href="/campus-life/diversity-and-inclusion" title="Diversity">
#         Diversity</a>
# <span aria-hidden="true" class="wc-bullet">•</span>
# </li>
# <li>
# <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - Library" href="https://library.whitman.edu/" title="Library">
#         Library</a>
# <span aria-hidden="true" class="wc-bullet">•</span>
# </li>
# <li>
# <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - MyWhitman" href="https://my.whitman.edu/" title="MyWhitman">
#         MyWhitman</a>
# <span aria-hidden="true" class="wc-bullet">•</span>
# </li>
# <li>
# <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - Families" href="/families" title="Families">
#         Families</a>
# </li>
# </ul>

# %% [markdown]
# #### We can use .find_all() to find all the instances of a tag
# Note how it returns them as a list

# %%
# Find all the links:
links = soup.find_all("a")

# %%
# How many links (a tags) are there are in this page?
print(len(links))
# Out:
# 281

# %%
print(links)
# Out:
# [<a class="wc-skip-to-content-link" href="/academics/majors-and-minors/economics/faculty#wc-reader-content">Skip to main content</a>, <a class="wc-header-logo-link" href="/" title="Whitman College home">
# <!-- Desktop Logo -->
# <img alt="Clocktower Logo" class="wc-desktop-header-logo" onerror="this.src='/prebuilt/v9/images/misc/whitman-logo-header.png'" src="/prebuilt/v9/images/svg/whitman-logo-header.svg"/>
# <!-- Mobile Logo-->
# <svg class="wc-mobile-header-logo" viewbox="0 0 180 15">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#logo-whitman-nc-flat"></use>
# </svg>
# </a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - Apply" href="/admission-and-aid/applying-to-whitman" title="Apply">
#         Apply</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - Alumni" href="/alumni" title="Alumni">
#         Alumni</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - Diversity" href="/campus-life/diversity-and-inclusion" title="Diversity">
#         Diversity</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - Library" href="https://library.whitman.edu/" title="Library">
#         Library</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - MyWhitman" href="https://my.whitman.edu/" title="MyWhitman">
#         MyWhitman</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link - Families" href="/families" title="Families">
#         Families</a>, <a class="wc-special-button wc-box-button wc-white" href="https://www.givecampus.com/campaigns/7878/donations/new" target="_blank" title="Make A Gift">
#         Make A Gift</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Bias Reporting" href="https://whitman-advocate.symplicity.com/public_report/index.php" title="Bias Reporting">
#         Bias Reporting</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Bookstore" href="http://bookstore.whitman.edu/home.aspx" title="Bookstore">
#         Bookstore</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - CARE Team" href="/dean-of-students/care-team" title="CARE Team">
#         CARE Team</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Career Services" href="/after-whitman/career-and-community-engagement-center/job-and-career-resources" title="Career Services">
#         Career Services</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Communications" href="/communications" title="Communications">
#         Communications</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Employment Opportunities" href="/human-resources" title="Employment Opportunities">
#         Employment Opportunities</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Giving" href="/giving" title="Giving">
#         Giving</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Grievance Policy" href="/human-resources/grievance-policy" title="Grievance Policy">
#         Grievance Policy</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Newsroom" href="/newsroom" title="Newsroom">
#         Newsroom</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Nondiscrimination Policy" href="/campus-life/diversity-and-inclusion/nondiscrimination-policy" title="Nondiscrimination Policy">
#         Nondiscrimination Policy</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Right to Know" href="/dean-of-students/right-to-know" title="Right to Know">
#         Right to Know</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Sexual Misconduct &amp; Title IX" href="/campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct" title="Sexual Misconduct &amp; Title IX">
#         Sexual Misconduct &amp; Title IX</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Social Media " href="/communications/social-media" title="Social Media ">
#         Social Media </a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - The Center for Writing and Speaking (COWS)" href="/academics/the-center-for-writing-and-speaking" title="The Center for Writing and Speaking (COWS)">
#         The Center for Writing and Speaking (COWS)</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Website Privacy Policy" href="/website-privacy-policy" title="Website Privacy Policy">
#         Website Privacy Policy</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link - Welty Student Health Center" href="/welty-student-health-center" title="Welty Student Health Center">
#         Welty Student Health Center</a>, <a class="wc-icon-quick-link" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Icon - A to Z Index" href="a-to-z-index">
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-a-to-z"></use>
# </svg>
# <span class="wc-text">
# 											A to Z Index
#
# 										</span>
# </a>, <a class="wc-icon-quick-link" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Icon - Map" href="campus-map">
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-map-pin"></use>
# </svg>
# <span class="wc-text">
# 											Map
#
# 										</span>
# </a>, <a class="wc-icon-quick-link" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Icon - Events Calendar" href="http://calendar.whitman.edu">
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-calendar-no-circle"></use>
# </svg>
# <span class="wc-text">
# 											Events Calendar
#
# 										</span>
# </a>, <a class="wc-icon-quick-link" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Icon - Penrose Library" href="https://library.whitman.edu/">
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-library"></use>
# </svg>
# <span class="wc-text">
# 											Penrose Library
#
# 										</span>
# </a>, <a class="wc-icon-quick-link" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Icon - myWhitman" href="https://my.whitman.edu">
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-mywhitman-cog"></use>
# </svg>
# <span class="wc-text">
# 											myWhitman
# 													<svg aria-hidden="true" class="wc-icon-inline" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-lock"></use>
# </svg>
# </span>
# </a>, <a class="wc-icon-quick-link" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Icon - A to Z Index" href="a-to-z-index">
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-a-to-z"></use>
# </svg>
# <span class="wc-text">
# 												A to Z
#
# 											</span>
# </a>, <a class="wc-icon-quick-link" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Icon - Map" href="campus-map">
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-map-pin"></use>
# </svg>
# <span class="wc-text">
# 												Map
#
# 											</span>
# </a>, <a class="wc-icon-quick-link" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Icon - Events Calendar" href="http://calendar.whitman.edu">
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-calendar-no-circle"></use>
# </svg>
# <span class="wc-text">
# 												Events
#
# 											</span>
# </a>, <a class="wc-icon-quick-link" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Icon - Penrose Library" href="https://library.whitman.edu/">
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-library"></use>
# </svg>
# <span class="wc-text">
# 												Library
#
# 											</span>
# </a>, <a class="wc-icon-quick-link" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Icon - myWhitman" href="https://my.whitman.edu">
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-mywhitman-cog"></use>
# </svg>
# <span class="wc-text">
# 												myWhitman
# 														<svg aria-hidden="true" class="wc-icon-inline" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-lock"></use>
# </svg>
# </span>
# </a>, <a class="wc-main-nav-primary-category wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About" href="about" id="main-1">About</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About - Contact Us &amp; Building Hours" href="/about/contact-us" title="Contact Us &amp; Building Hours">
#         Contact Us &amp; Building Hours</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About - Interactive Map" href="/campus-map" title="Interactive Map">
#         Interactive Map</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About - Leadership and Organization" href="/about/leadership-and-organization" title="Leadership and Organization">
#         Leadership and Organization</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About - Mission, Constitution and Bylaws" href="/about/mission-constitution-and-bylaws" title="Mission, Constitution and Bylaws">
#         Mission, Constitution and Bylaws</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About - Newsroom" href="/newsroom" title="Newsroom">
#         Newsroom</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About - Office of the President" href="/president" title="Office of the President">
#         Office of the President</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About - Our Campus" href="/about/our-campus" title="Our Campus">
#         Our Campus</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About - Our Community" href="/about/our-community" title="Our Community">
#         Our Community</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About - Rankings and Top Lists" href="/about/rankings" title="Rankings and Top Lists">
#         Rankings and Top Lists</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="About - Strategic Planning" href="/president/strategic-planning" title="Strategic Planning">
#         Strategic Planning</a>, <a class="wc-main-nav-primary-category wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics" href="academics" id="main-2">Academics</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Academic Calendar" href="/academics/academic-calendar" title="Academic Calendar">
#         Academic Calendar</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Academic Resource Center" href="/academics/academic-resource-center" title="Academic Resource Center">
#         Academic Resource Center</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Academic Theme" href="/academics/academic-theme" title="Academic Theme">
#         Academic Theme</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Careers, Professions and the Liberal Arts" href="/academics/careers-professions-and-the-liberal-arts" title="Careers, Professions and the Liberal Arts">
#         Careers, Professions and the Liberal Arts</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Catalog" href="/academics/catalog" title="Catalog">
#         Catalog</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Center for Global Studies" href="/academics/center-for-global-studies" title="Center for Global Studies">
#         Center for Global Studies</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Community Outreach" href="/academics/community-outreach" title="Community Outreach">
#         Community Outreach</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Fellowships and Grants" href="/after-whitman/fellowships-and-grants" title="Fellowships and Grants">
#         Fellowships and Grants</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Honor Societies" href="/academics/honor-societies" title="Honor Societies">
#         Honor Societies</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Majors and Minors" href="/academics/majors-and-minors" title="Majors and Minors">
#         Majors and Minors</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Maxey Museum" href="/academics/maxey-museum" title="Maxey Museum">
#         Maxey Museum</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Off-Campus Studies" href="/off-campus-studies" title="Off-Campus Studies">
#         Off-Campus Studies</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Penrose Library" href="https://library.whitman.edu/" title="Penrose Library">
#         Penrose Library</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Provost and Dean of the Faculty" href="/provost" title="Provost and Dean of the Faculty">
#         Provost and Dean of the Faculty</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Registrar's Office" href="/registrar" title="Registrar's Office">
#         Registrar's Office</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - STEM Hub" href="/academics/stem-hub" title="STEM Hub">
#         STEM Hub</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Whitman Undergraduate Conference" href="/academics/research/whitman-undergraduate-conference" title="Whitman Undergraduate Conference">
#         Whitman Undergraduate Conference</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Academics - Whitman's Faculty" href="/academics/the-faculty" title="Whitman's Faculty">
#         Whitman's Faculty</a>, <a href="/after-whitman/fellowships-and-grants"> <img alt="Fellowships and Grants" src="/images/Academics/Fellowships%20%26%20Grants/hunter-conservatory-250.jpg" width="150"/>
# </a>, <a class="wc-box-button wc-bb-more-link wc-white" href="/after-whitman/fellowships-and-grants" title="Fellowships and Grants">
#         Fellowships and Grants</a>, <a class="wc-main-nav-primary-category wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid" href="admission-and-aid" id="main-3">Admission &amp; Aid</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Admission &amp; Financial Aid Contacts" href="/admission-and-aid/contact-us" title="Admission &amp; Financial Aid Contacts">
#         Admission &amp; Financial Aid Contacts</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Applying to Whitman" href="/admission-and-aid/applying-to-whitman" title="Applying to Whitman">
#         Applying to Whitman</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Early Decision" href="/admission-and-aid/applying-to-whitman/early-decision" title="Early Decision">
#         Early Decision</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Early Financial Aid Guarantee" href="/admission-and-aid/early-financial-aid-guarantee" title="Early Financial Aid Guarantee">
#         Early Financial Aid Guarantee</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Financial Aid &amp; Costs" href="/admission-and-aid/financial-aid-and-costs" title="Financial Aid &amp; Costs">
#         Financial Aid &amp; Costs</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Learn More About Whitman" href="/admission-and-aid/learn-more-about-whitman" title="Learn More About Whitman">
#         Learn More About Whitman</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Merit and Talent Awards" href="/admission-and-aid/financial-aid-and-costs/merit-and-talent-awards" title="Merit and Talent Awards">
#         Merit and Talent Awards</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Request Information" href="/admission-and-aid/request-information" title="Request Information">
#         Request Information</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Virtual Tours" href="/admission-and-aid/virtual-tours" title="Virtual Tours">
#         Virtual Tours</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Visiting Whitman College" href="/admission-and-aid/visit-whitman" title="Visiting Whitman College">
#         Visiting Whitman College</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Welcome Class of 2027" href="/admission-and-aid/class-of-2027" title="Welcome Class of 2027">
#         Welcome Class of 2027</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Whitman on the Road" href="/admission-and-aid/whitman-on-the-road" title="Whitman on the Road">
#         Whitman on the Road</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Admission &amp; Aid - Why Whitman?" href="/admission-and-aid/why-whitman" title="Why Whitman?">
#         Why Whitman?</a>, <a href="/admission-and-aid/visit-whitman"> <img alt="Whitman's campus in the fall" src="/images/Admission%20and%20Aid/Thumbnail/campus-fall-250.jpg" width="150"/>
# </a>, <a class="wc-box-button wc-bb-more-link wc-white" href="/admission-and-aid/visit-whitman" title="Visit Whitman">
#         Visit Whitman</a>, <a class="wc-main-nav-primary-category wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="After Whitman" href="after-whitman" id="main-4">After Whitman</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="After Whitman - Career and Community Engagement Center" href="/after-whitman/career-and-community-engagement-center" title="Career and Community Engagement Center">
#         Career and Community Engagement Center</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="After Whitman - Careers, Professions and the Liberal Arts" href="/academics/careers-professions-and-the-liberal-arts" title="Careers, Professions and the Liberal Arts">
#         Careers, Professions and the Liberal Arts</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="After Whitman - Fellowships and Grants" href="/after-whitman/fellowships-and-grants" title="Fellowships and Grants">
#         Fellowships and Grants</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="After Whitman - Graduate Schools and Pre-Professional Programs" href="/after-whitman/graduate-schools-and-pre-professional-programs" title="Graduate Schools and Pre-Professional Programs">
#         Graduate Schools and Pre-Professional Programs</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="After Whitman - Internships" href="/after-whitman/career-and-community-engagement-center/internships" title="Internships">
#         Internships</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="After Whitman - Life After Whitman Stories" href="/after-whitman/life-after-whitman-stories" title="Life After Whitman Stories">
#         Life After Whitman Stories</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="After Whitman - Whitman Undergraduate Conference" href="/academics/research/whitman-undergraduate-conference" title="Whitman Undergraduate Conference">
#         Whitman Undergraduate Conference</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="After Whitman - Whitties Helping Whitties" href="/after-whitman/whitties-helping-whitties" title="Whitties Helping Whitties">
#         Whitties Helping Whitties</a>, <a class="wc-main-nav-primary-category wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Athletics" href="athletics" id="main-5">Athletics</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Athletics - Athletic Facility Hours" href="https://athletics.whitman.edu/news/2020/10/6/general-student-access-to-buildings-or-other-campus-resources.aspx" title="Athletic Facility Hours">
#         Athletic Facility Hours</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Athletics - Club Sports" href="/athletics/club-sports" title="Club Sports">
#         Club Sports</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Athletics - Intramural Sports" href="/athletics/intramural-sports" title="Intramural Sports">
#         Intramural Sports</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Athletics - Sports Studies, Recreation and Athletics" href="/academics/majors-and-minors/sports-studies-recreation-and-athletics" title="Sports Studies, Recreation and Athletics">
#         Sports Studies, Recreation and Athletics</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Athletics - Varsity Athletics" href="http://athletics.whitman.edu/" title="Varsity Athletics">
#         Varsity Athletics</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Athletics - W Club" href="https://athletics.whitman.edu/news/2020/11/30/general-join-the-w-club.aspx" title="W Club">
#         W Club</a>, <a href="http://athletics2.whitman.edu/calendar.aspx"> <img alt="Women's Soccer" src="/images/About/sort/womens-soccer-250.jpg" width="150"/>
# </a>, <a class="wc-box-button wc-bb-more-link wc-white" href="http://athletics2.whitman.edu/calendar.aspx" title="Varsity Athletics Calendar">
#         Varsity Athletics Calendar</a>, <a class="wc-main-nav-primary-category wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life" href="campus-life" id="main-6">Campus Life</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Career and Community Engagement Center" href="/after-whitman/career-and-community-engagement-center" title="Career and Community Engagement Center">
#         Career and Community Engagement Center</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Diversity &amp; Inclusion" href="/campus-life/diversity-and-inclusion" title="Diversity &amp; Inclusion">
#         Diversity &amp; Inclusion</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - International Student &amp; Scholar Services" href="/campus-life/international-student-and-scholar-services" title="International Student &amp; Scholar Services">
#         International Student &amp; Scholar Services</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - New Student Orientation" href="/campus-life/orientation" title="New Student Orientation">
#         New Student Orientation</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Outdoor Program" href="/campus-life/outdoor-program" title="Outdoor Program">
#         Outdoor Program</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Pathways Leadership Program" href="/campus-life/pathways-leadership-program" title="Pathways Leadership Program">
#         Pathways Leadership Program</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Reid Campus Center" href="/campus-life/reid-campus-center" title="Reid Campus Center">
#         Reid Campus Center</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Residence Life" href="/campus-life/residence-life" title="Residence Life">
#         Residence Life</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Sorority &amp; Fraternity Life" href="/campus-life/sorority-and-fraternity-life" title="Sorority &amp; Fraternity Life">
#         Sorority &amp; Fraternity Life</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Student Activities" href="/campus-life/student-activities" title="Student Activities">
#         Student Activities</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Student Affairs" href="/dean-of-students/student-affairs" title="Student Affairs">
#         Student Affairs</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Student Employment" href="/campus-life/student-employment" title="Student Employment">
#         Student Employment</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Sustainability" href="/campus-life/sustainability" title="Sustainability">
#         Sustainability</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - Virtual Campus" href="/campus-life/student-activities/virtual-campus" title="Virtual Campus">
#         Virtual Campus</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Campus Life - WhitLife" href="https://whitman.presence.io/" title="WhitLife">
#         WhitLife</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link Mobile - Apply" href="/admission-and-aid/applying-to-whitman" title="Apply">
#         Apply</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link Mobile - Alumni" href="/alumni" title="Alumni">
#         Alumni</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link Mobile - Diversity" href="/campus-life/diversity-and-inclusion" title="Diversity">
#         Diversity</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link Mobile - Library" href="https://library.whitman.edu/" title="Library">
#         Library</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link Mobile - MyWhitman" href="https://my.whitman.edu/" title="MyWhitman">
#         MyWhitman</a>, <a class="wc-clickable" data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Constituent Link Mobile - Families" href="/families" title="Families">
#         Families</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Bias Reporting" href="https://whitman-advocate.symplicity.com/public_report/index.php" title="Bias Reporting">
#         Bias Reporting</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Bookstore" href="http://bookstore.whitman.edu/home.aspx" title="Bookstore">
#         Bookstore</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - CARE Team" href="/dean-of-students/care-team" title="CARE Team">
#         CARE Team</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Career Services" href="/after-whitman/career-and-community-engagement-center/job-and-career-resources" title="Career Services">
#         Career Services</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Communications" href="/communications" title="Communications">
#         Communications</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Employment Opportunities" href="/human-resources" title="Employment Opportunities">
#         Employment Opportunities</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Giving" href="/giving" title="Giving">
#         Giving</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Grievance Policy" href="/human-resources/grievance-policy" title="Grievance Policy">
#         Grievance Policy</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Newsroom" href="/newsroom" title="Newsroom">
#         Newsroom</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Nondiscrimination Policy" href="/campus-life/diversity-and-inclusion/nondiscrimination-policy" title="Nondiscrimination Policy">
#         Nondiscrimination Policy</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Right to Know" href="/dean-of-students/right-to-know" title="Right to Know">
#         Right to Know</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Sexual Misconduct &amp; Title IX" href="/campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct" title="Sexual Misconduct &amp; Title IX">
#         Sexual Misconduct &amp; Title IX</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Social Media " href="/communications/social-media" title="Social Media ">
#         Social Media </a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - The Center for Writing and Speaking (COWS)" href="/academics/the-center-for-writing-and-speaking" title="The Center for Writing and Speaking (COWS)">
#         The Center for Writing and Speaking (COWS)</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Website Privacy Policy" href="/website-privacy-policy" title="Website Privacy Policy">
#         Website Privacy Policy</a>, <a data-tracking-action="Click" data-tracking-category="Header Link" data-tracking-label="Quick Link Mobile1 - Welty Student Health Center" href="/welty-student-health-center" title="Welty Student Health Center">
#         Welty Student Health Center</a>, <a class="wc-search-option wc-search-website wc-highlighted" id="wc-search-website" role="button">Site</a>, <a class="wc-search-option wc-search-people" id="wc-search-people" role="button">People</a>, <a aria-label="Home" href="" title="Home">
# <svg aria-hidden="true" class="" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-home"></use>
# </svg>
# </a>, <a href="/academics" title="Academics">
#         Academics</a>, <a href="/academics/majors-and-minors" title="Majors and Minors">
#         Majors and Minors</a>, <a href="/academics/majors-and-minors/economics" title="Economics">
#         Economics</a>, <a class="wc-home-button" href="" title="Home">
# <svg class="wc-icon" viewbox="0 0 32 32"><use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-home"></use></svg></a>, <a class="wc-close-button wc-collapse-button" data-target="#wc-mobile-breadcrumbs">
# <svg class="wc-icon wc-close-button" viewbox="0 0 32 32"><use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-menu-x"></use></svg>
# </a>, <a class="wc-ellipsis-link wc-collapse-button" data-target="#wc-mobile-breadcrumbs">/ ... /</a>, <a class="wc-link" href="/academics" title="Academics">
#         Academics</a>, <a class="wc-link" href="/academics/majors-and-minors" title="Majors and Minors">
#         Majors and Minors</a>, <a class="wc-link" href="/academics/majors-and-minors/economics" title="Economics">
#         Economics</a>, <a class="wc-section-nav-heading" href="/academics/majors-and-minors/economics" title="Economics">
#         Economics</a>, <a class="wc-nav-link" data-tracking-label=" Department Highlights" href="/academics/majors-and-minors/economics/department-highlights" title="Department Highlights">
# Department Highlights
#                 </a>, <a class="wc-nav-link wc-sub-nav-header" data-tracking-label=" Economics Major Programs" href="/academics/majors-and-minors/economics/economics-major-programs" title="Economics Major Programs">
# Economics Major Programs
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Courses and Requirements" href="/documents/Offices/Registrar/Catalog/Economics.pdf" title="Courses and Requirements">
# Courses and Requirements
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Learning Goals" href="/academics/majors-and-minors/economics/economics-major-programs/learning-goals" title="Learning Goals">
# Learning Goals
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Senior Assessment" href="/academics/majors-and-minors/economics/economics-major-programs/economics-senior-assessment" title="Senior Assessment">
# Senior Assessment
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Department Honors" href="/academics/majors-and-minors/economics/economics-major-programs/department-honors" title="Department Honors">
# Department Honors
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Economics - Environmental Studies" href="/academics/majors-and-minors/environmental-studies/environmental-studies-major/economics-environmental-studies" title="Economics - Environmental Studies">
# Economics - Environmental Studies
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Economics - Mathematics" href="/academics/majors-and-minors/interdisciplinary-majors/economics-mathematics" title="Economics - Mathematics">
# Economics - Mathematics
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Economics Lectureships" href="/academics/majors-and-minors/economics/economics-lectureships" title="Economics Lectureships">
# Economics Lectureships
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Whitman Investment Company" href="https://whitmanwic.blog/" target="_blank" title="Whitman Investment Company">
# Whitman Investment Company    <svg aria-hidden="true" class="wc-link-info-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-external-link"></use>
# </svg>
# </a>, <a class="wc-nav-link wc-sub-nav-header" data-tracking-label=" Working Paper Series" href="/academics/majors-and-minors/economics/working-paper-series" title="Working Paper Series">
# Working Paper Series
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Editors" href="/academics/majors-and-minors/economics/working-paper-series/editors" title="Editors">
# Editors
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Submission Guidelines" href="/academics/majors-and-minors/economics/working-paper-series/submission-guidelines" title="Submission Guidelines">
# Submission Guidelines
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Contents" href="/academics/majors-and-minors/economics/working-paper-series/contents" title="Contents">
# Contents
#                 </a>, <a class="wc-nav-link" data-tracking-label=" After Whitman" href="/academics/majors-and-minors/economics/economics-after-whitman" title="After Whitman">
# After Whitman
#                 </a>, <a class="wc-nav-link" data-tracking-label=" Links" href="/academics/majors-and-minors/economics/links" title="Links">
# Links
#                 </a>, <a href="/documents/Offices/Registrar/Catalog/Economics.pdf" title="Course Catalog">
#         Course Catalog</a>, <a href="/academics/majors-and-minors/interdisciplinary-majors/economics-environmental-studies" title="Economics - Environmental Studies ">
#         Economics - Environmental Studies </a>, <a href="/academics/majors-and-minors/interdisciplinary-majors/economics-mathematics" title="Economics - Mathematics ">
#         Economics - Mathematics </a>, <a href="/off-campus-studies/advising-by-major/economics" title="Off-Campus Studies">
#         Off-Campus Studies</a>, <a class="wc-text" href="mailto:hazlett@whitman.edu">hazlett@whitman.edu</a>, <a class="wc-text" href="a/64306">Curriculum Vitae</a>, <a class="wc-box-button solid wc-bb-more-link" href="/academics/majors-and-minors/economics/denise-hazlett" title="More Information">
#         More Information</a>, <a class="wc-text" href="mailto:belayh@whitman.edu">belayh@whitman.edu</a>, <a class="wc-text" href="http://people.whitman.edu/~belayh/">Halefom's Personal Website</a>, <a class="wc-box-button solid wc-bb-more-link" href="/academics/majors-and-minors/economics/halefom-belay" title="More Information">
#         More Information</a>, <a class="wc-text" href="mailto:crouter@whitman.edu">crouter@whitman.edu</a>, <a class="wc-text" href="a/19960">Curriculum Vitae</a>, <a class="wc-box-button solid wc-bb-more-link" href="/academics/majors-and-minors/economics/jan-crouter" title="More Information">
#         More Information</a>, <a class="wc-text" href="mailto:hanr@whitman.edu">hanr@whitman.edu</a>, <a class="wc-box-button solid wc-bb-more-link" href="/academics/majors-and-minors/economics/ruoning-han" title="More Information">
#         More Information</a>, <a class="wc-text" href="mailto:sai@whitman.edu">sai@whitman.edu</a>, <a class="wc-text" href="a/61325">Curriculum Vitae</a>, <a class="wc-box-button solid wc-bb-more-link" href="/academics/majors-and-minors/economics/sai-madhurika-mamunuru" title="More Information">
#         More Information</a>, <a class="wc-text" href="mailto:manicm@whitman.edu">manicm@whitman.edu</a>, <a class="wc-text" href="https://drive.google.com/open?id=1cmfp-RDeD-okE1qA-KDiURC88SrczvNC">Curriculum Vitae</a>, <a class="wc-box-button solid wc-bb-more-link" href="/academics/majors-and-minors/economics/marian-manic" title="More Information">
#         More Information</a>, <a class="wc-text" href="mailto:muellerm@whitman.edu">muellerm@whitman.edu</a>, <a class="wc-text" href="https://www.rosiemueller.com/">Curriculum Vitae</a>, <a class="wc-box-button solid wc-bb-more-link" href="/academics/majors-and-minors/economics/rosie-mueller" title="More Information">
#         More Information</a>, <a class="wc-text" href="mailto:ralstonj@whitman.edu">ralstonj@whitman.edu</a>, <a class="wc-text" href="a/61315">Curriculum Vitae</a>, <a class="wc-box-button solid wc-bb-more-link" href="/academics/majors-and-minors/economics/jason-ralston" title="More Information">
#         More Information</a>, <a class="wc-text" href="mailto:hassenms@whitman.edu">hassenms@whitman.edu</a>, <a class="wc-box-button solid wc-bb-more-link" href="/academics/majors-and-minors/economics/sied-hassen-mohamed" title="More Information">
#         More Information</a>, <a class="wc-text" href="mailto:parcells@whitman.edu">parcells@whitman.edu</a>, <a class="wc-text" href="http://people.whitman.edu/~parcells">Pete's Personal Website</a>, <a class="wc-box-button solid wc-bb-more-link" href="/academics/majors-and-minors/economics/r-pete-parcells" title="More Information">
#         More Information</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="About - Contact Us &amp; Building Hours" href="/about/contact-us" title="Contact Us &amp; Building Hours">
#         Contact Us &amp; Building Hours</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="About - Interactive Map" href="/campus-map" title="Interactive Map">
#         Interactive Map</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="About - Leadership and Organization" href="/about/leadership-and-organization" title="Leadership and Organization">
#         Leadership and Organization</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="About - Mission, Constitution and Bylaws" href="/about/mission-constitution-and-bylaws" title="Mission, Constitution and Bylaws">
#         Mission, Constitution and Bylaws</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="About - Newsroom" href="/newsroom" title="Newsroom">
#         Newsroom</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="About - Our Campus" href="/about/our-campus" title="Our Campus">
#         Our Campus</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="About - Our Community" href="/about/our-community" title="Our Community">
#         Our Community</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="About - Office of the President" href="/president" title="Office of the President">
#         Office of the President</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="About - Rankings and Top Lists" href="/about/rankings" title="Rankings and Top Lists">
#         Rankings and Top Lists</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="About - Strategic Planning" href="/president/strategic-planning" title="Strategic Planning">
#         Strategic Planning</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Academic Calendar" href="/academics/academic-calendar" title="Academic Calendar">
#         Academic Calendar</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Academic Resource Center" href="/academics/academic-resource-center" title="Academic Resource Center">
#         Academic Resource Center</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Academic Theme" href="/academics/academic-theme" title="Academic Theme">
#         Academic Theme</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Careers, Professions and the Liberal Arts" href="/academics/careers-professions-and-the-liberal-arts" title="Careers, Professions and the Liberal Arts">
#         Careers, Professions and the Liberal Arts</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Catalog" href="/academics/catalog" title="Catalog">
#         Catalog</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Center for Global Studies" href="/academics/center-for-global-studies" title="Center for Global Studies">
#         Center for Global Studies</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Community Outreach" href="/academics/community-outreach" title="Community Outreach">
#         Community Outreach</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Fellowships and Grants" href="/after-whitman/fellowships-and-grants" title="Fellowships and Grants">
#         Fellowships and Grants</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Honor Societies" href="/academics/honor-societies" title="Honor Societies">
#         Honor Societies</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Majors and Minors" href="/academics/majors-and-minors" title="Majors and Minors">
#         Majors and Minors</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Maxey Museum" href="/academics/maxey-museum" title="Maxey Museum">
#         Maxey Museum</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Off-Campus Studies" href="/off-campus-studies" title="Off-Campus Studies">
#         Off-Campus Studies</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Penrose Library" href="https://library.whitman.edu/" title="Penrose Library">
#         Penrose Library</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Provost and Dean of the Faculty" href="/provost" title="Provost and Dean of the Faculty">
#         Provost and Dean of the Faculty</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Registrar's Office" href="/registrar" title="Registrar's Office">
#         Registrar's Office</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - STEM Hub" href="/academics/stem-hub" title="STEM Hub">
#         STEM Hub</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Whitman's Faculty" href="/academics/the-faculty" title="Whitman's Faculty">
#         Whitman's Faculty</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Academics - Whitman Undergraduate Conference" href="/academics/research/whitman-undergraduate-conference" title="Whitman Undergraduate Conference">
#         Whitman Undergraduate Conference</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Applying to Whitman" href="/admission-and-aid/applying-to-whitman" title="Applying to Whitman">
#         Applying to Whitman</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Welcome Class of 2027" href="/admission-and-aid/class-of-2027" title="Welcome Class of 2027">
#         Welcome Class of 2027</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Admission &amp; Financial Aid Contacts" href="/admission-and-aid/contact-us" title="Admission &amp; Financial Aid Contacts">
#         Admission &amp; Financial Aid Contacts</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Early Decision" href="/admission-and-aid/applying-to-whitman/early-decision" title="Early Decision">
#         Early Decision</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Early Financial Aid Guarantee" href="/admission-and-aid/early-financial-aid-guarantee" title="Early Financial Aid Guarantee">
#         Early Financial Aid Guarantee</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Financial Aid &amp; Costs" href="/admission-and-aid/financial-aid-and-costs" title="Financial Aid &amp; Costs">
#         Financial Aid &amp; Costs</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Learn More About Whitman" href="/admission-and-aid/learn-more-about-whitman" title="Learn More About Whitman">
#         Learn More About Whitman</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Merit and Talent Awards" href="/admission-and-aid/financial-aid-and-costs/merit-and-talent-awards" title="Merit and Talent Awards">
#         Merit and Talent Awards</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Request Information" href="/admission-and-aid/request-information" title="Request Information">
#         Request Information</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Virtual Tours" href="/admission-and-aid/virtual-tours" title="Virtual Tours">
#         Virtual Tours</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Visiting Whitman College" href="/admission-and-aid/visit-whitman" title="Visiting Whitman College">
#         Visiting Whitman College</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Whitman on the Road" href="/admission-and-aid/whitman-on-the-road" title="Whitman on the Road">
#         Whitman on the Road</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Admission &amp; Aid - Why Whitman?" href="/admission-and-aid/why-whitman" title="Why Whitman?">
#         Why Whitman?</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Career and Community Engagement Center" href="/after-whitman/career-and-community-engagement-center" title="Career and Community Engagement Center">
#         Career and Community Engagement Center</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Diversity &amp; Inclusion" href="/campus-life/diversity-and-inclusion" title="Diversity &amp; Inclusion">
#         Diversity &amp; Inclusion</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - International Student &amp; Scholar Services" href="/campus-life/international-student-and-scholar-services" title="International Student &amp; Scholar Services">
#         International Student &amp; Scholar Services</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - New Student Orientation" href="/campus-life/orientation" title="New Student Orientation">
#         New Student Orientation</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Outdoor Program" href="/campus-life/outdoor-program" title="Outdoor Program">
#         Outdoor Program</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Pathways Leadership Program" href="/campus-life/pathways-leadership-program" title="Pathways Leadership Program">
#         Pathways Leadership Program</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Reid Campus Center" href="/campus-life/reid-campus-center" title="Reid Campus Center">
#         Reid Campus Center</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Residence Life" href="/campus-life/residence-life" title="Residence Life">
#         Residence Life</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Sorority &amp; Fraternity Life" href="/campus-life/sorority-and-fraternity-life" title="Sorority &amp; Fraternity Life">
#         Sorority &amp; Fraternity Life</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Student Activities" href="/campus-life/student-activities" title="Student Activities">
#         Student Activities</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Student Affairs" href="/dean-of-students/student-affairs" title="Student Affairs">
#         Student Affairs</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Student Employment" href="/campus-life/student-employment" title="Student Employment">
#         Student Employment</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Sustainability" href="/campus-life/sustainability" title="Sustainability">
#         Sustainability</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - Virtual Campus" href="/campus-life/student-activities/virtual-campus" title="Virtual Campus">
#         Virtual Campus</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Campus Life - WhitLife" href="https://whitman.presence.io/" title="WhitLife">
#         WhitLife</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - A to Z Index" href="/a-to-z-index" title="A to Z Index">
#         A to Z Index</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Bias Reporting" href="https://whitman-advocate.symplicity.com/public_report/index.php" title="Bias Reporting">
#         Bias Reporting</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Bookstore" href="http://bookstore.whitman.edu/home.aspx" title="Bookstore">
#         Bookstore</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Campus Map" href="/campus-map" title="Campus Map">
#         Campus Map</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - CARE Team" href="/dean-of-students/care-team" title="CARE Team">
#         CARE Team</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Career Services" href="/after-whitman/career-and-community-engagement-center/job-and-career-resources" title="Career Services">
#         Career Services</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Communications" href="/communications" title="Communications">
#         Communications</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Employment Opportunities" href="/human-resources" title="Employment Opportunities">
#         Employment Opportunities</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Giving" href="/giving" title="Giving">
#         Giving</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Grievance Policy" href="/human-resources/grievance-policy" title="Grievance Policy">
#         Grievance Policy</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Newsroom" href="/newsroom" title="Newsroom">
#         Newsroom</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Nondiscrimination Policy" href="/campus-life/diversity-and-inclusion/nondiscrimination-policy" title="Nondiscrimination Policy">
#         Nondiscrimination Policy</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Penrose Library" href="https://library.whitman.edu/" title="Penrose Library">
#         Penrose Library</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Right to Know" href="/dean-of-students/right-to-know" title="Right to Know">
#         Right to Know</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Sexual Misconduct &amp; Title IX" href="/campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct" title="Sexual Misconduct &amp; Title IX">
#         Sexual Misconduct &amp; Title IX</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Social Media " href="/communications/social-media" title="Social Media ">
#         Social Media </a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - The Center for Writing and Speaking (COWS)" href="/academics/the-center-for-writing-and-speaking" title="The Center for Writing and Speaking (COWS)">
#         The Center for Writing and Speaking (COWS)</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Website Privacy Policy" href="/website-privacy-policy" title="Website Privacy Policy">
#         Website Privacy Policy</a>, <a data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Quick Links - Welty Student Health Center" href="/welty-student-health-center" title="Welty Student Health Center">
#         Welty Student Health Center</a>, <a class="wc-street-address" href="https://www.google.com/maps/place/Whitman+College/@46.0717833,-118.3304355,16z/data=!4m2!3m1!1s0x0000000000000000:0x8704a8d5077eb801" target="_blank">
# <svg aria-hidden="true" class="" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-map-pin"></use>
# </svg>
# <span class="wc-text">
# <span itemprop="streetAddress">345 Boyer Ave. </span>
# <span><span itemprop="addressLocality">Walla Walla</span>, <span itemprop="addressRegion">WA</span> <span itemprop="postalCode">99362</span></span>
# </span>
# </a>, <a aria-label="Whitman College Facebook Page" class="wc-social-link" href="https://facebook.com/whitmancollege" target="_blank" title="Whitman College Facebook Page">
# <span class="visually-hidden">visually-hidden text</span>
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-facebook"></use>
# </svg>
# </a>, <a aria-label="Whitman College Twitter Page" class="wc-social-link" href="https://twitter.com/whitmancollege" target="_blank" title="Whitman College Twitter Page">
# <span class="visually-hidden">visually-hidden text</span>
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-twitter"></use>
# </svg>
# </a>, <a aria-label="Whitman College Instagram Page" class="wc-social-link" href="https://instagram.com/whitmancollege" target="_blank" title="Whitman College Instagram Page">
# <span class="visually-hidden">visually-hidden text</span>
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-instagram"></use>
# </svg>
# </a>, <a aria-label="Whitman College YouTube Page" class="wc-social-link" href="https://youtube.com/whitmancollege" target="_blank" title="Whitman College YouTube Page">
# <span class="visually-hidden">visually-hidden text</span>
# <svg aria-hidden="true" class="wc-icon" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-youtube"></use>
# </svg>
# </a>, <a aria-label="Social Media at Whitman" class="wc-more-social-links" data-tracking-action="Click" data-tracking-category="Footer Link" data-tracking-label="Social Media at Whitman" href="communications/social-media/social-media-links" title="Social Media at Whitman">
# <svg aria-hidden="true" class="" viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-right"></use>
# </svg>
# </a>]

# %% [markdown]
# #### We can use .text() or .get() to extract information from a tag

# %%
# Print the text of the links (a tags)
for l in links:
    print(l.text)
# Out:
# Skip to main content
#
#
#
#
#
#
#
#
#
#         Apply
#
#         Alumni
#
#         Diversity
#
#         Library
#
#         MyWhitman
#
#         Families
#
#         Make A Gift
#
#         Bias Reporting
#
#         Bookstore
#
#         CARE Team
#
#         Career Services
#
#         Communications
#
#         Employment Opportunities
#
#         Giving
#
#         Grievance Policy
#
#         Newsroom
#
#         Nondiscrimination Policy
#
#         Right to Know
#
#         Sexual Misconduct & Title IX
#
#         Social Media
#
#         The Center for Writing and Speaking (COWS)
#
#         Website Privacy Policy
#
#         Welty Student Health Center
#
#
#
#
#
# 											A to Z Index
#
#
#
#
#
#
#
#
# 											Map
#
#
#
#
#
#
#
#
# 											Events Calendar
#
#
#
#
#
#
#
#
# 											Penrose Library
#
#
#
#
#
#
#
#
# 											myWhitman
#
#
#
#
#
#
#
#
#
#
# 												A to Z
#
#
#
#
#
#
#
#
# 												Map
#
#
#
#
#
#
#
#
# 												Events
#
#
#
#
#
#
#
#
# 												Library
#
#
#
#
#
#
#
#
# 												myWhitman
#
#
#
#
#
# About
#
#         Contact Us & Building Hours
#
#         Interactive Map
#
#         Leadership and Organization
#
#         Mission, Constitution and Bylaws
#
#         Newsroom
#
#         Office of the President
#
#         Our Campus
#
#         Our Community
#
#         Rankings and Top Lists
#
#         Strategic Planning
# Academics
#
#         Academic Calendar
#
#         Academic Resource Center
#
#         Academic Theme
#
#         Careers, Professions and the Liberal Arts
#
#         Catalog
#
#         Center for Global Studies
#
#         Community Outreach
#
#         Fellowships and Grants
#
#         Honor Societies
#
#         Majors and Minors
#
#         Maxey Museum
#
#         Off-Campus Studies
#
#         Penrose Library
#
#         Provost and Dean of the Faculty
#
#         Registrar's Office
#
#         STEM Hub
#
#         Whitman Undergraduate Conference
#
#         Whitman's Faculty
#
#
#
#         Fellowships and Grants
# Admission & Aid
#
#         Admission & Financial Aid Contacts
#
#         Applying to Whitman
#
#         Early Decision
#
#         Early Financial Aid Guarantee
#
#         Financial Aid & Costs
#
#         Learn More About Whitman
#
#         Merit and Talent Awards
#
#         Request Information
#
#         Virtual Tours
#
#         Visiting Whitman College
#
#         Welcome Class of 2027
#
#         Whitman on the Road
#
#         Why Whitman?
#
#
#
#         Visit Whitman
# After Whitman
#
#         Career and Community Engagement Center
#
#         Careers, Professions and the Liberal Arts
#
#         Fellowships and Grants
#
#         Graduate Schools and Pre-Professional Programs
#
#         Internships
#
#         Life After Whitman Stories
#
#         Whitman Undergraduate Conference
#
#         Whitties Helping Whitties
# Athletics
#
#         Athletic Facility Hours
#
#         Club Sports
#
#         Intramural Sports
#
#         Sports Studies, Recreation and Athletics
#
#         Varsity Athletics
#
#         W Club
#
#
#
#         Varsity Athletics Calendar
# Campus Life
#
#         Career and Community Engagement Center
#
#         Diversity & Inclusion
#
#         International Student & Scholar Services
#
#         New Student Orientation
#
#         Outdoor Program
#
#         Pathways Leadership Program
#
#         Reid Campus Center
#
#         Residence Life
#
#         Sorority & Fraternity Life
#
#         Student Activities
#
#         Student Affairs
#
#         Student Employment
#
#         Sustainability
#
#         Virtual Campus
#
#         WhitLife
#
#         Apply
#
#         Alumni
#
#         Diversity
#
#         Library
#
#         MyWhitman
#
#         Families
#
#         Bias Reporting
#
#         Bookstore
#
#         CARE Team
#
#         Career Services
#
#         Communications
#
#         Employment Opportunities
#
#         Giving
#
#         Grievance Policy
#
#         Newsroom
#
#         Nondiscrimination Policy
#
#         Right to Know
#
#         Sexual Misconduct & Title IX
#
#         Social Media
#
#         The Center for Writing and Speaking (COWS)
#
#         Website Privacy Policy
#
#         Welty Student Health Center
# Site
# People
#
#
#
#
#
#
#         Academics
#
#         Majors and Minors
#
#         Economics
#
#
#
#
#
# / ... /
#
#         Academics
#
#         Majors and Minors
#
#         Economics
#
#         Economics
#
# Department Highlights
#
#
# Economics Major Programs
#
#
# Courses and Requirements
#
#
# Learning Goals
#
#
# Senior Assessment
#
#
# Department Honors
#
#
# Economics - Environmental Studies
#
#
# Economics - Mathematics
#
#
# Economics Lectureships
#
#
# Whitman Investment Company
#
#
#
#
# Working Paper Series
#
#
# Editors
#
#
# Submission Guidelines
#
#
# Contents
#
#
# After Whitman
#
#
# Links
#
#
#         Course Catalog
#
#         Economics - Environmental Studies
#
#         Economics - Mathematics
#
#         Off-Campus Studies
# hazlett@whitman.edu
# Curriculum Vitae
#
#         More Information
# belayh@whitman.edu
# Halefom's Personal Website
#
#         More Information
# crouter@whitman.edu
# Curriculum Vitae
#
#         More Information
# hanr@whitman.edu
#
#         More Information
# sai@whitman.edu
# Curriculum Vitae
#
#         More Information
# manicm@whitman.edu
# Curriculum Vitae
#
#         More Information
# muellerm@whitman.edu
# Curriculum Vitae
#
#         More Information
# ralstonj@whitman.edu
# Curriculum Vitae
#
#         More Information
# hassenms@whitman.edu
#
#         More Information
# parcells@whitman.edu
# Pete's Personal Website
#
#         More Information
#
#         Contact Us & Building Hours
#
#         Interactive Map
#
#         Leadership and Organization
#
#         Mission, Constitution and Bylaws
#
#         Newsroom
#
#         Our Campus
#
#         Our Community
#
#         Office of the President
#
#         Rankings and Top Lists
#
#         Strategic Planning
#
#         Academic Calendar
#
#         Academic Resource Center
#
#         Academic Theme
#
#         Careers, Professions and the Liberal Arts
#
#         Catalog
#
#         Center for Global Studies
#
#         Community Outreach
#
#         Fellowships and Grants
#
#         Honor Societies
#
#         Majors and Minors
#
#         Maxey Museum
#
#         Off-Campus Studies
#
#         Penrose Library
#
#         Provost and Dean of the Faculty
#
#         Registrar's Office
#
#         STEM Hub
#
#         Whitman's Faculty
#
#         Whitman Undergraduate Conference
#
#         Applying to Whitman
#
#         Welcome Class of 2027
#
#         Admission & Financial Aid Contacts
#
#         Early Decision
#
#         Early Financial Aid Guarantee
#
#         Financial Aid & Costs
#
#         Learn More About Whitman
#
#         Merit and Talent Awards
#
#         Request Information
#
#         Virtual Tours
#
#         Visiting Whitman College
#
#         Whitman on the Road
#
#         Why Whitman?
#
#         Career and Community Engagement Center
#
#         Diversity & Inclusion
#
#         International Student & Scholar Services
#
#         New Student Orientation
#
#         Outdoor Program
#
#         Pathways Leadership Program
#
#         Reid Campus Center
#
#         Residence Life
#
#         Sorority & Fraternity Life
#
#         Student Activities
#
#         Student Affairs
#
#         Student Employment
#
#         Sustainability
#
#         Virtual Campus
#
#         WhitLife
#
#         A to Z Index
#
#         Bias Reporting
#
#         Bookstore
#
#         Campus Map
#
#         CARE Team
#
#         Career Services
#
#         Communications
#
#         Employment Opportunities
#
#         Giving
#
#         Grievance Policy
#
#         Newsroom
#
#         Nondiscrimination Policy
#
#         Penrose Library
#
#         Right to Know
#
#         Sexual Misconduct & Title IX
#
#         Social Media
#
#         The Center for Writing and Speaking (COWS)
#
#         Website Privacy Policy
#
#         Welty Student Health Center
#
#
#
#
#
# 345 Boyer Ave.
# Walla Walla, WA 99362
#
#
#
# visually-hidden text
#
#
#
#
#
# visually-hidden text
#
#
#
#
#
# visually-hidden text
#
#
#
#
#
# visually-hidden text

# %%
# Get the URL of an a tag using .get('href')
for l in links:
    print(l.get('href'))
# Out:
# /academics/majors-and-minors/economics/faculty#wc-reader-content
# /
# /admission-and-aid/applying-to-whitman
# /alumni
# /campus-life/diversity-and-inclusion
# https://library.whitman.edu/
# https://my.whitman.edu/
# /families
# https://www.givecampus.com/campaigns/7878/donations/new
# https://whitman-advocate.symplicity.com/public_report/index.php
# http://bookstore.whitman.edu/home.aspx
# /dean-of-students/care-team
# /after-whitman/career-and-community-engagement-center/job-and-career-resources
# /communications
# /human-resources
# /giving
# /human-resources/grievance-policy
# /newsroom
# /campus-life/diversity-and-inclusion/nondiscrimination-policy
# /dean-of-students/right-to-know
# /campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct
# /communications/social-media
# /academics/the-center-for-writing-and-speaking
# /website-privacy-policy
# /welty-student-health-center
# a-to-z-index
# campus-map
# http://calendar.whitman.edu
# https://library.whitman.edu/
# https://my.whitman.edu
# a-to-z-index
# campus-map
# http://calendar.whitman.edu
# https://library.whitman.edu/
# https://my.whitman.edu
# about
# /about/contact-us
# /campus-map
# /about/leadership-and-organization
# /about/mission-constitution-and-bylaws
# /newsroom
# /president
# /about/our-campus
# /about/our-community
# /about/rankings
# /president/strategic-planning
# academics
# /academics/academic-calendar
# /academics/academic-resource-center
# /academics/academic-theme
# /academics/careers-professions-and-the-liberal-arts
# /academics/catalog
# /academics/center-for-global-studies
# /academics/community-outreach
# /after-whitman/fellowships-and-grants
# /academics/honor-societies
# /academics/majors-and-minors
# /academics/maxey-museum
# /off-campus-studies
# https://library.whitman.edu/
# /provost
# /registrar
# /academics/stem-hub
# /academics/research/whitman-undergraduate-conference
# /academics/the-faculty
# /after-whitman/fellowships-and-grants
# /after-whitman/fellowships-and-grants
# admission-and-aid
# /admission-and-aid/contact-us
# /admission-and-aid/applying-to-whitman
# /admission-and-aid/applying-to-whitman/early-decision
# /admission-and-aid/early-financial-aid-guarantee
# /admission-and-aid/financial-aid-and-costs
# /admission-and-aid/learn-more-about-whitman
# /admission-and-aid/financial-aid-and-costs/merit-and-talent-awards
# /admission-and-aid/request-information
# /admission-and-aid/virtual-tours
# /admission-and-aid/visit-whitman
# /admission-and-aid/class-of-2027
# /admission-and-aid/whitman-on-the-road
# /admission-and-aid/why-whitman
# /admission-and-aid/visit-whitman
# /admission-and-aid/visit-whitman
# after-whitman
# /after-whitman/career-and-community-engagement-center
# /academics/careers-professions-and-the-liberal-arts
# /after-whitman/fellowships-and-grants
# /after-whitman/graduate-schools-and-pre-professional-programs
# /after-whitman/career-and-community-engagement-center/internships
# /after-whitman/life-after-whitman-stories
# /academics/research/whitman-undergraduate-conference
# /after-whitman/whitties-helping-whitties
# athletics
# https://athletics.whitman.edu/news/2020/10/6/general-student-access-to-buildings-or-other-campus-resources.aspx
# /athletics/club-sports
# /athletics/intramural-sports
# /academics/majors-and-minors/sports-studies-recreation-and-athletics
# http://athletics.whitman.edu/
# https://athletics.whitman.edu/news/2020/11/30/general-join-the-w-club.aspx
# http://athletics2.whitman.edu/calendar.aspx
# http://athletics2.whitman.edu/calendar.aspx
# campus-life
# /after-whitman/career-and-community-engagement-center
# /campus-life/diversity-and-inclusion
# /campus-life/international-student-and-scholar-services
# /campus-life/orientation
# /campus-life/outdoor-program
# /campus-life/pathways-leadership-program
# /campus-life/reid-campus-center
# /campus-life/residence-life
# /campus-life/sorority-and-fraternity-life
# /campus-life/student-activities
# /dean-of-students/student-affairs
# /campus-life/student-employment
# /campus-life/sustainability
# /campus-life/student-activities/virtual-campus
# https://whitman.presence.io/
# /admission-and-aid/applying-to-whitman
# /alumni
# /campus-life/diversity-and-inclusion
# https://library.whitman.edu/
# https://my.whitman.edu/
# /families
# https://whitman-advocate.symplicity.com/public_report/index.php
# http://bookstore.whitman.edu/home.aspx
# /dean-of-students/care-team
# /after-whitman/career-and-community-engagement-center/job-and-career-resources
# /communications
# /human-resources
# /giving
# /human-resources/grievance-policy
# /newsroom
# /campus-life/diversity-and-inclusion/nondiscrimination-policy
# /dean-of-students/right-to-know
# /campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct
# /communications/social-media
# /academics/the-center-for-writing-and-speaking
# /website-privacy-policy
# /welty-student-health-center
# None
# None
#
# /academics
# /academics/majors-and-minors
# /academics/majors-and-minors/economics
#
# None
# None
# /academics
# /academics/majors-and-minors
# /academics/majors-and-minors/economics
# /academics/majors-and-minors/economics
# /academics/majors-and-minors/economics/department-highlights
# /academics/majors-and-minors/economics/economics-major-programs
# /documents/Offices/Registrar/Catalog/Economics.pdf
# /academics/majors-and-minors/economics/economics-major-programs/learning-goals
# /academics/majors-and-minors/economics/economics-major-programs/economics-senior-assessment
# /academics/majors-and-minors/economics/economics-major-programs/department-honors
# /academics/majors-and-minors/environmental-studies/environmental-studies-major/economics-environmental-studies
# /academics/majors-and-minors/interdisciplinary-majors/economics-mathematics
# /academics/majors-and-minors/economics/economics-lectureships
# https://whitmanwic.blog/
# /academics/majors-and-minors/economics/working-paper-series
# /academics/majors-and-minors/economics/working-paper-series/editors
# /academics/majors-and-minors/economics/working-paper-series/submission-guidelines
# /academics/majors-and-minors/economics/working-paper-series/contents
# /academics/majors-and-minors/economics/economics-after-whitman
# /academics/majors-and-minors/economics/links
# /documents/Offices/Registrar/Catalog/Economics.pdf
# /academics/majors-and-minors/interdisciplinary-majors/economics-environmental-studies
# /academics/majors-and-minors/interdisciplinary-majors/economics-mathematics
# /off-campus-studies/advising-by-major/economics
# mailto:hazlett@whitman.edu
# a/64306
# /academics/majors-and-minors/economics/denise-hazlett
# mailto:belayh@whitman.edu
# http://people.whitman.edu/~belayh/
# /academics/majors-and-minors/economics/halefom-belay
# mailto:crouter@whitman.edu
# a/19960
# /academics/majors-and-minors/economics/jan-crouter
# mailto:hanr@whitman.edu
# /academics/majors-and-minors/economics/ruoning-han
# mailto:sai@whitman.edu
# a/61325
# /academics/majors-and-minors/economics/sai-madhurika-mamunuru
# mailto:manicm@whitman.edu
# https://drive.google.com/open?id=1cmfp-RDeD-okE1qA-KDiURC88SrczvNC
# /academics/majors-and-minors/economics/marian-manic
# mailto:muellerm@whitman.edu
# https://www.rosiemueller.com/
# /academics/majors-and-minors/economics/rosie-mueller
# mailto:ralstonj@whitman.edu
# a/61315
# /academics/majors-and-minors/economics/jason-ralston
# mailto:hassenms@whitman.edu
# /academics/majors-and-minors/economics/sied-hassen-mohamed
# mailto:parcells@whitman.edu
# http://people.whitman.edu/~parcells
# /academics/majors-and-minors/economics/r-pete-parcells
# /about/contact-us
# /campus-map
# /about/leadership-and-organization
# /about/mission-constitution-and-bylaws
# /newsroom
# /about/our-campus
# /about/our-community
# /president
# /about/rankings
# /president/strategic-planning
# /academics/academic-calendar
# /academics/academic-resource-center
# /academics/academic-theme
# /academics/careers-professions-and-the-liberal-arts
# /academics/catalog
# /academics/center-for-global-studies
# /academics/community-outreach
# /after-whitman/fellowships-and-grants
# /academics/honor-societies
# /academics/majors-and-minors
# /academics/maxey-museum
# /off-campus-studies
# https://library.whitman.edu/
# /provost
# /registrar
# /academics/stem-hub
# /academics/the-faculty
# /academics/research/whitman-undergraduate-conference
# /admission-and-aid/applying-to-whitman
# /admission-and-aid/class-of-2027
# /admission-and-aid/contact-us
# /admission-and-aid/applying-to-whitman/early-decision
# /admission-and-aid/early-financial-aid-guarantee
# /admission-and-aid/financial-aid-and-costs
# /admission-and-aid/learn-more-about-whitman
# /admission-and-aid/financial-aid-and-costs/merit-and-talent-awards
# /admission-and-aid/request-information
# /admission-and-aid/virtual-tours
# /admission-and-aid/visit-whitman
# /admission-and-aid/whitman-on-the-road
# /admission-and-aid/why-whitman
# /after-whitman/career-and-community-engagement-center
# /campus-life/diversity-and-inclusion
# /campus-life/international-student-and-scholar-services
# /campus-life/orientation
# /campus-life/outdoor-program
# /campus-life/pathways-leadership-program
# /campus-life/reid-campus-center
# /campus-life/residence-life
# /campus-life/sorority-and-fraternity-life
# /campus-life/student-activities
# /dean-of-students/student-affairs
# /campus-life/student-employment
# /campus-life/sustainability
# /campus-life/student-activities/virtual-campus
# https://whitman.presence.io/
# /a-to-z-index
# https://whitman-advocate.symplicity.com/public_report/index.php
# http://bookstore.whitman.edu/home.aspx
# /campus-map
# /dean-of-students/care-team
# /after-whitman/career-and-community-engagement-center/job-and-career-resources
# /communications
# /human-resources
# /giving
# /human-resources/grievance-policy
# /newsroom
# /campus-life/diversity-and-inclusion/nondiscrimination-policy
# https://library.whitman.edu/
# /dean-of-students/right-to-know
# /campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct
# /communications/social-media
# /academics/the-center-for-writing-and-speaking
# /website-privacy-policy
# /welty-student-health-center
# https://www.google.com/maps/place/Whitman+College/@46.0717833,-118.3304355,16z/data=!4m2!3m1!1s0x0000000000000000:0x8704a8d5077eb801
# https://facebook.com/whitmancollege
# https://twitter.com/whitmancollege
# https://instagram.com/whitmancollege
# https://youtube.com/whitmancollege
# communications/social-media/social-media-links

# %% [markdown]
# What do you notice about the URLs above? Can you paste them all into a web browser? Can you use .requests() to get their HTML?
#
# No!
#
# Some of these are _relative_ links.
#
# How would we turn them all into URLs of the format:
# "https://whitman.edu/stuff"?

# %% [markdown]
# ### Challenge: Take the list of links and use it to make a list of URLs in the format above

# %%
# YOUR CODE HERE



# Don't peek at the code below if you want to try on your own


# Hints: 
# Skip the ones that are empty or that are in the form of 'mailto'
# Think about the different cases, for example:
# /alumni
# http://bookstore.whitman.edu/home.aspx
# about

# %%
# One potential solution:

# This code turns all of the links into a list of URLs that we could follow:

# Create an empty list
list_of_URLs = []

# Iterate through all of the links
for l in links:
    
    # we want to ignore the ones that are empty or are 'mailto' links
    if (l.get('href') == None) or (l.get('href') == "") or ('mailto' in l.get('href')):
        pass
    
    # these are the cases where they start with http
    elif "http" in l.get('href'):
        
        # append the link as is
        list_of_URLs.append(l.get('href'))
    
    # these are the cases where the href starts with "/"
    elif l.get('href')[0] == "/":
        list_of_URLs.append("https://whitman.edu" + l.get('href'))
    
    # these are the cases where the href doesn't start with '/'
    else:
        list_of_URLs.append("https://whitman.edu/" + l.get('href'))

# %%
list_of_URLs
# Out:
# ['https://whitman.edu/academics/majors-and-minors/economics/faculty#wc-reader-content',
#  'https://whitman.edu/',
#  'https://whitman.edu/admission-and-aid/applying-to-whitman',
#  'https://whitman.edu/alumni',
#  'https://whitman.edu/campus-life/diversity-and-inclusion',
#  'https://library.whitman.edu/',
#  'https://my.whitman.edu/',
#  'https://whitman.edu/families',
#  'https://www.givecampus.com/campaigns/7878/donations/new',
#  'https://whitman-advocate.symplicity.com/public_report/index.php',
#  'http://bookstore.whitman.edu/home.aspx',
#  'https://whitman.edu/dean-of-students/care-team',
#  'https://whitman.edu/after-whitman/career-and-community-engagement-center/job-and-career-resources',
#  'https://whitman.edu/communications',
#  'https://whitman.edu/human-resources',
#  'https://whitman.edu/giving',
#  'https://whitman.edu/human-resources/grievance-policy',
#  'https://whitman.edu/newsroom',
#  'https://whitman.edu/campus-life/diversity-and-inclusion/nondiscrimination-policy',
#  'https://whitman.edu/dean-of-students/right-to-know',
#  'https://whitman.edu/campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct',
#  'https://whitman.edu/communications/social-media',
#  'https://whitman.edu/academics/the-center-for-writing-and-speaking',
#  'https://whitman.edu/website-privacy-policy',
#  'https://whitman.edu/welty-student-health-center',
#  'https://whitman.edu/a-to-z-index',
#  'https://whitman.edu/campus-map',
#  'http://calendar.whitman.edu',
#  'https://library.whitman.edu/',
#  'https://my.whitman.edu',
#  'https://whitman.edu/a-to-z-index',
#  'https://whitman.edu/campus-map',
#  'http://calendar.whitman.edu',
#  'https://library.whitman.edu/',
#  'https://my.whitman.edu',
#  'https://whitman.edu/about',
#  'https://whitman.edu/about/contact-us',
#  'https://whitman.edu/campus-map',
#  'https://whitman.edu/about/leadership-and-organization',
#  'https://whitman.edu/about/mission-constitution-and-bylaws',
#  'https://whitman.edu/newsroom',
#  'https://whitman.edu/president',
#  'https://whitman.edu/about/our-campus',
#  'https://whitman.edu/about/our-community',
#  'https://whitman.edu/about/rankings',
#  'https://whitman.edu/president/strategic-planning',
#  'https://whitman.edu/academics',
#  'https://whitman.edu/academics/academic-calendar',
#  'https://whitman.edu/academics/academic-resource-center',
#  'https://whitman.edu/academics/academic-theme',
#  'https://whitman.edu/academics/careers-professions-and-the-liberal-arts',
#  'https://whitman.edu/academics/catalog',
#  'https://whitman.edu/academics/center-for-global-studies',
#  'https://whitman.edu/academics/community-outreach',
#  'https://whitman.edu/after-whitman/fellowships-and-grants',
#  'https://whitman.edu/academics/honor-societies',
#  'https://whitman.edu/academics/majors-and-minors',
#  'https://whitman.edu/academics/maxey-museum',
#  'https://whitman.edu/off-campus-studies',
#  'https://library.whitman.edu/',
#  'https://whitman.edu/provost',
#  'https://whitman.edu/registrar',
#  'https://whitman.edu/academics/stem-hub',
#  'https://whitman.edu/academics/research/whitman-undergraduate-conference',
#  'https://whitman.edu/academics/the-faculty',
#  'https://whitman.edu/after-whitman/fellowships-and-grants',
#  'https://whitman.edu/after-whitman/fellowships-and-grants',
#  'https://whitman.edu/admission-and-aid',
#  'https://whitman.edu/admission-and-aid/contact-us',
#  'https://whitman.edu/admission-and-aid/applying-to-whitman',
#  'https://whitman.edu/admission-and-aid/applying-to-whitman/early-decision',
#  'https://whitman.edu/admission-and-aid/early-financial-aid-guarantee',
#  'https://whitman.edu/admission-and-aid/financial-aid-and-costs',
#  'https://whitman.edu/admission-and-aid/learn-more-about-whitman',
#  'https://whitman.edu/admission-and-aid/financial-aid-and-costs/merit-and-talent-awards',
#  'https://whitman.edu/admission-and-aid/request-information',
#  'https://whitman.edu/admission-and-aid/virtual-tours',
#  'https://whitman.edu/admission-and-aid/visit-whitman',
#  'https://whitman.edu/admission-and-aid/class-of-2027',
#  'https://whitman.edu/admission-and-aid/whitman-on-the-road',
#  'https://whitman.edu/admission-and-aid/why-whitman',
#  'https://whitman.edu/admission-and-aid/visit-whitman',
#  'https://whitman.edu/admission-and-aid/visit-whitman',
#  'https://whitman.edu/after-whitman',
#  'https://whitman.edu/after-whitman/career-and-community-engagement-center',
#  'https://whitman.edu/academics/careers-professions-and-the-liberal-arts',
#  'https://whitman.edu/after-whitman/fellowships-and-grants',
#  'https://whitman.edu/after-whitman/graduate-schools-and-pre-professional-programs',
#  'https://whitman.edu/after-whitman/career-and-community-engagement-center/internships',
#  'https://whitman.edu/after-whitman/life-after-whitman-stories',
#  'https://whitman.edu/academics/research/whitman-undergraduate-conference',
#  'https://whitman.edu/after-whitman/whitties-helping-whitties',
#  'https://whitman.edu/athletics',
#  'https://athletics.whitman.edu/news/2020/10/6/general-student-access-to-buildings-or-other-campus-resources.aspx',
#  'https://whitman.edu/athletics/club-sports',
#  'https://whitman.edu/athletics/intramural-sports',
#  'https://whitman.edu/academics/majors-and-minors/sports-studies-recreation-and-athletics',
#  'http://athletics.whitman.edu/',
#  'https://athletics.whitman.edu/news/2020/11/30/general-join-the-w-club.aspx',
#  'http://athletics2.whitman.edu/calendar.aspx',
#  'http://athletics2.whitman.edu/calendar.aspx',
#  'https://whitman.edu/campus-life',
#  'https://whitman.edu/after-whitman/career-and-community-engagement-center',
#  'https://whitman.edu/campus-life/diversity-and-inclusion',
#  'https://whitman.edu/campus-life/international-student-and-scholar-services',
#  'https://whitman.edu/campus-life/orientation',
#  'https://whitman.edu/campus-life/outdoor-program',
#  'https://whitman.edu/campus-life/pathways-leadership-program',
#  'https://whitman.edu/campus-life/reid-campus-center',
#  'https://whitman.edu/campus-life/residence-life',
#  'https://whitman.edu/campus-life/sorority-and-fraternity-life',
#  'https://whitman.edu/campus-life/student-activities',
#  'https://whitman.edu/dean-of-students/student-affairs',
#  'https://whitman.edu/campus-life/student-employment',
#  'https://whitman.edu/campus-life/sustainability',
#  'https://whitman.edu/campus-life/student-activities/virtual-campus',
#  'https://whitman.presence.io/',
#  'https://whitman.edu/admission-and-aid/applying-to-whitman',
#  'https://whitman.edu/alumni',
#  'https://whitman.edu/campus-life/diversity-and-inclusion',
#  'https://library.whitman.edu/',
#  'https://my.whitman.edu/',
#  'https://whitman.edu/families',
#  'https://whitman-advocate.symplicity.com/public_report/index.php',
#  'http://bookstore.whitman.edu/home.aspx',
#  'https://whitman.edu/dean-of-students/care-team',
#  'https://whitman.edu/after-whitman/career-and-community-engagement-center/job-and-career-resources',
#  'https://whitman.edu/communications',
#  'https://whitman.edu/human-resources',
#  'https://whitman.edu/giving',
#  'https://whitman.edu/human-resources/grievance-policy',
#  'https://whitman.edu/newsroom',
#  'https://whitman.edu/campus-life/diversity-and-inclusion/nondiscrimination-policy',
#  'https://whitman.edu/dean-of-students/right-to-know',
#  'https://whitman.edu/campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct',
#  'https://whitman.edu/communications/social-media',
#  'https://whitman.edu/academics/the-center-for-writing-and-speaking',
#  'https://whitman.edu/website-privacy-policy',
#  'https://whitman.edu/welty-student-health-center',
#  'https://whitman.edu/academics',
#  'https://whitman.edu/academics/majors-and-minors',
#  'https://whitman.edu/academics/majors-and-minors/economics',
#  'https://whitman.edu/academics',
#  'https://whitman.edu/academics/majors-and-minors',
#  'https://whitman.edu/academics/majors-and-minors/economics',
#  'https://whitman.edu/academics/majors-and-minors/economics',
#  'https://whitman.edu/academics/majors-and-minors/economics/department-highlights',
#  'https://whitman.edu/academics/majors-and-minors/economics/economics-major-programs',
#  'https://whitman.edu/documents/Offices/Registrar/Catalog/Economics.pdf',
#  'https://whitman.edu/academics/majors-and-minors/economics/economics-major-programs/learning-goals',
#  'https://whitman.edu/academics/majors-and-minors/economics/economics-major-programs/economics-senior-assessment',
#  'https://whitman.edu/academics/majors-and-minors/economics/economics-major-programs/department-honors',
#  'https://whitman.edu/academics/majors-and-minors/environmental-studies/environmental-studies-major/economics-environmental-studies',
#  'https://whitman.edu/academics/majors-and-minors/interdisciplinary-majors/economics-mathematics',
#  'https://whitman.edu/academics/majors-and-minors/economics/economics-lectureships',
#  'https://whitmanwic.blog/',
#  'https://whitman.edu/academics/majors-and-minors/economics/working-paper-series',
#  'https://whitman.edu/academics/majors-and-minors/economics/working-paper-series/editors',
#  'https://whitman.edu/academics/majors-and-minors/economics/working-paper-series/submission-guidelines',
#  'https://whitman.edu/academics/majors-and-minors/economics/working-paper-series/contents',
#  'https://whitman.edu/academics/majors-and-minors/economics/economics-after-whitman',
#  'https://whitman.edu/academics/majors-and-minors/economics/links',
#  'https://whitman.edu/documents/Offices/Registrar/Catalog/Economics.pdf',
#  'https://whitman.edu/academics/majors-and-minors/interdisciplinary-majors/economics-environmental-studies',
#  'https://whitman.edu/academics/majors-and-minors/interdisciplinary-majors/economics-mathematics',
#  'https://whitman.edu/off-campus-studies/advising-by-major/economics',
#  'https://whitman.edu/a/64306',
#  'https://whitman.edu/academics/majors-and-minors/economics/denise-hazlett',
#  'http://people.whitman.edu/~belayh/',
#  'https://whitman.edu/academics/majors-and-minors/economics/halefom-belay',
#  'https://whitman.edu/a/19960',
#  'https://whitman.edu/academics/majors-and-minors/economics/jan-crouter',
#  'https://whitman.edu/academics/majors-and-minors/economics/ruoning-han',
#  'https://whitman.edu/a/61325',
#  'https://whitman.edu/academics/majors-and-minors/economics/sai-madhurika-mamunuru',
#  'https://drive.google.com/open?id=1cmfp-RDeD-okE1qA-KDiURC88SrczvNC',
#  'https://whitman.edu/academics/majors-and-minors/economics/marian-manic',
#  'https://www.rosiemueller.com/',
#  'https://whitman.edu/academics/majors-and-minors/economics/rosie-mueller',
#  'https://whitman.edu/a/61315',
#  'https://whitman.edu/academics/majors-and-minors/economics/jason-ralston',
#  'https://whitman.edu/academics/majors-and-minors/economics/sied-hassen-mohamed',
#  'http://people.whitman.edu/~parcells',
#  'https://whitman.edu/academics/majors-and-minors/economics/r-pete-parcells',
#  'https://whitman.edu/about/contact-us',
#  'https://whitman.edu/campus-map',
#  'https://whitman.edu/about/leadership-and-organization',
#  'https://whitman.edu/about/mission-constitution-and-bylaws',
#  'https://whitman.edu/newsroom',
#  'https://whitman.edu/about/our-campus',
#  'https://whitman.edu/about/our-community',
#  'https://whitman.edu/president',
#  'https://whitman.edu/about/rankings',
#  'https://whitman.edu/president/strategic-planning',
#  'https://whitman.edu/academics/academic-calendar',
#  'https://whitman.edu/academics/academic-resource-center',
#  'https://whitman.edu/academics/academic-theme',
#  'https://whitman.edu/academics/careers-professions-and-the-liberal-arts',
#  'https://whitman.edu/academics/catalog',
#  'https://whitman.edu/academics/center-for-global-studies',
#  'https://whitman.edu/academics/community-outreach',
#  'https://whitman.edu/after-whitman/fellowships-and-grants',
#  'https://whitman.edu/academics/honor-societies',
#  'https://whitman.edu/academics/majors-and-minors',
#  'https://whitman.edu/academics/maxey-museum',
#  'https://whitman.edu/off-campus-studies',
#  'https://library.whitman.edu/',
#  'https://whitman.edu/provost',
#  'https://whitman.edu/registrar',
#  'https://whitman.edu/academics/stem-hub',
#  'https://whitman.edu/academics/the-faculty',
#  'https://whitman.edu/academics/research/whitman-undergraduate-conference',
#  'https://whitman.edu/admission-and-aid/applying-to-whitman',
#  'https://whitman.edu/admission-and-aid/class-of-2027',
#  'https://whitman.edu/admission-and-aid/contact-us',
#  'https://whitman.edu/admission-and-aid/applying-to-whitman/early-decision',
#  'https://whitman.edu/admission-and-aid/early-financial-aid-guarantee',
#  'https://whitman.edu/admission-and-aid/financial-aid-and-costs',
#  'https://whitman.edu/admission-and-aid/learn-more-about-whitman',
#  'https://whitman.edu/admission-and-aid/financial-aid-and-costs/merit-and-talent-awards',
#  'https://whitman.edu/admission-and-aid/request-information',
#  'https://whitman.edu/admission-and-aid/virtual-tours',
#  'https://whitman.edu/admission-and-aid/visit-whitman',
#  'https://whitman.edu/admission-and-aid/whitman-on-the-road',
#  'https://whitman.edu/admission-and-aid/why-whitman',
#  'https://whitman.edu/after-whitman/career-and-community-engagement-center',
#  'https://whitman.edu/campus-life/diversity-and-inclusion',
#  'https://whitman.edu/campus-life/international-student-and-scholar-services',
#  'https://whitman.edu/campus-life/orientation',
#  'https://whitman.edu/campus-life/outdoor-program',
#  'https://whitman.edu/campus-life/pathways-leadership-program',
#  'https://whitman.edu/campus-life/reid-campus-center',
#  'https://whitman.edu/campus-life/residence-life',
#  'https://whitman.edu/campus-life/sorority-and-fraternity-life',
#  'https://whitman.edu/campus-life/student-activities',
#  'https://whitman.edu/dean-of-students/student-affairs',
#  'https://whitman.edu/campus-life/student-employment',
#  'https://whitman.edu/campus-life/sustainability',
#  'https://whitman.edu/campus-life/student-activities/virtual-campus',
#  'https://whitman.presence.io/',
#  'https://whitman.edu/a-to-z-index',
#  'https://whitman-advocate.symplicity.com/public_report/index.php',
#  'http://bookstore.whitman.edu/home.aspx',
#  'https://whitman.edu/campus-map',
#  'https://whitman.edu/dean-of-students/care-team',
#  'https://whitman.edu/after-whitman/career-and-community-engagement-center/job-and-career-resources',
#  'https://whitman.edu/communications',
#  'https://whitman.edu/human-resources',
#  'https://whitman.edu/giving',
#  'https://whitman.edu/human-resources/grievance-policy',
#  'https://whitman.edu/newsroom',
#  'https://whitman.edu/campus-life/diversity-and-inclusion/nondiscrimination-policy',
#  'https://library.whitman.edu/',
#  'https://whitman.edu/dean-of-students/right-to-know',
#  'https://whitman.edu/campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct',
#  'https://whitman.edu/communications/social-media',
#  'https://whitman.edu/academics/the-center-for-writing-and-speaking',
#  'https://whitman.edu/website-privacy-policy',
#  'https://whitman.edu/welty-student-health-center',
#  'https://www.google.com/maps/place/Whitman+College/@46.0717833,-118.3304355,16z/data=!4m2!3m1!1s0x0000000000000000:0x8704a8d5077eb801',
#  'https://facebook.com/whitmancollege',
#  'https://twitter.com/whitmancollege',
#  'https://instagram.com/whitmancollege',
#  'https://youtube.com/whitmancollege',
#  'https://whitman.edu/communications/social-media/social-media-links']

# %% [markdown]
# Why is this useful? We can use them to do more scraping -- we cold programmatically visit every page on the Whitman.edu website this way.
#
# (Side note: This is fundamentally how [web crawlers](https://en.wikipedia.org/wiki/Web_crawler) work -- which are the underlying technology behind search engines!)

# %% [markdown]
# ### Part 3: Targeting our scraping
# We are interested in the Faculty and their information. How would we get that?
#
# First, let's inspect this page in our web browsers and see how the Faculty info is formatted.

# %%
# Start by finding all of the 'h2' tags
soup.find_all('h2')
# Out:
# [<h2 class="wc-off-screen">Section Navigation</h2>,
#  <h2>Academic Requirements</h2>,
#  <h2>Combined Majors</h2>,
#  <h2>Related Links</h2>,
#  <h2 class="wc-profile-name">Denise Hazlett</h2>,
#  <h2 class="wc-profile-name">Halefom Belay</h2>,
#  <h2 class="wc-profile-name">Jan Crouter</h2>,
#  <h2 class="wc-profile-name">Ruoning Han</h2>,
#  <h2 class="wc-profile-name">Sai Madhurika Mamunuru</h2>,
#  <h2 class="wc-profile-name">Marian Manic</h2>,
#  <h2 class="wc-profile-name">Rosie Mueller</h2>,
#  <h2 class="wc-profile-name">Jason Ralston</h2>,
#  <h2 class="wc-profile-name">Sied Hassen Mohamed</h2>,
#  <h2 class="wc-sub-header">Retired</h2>]

# %% [markdown]
# Note that all of the facilty names have the same class, 'wc-profile-name'. We can use this to target our soup search.

# %%
# Select h2 tags that have the 'wc-profile-name' class
faculty = soup.find_all('h2', {"class": "wc-profile-name"})

# %%
# Let's print out the faculty names
for f in faculty:
    print(f.text)
# Out:
# Denise Hazlett
# Halefom Belay
# Jan Crouter
# Ruoning Han
# Sai Madhurika Mamunuru
# Marian Manic
# Rosie Mueller
# Jason Ralston
# Sied Hassen Mohamed

# %% [markdown]
# #### Using .find_next() to move around our HTML
# Let's go back to our inspector. Notice how the Faculty info is stored...
#
# It's in an unordered list that comes after the h2 tags. How can we access that?
#
# BeautifulSoup has other useful tools: find.next() ... which works because the HTML is structured like a tree!

# %%
# From the first faculty tag, find the next tag:
faculty[0].find_next()

# What do you notice?
# Out:
# <h3 class="wc-profile-title">Hollon Parker Professor of Economics and Business, Chair</h3>

# %%
# And the one after that
faculty[0].find_next().find_next()
# Out:
# <div class="wc-profile-info-items">
# <div class="wc-info-item">
# <div class="wc-icon-box">
# <svg viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-email"></use>
# </svg>
# </div>
# <div class="wc-text-box">
# <a class="wc-text" href="mailto:hazlett@whitman.edu">hazlett@whitman.edu</a>
# </div>
# </div>
# <div class="wc-info-item">
# <div class="wc-icon-box">
# <svg viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-map-pin"></use>
# </svg>
# </div>
# <div class="wc-text-box">
# <span class="wc-text">Maxey Hall 224</span>
# </div>
# </div>
# <div class="wc-info-item">
# <div class="wc-icon-box">
# <svg viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-phone"></use>
# </svg>
# </div>
# <div class="wc-text-box">
# <span class="wc-text" itemprop="telephone">509-527-5155</span>
# </div>
# </div>
# <div class="wc-info-item">
# <div class="wc-icon-box">
# <svg viewbox="0 0 32 32">
# <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-link-circle"></use>
# </svg>
# </div>
# <div class="wc-text-box">
# <a class="wc-text" href="a/64306">Curriculum Vitae</a>
# </div>
# </div>
# </div>

# %% [markdown]
# ### Challenge: Collect Data on the Economics Faculty
# We now have everything we need to write some code that will:
# * find all the faculty names
# * find their titles
# * find their email addresses
# * store this info in a data frame

# %%
# YOUR CODE HERE

# %%
# Make a new dataframe
df_faculty = pd.DataFrame(columns=["Name", "Title", "Email"])

# %%
# Iterate over the faculty
for f in faculty:
    
    # Get the relevant info
    name = f.text
    title = f.find_next().text
    email = f.find_next().find_next().find('a').text
    
    # New row to add to the DataFrame
    new_row = {"Name": name, "Title": title, "Email":email}
    
    # Use .concat to add it
    df_faculty = pd.concat([df_faculty, pd.DataFrame([new_row])], ignore_index=True)

# %%
df_faculty
# Out:
#                      Name                                              Title  \
# 0          Denise Hazlett  Hollon Parker Professor of Economics and Busin...
# 1           Halefom Belay                   Associate Professor of Economics
# 2             Jan Crouter                   Associate Professor of Economics
# 3             Ruoning Han                   Assistant Professor of Economics
# 4  Sai Madhurika Mamunuru  Assistant Professor of Economics (Sabbatical F...
# 5            Marian Manic                   Associate Professor of Economics
# 6           Rosie Mueller                   Assistant Professor of Economics
# 7           Jason Ralston                   Assistant Professor of Economics
# 8     Sied Hassen Mohamed          Visiting Assistant Professor of Economics
#
#                   Email
# 0   hazlett@whitman.edu
# 1    belayh@whitman.edu
# 2   crouter@whitman.edu
# 3      hanr@whitman.edu
# 4       sai@whitman.edu
# 5    manicm@whitman.edu
# 6  muellerm@whitman.edu
# 7  ralstonj@whitman.edu
# 8  hassenms@whitman.edu

# %% [markdown]
# ### Part 4: What if we wanted to write a web scraper to do this for all departments at Whitman?
# What would our next steps be?
#
# We would need to systematically visit all of the department pages and repeat this process.
#
# How might we do that?
#
# Let's start by visiting the Whitman Majors & Minors page. We can use the list of Majors and Minor to make a list of all of the department links -- as well as the department faculty pages.

# %%
# We'll start with the Whitman Majors & Minors page
majorminorURL = "https://www.whitman.edu/academics/majors-and-minors"

# Use requests.get to grab the html
majorminorHTML = requests.get(majorminorURL)

# Examine it -- what does it look like? What format is it?
print(majorminorHTML.text)

# Now let's turn it into soup
# The first argument is our HTML (remember, we need to do html.text to access it)
# The second argument is our parser -- this tells bs4 that it is reading HTML (and not some other format)
majorminorSoup = BeautifulSoup(majorminorHTML.text, 'html')

# Let's examine it... what do you notice?
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
#             <!-- Google Tag Manager -->
#             <script>
#                 (function (w, d, s, l, i) {
#                     w[l] = w[l] || []; w[l].push({
#                         'gtm.start':
#                             new Date().getTime(), event: 'gtm.js'
#                     }); var f = d.getElementsByTagName(s)[0],
#                         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                             'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#                 })(window, document, 'script', 'dataLayer', 'GTM-PN449F');</script>
#             <!-- End Google Tag Manager -->
#
#
#
#             <meta name="APIKey" content="SnazzyMap:AIzaSyA8pm3DLjUEic2ds_HPBH_VcDJwT84D6uY" />
#             <meta name="APIKey" content="GoogleMaps:AIzaSyBBuhapIg-2rzMPiPltgp9gGP4rOXSV0B4" />
#             <meta name="APIKey" content="GoogleDrive:AIzaSyANHcgxXdeKV4FZdwwgGx8SnP57eK4Tl-g" />
#     <meta name="SearchURL" content="https://www.whitman.edu/xsd/customsearch4/?q=" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Majors and Minors | Whitman College</title>
#     <meta name="robots" content="noodp,noydir" />
#     <link rel="canonical" href="https://www.whitman.edu/academics/majors-and-minors" />
#     <meta name="description" property="og:description" content="Whitman has 52 majors, 35 minors, and 1 concentration as well as the opportunity to plan your own major." />
#     <meta name="Model.BaseURL" content="http://www.whitman.edu/" />
#
#     <!-- for facebook and twitter-->
#     <meta name="twitter:card" content="summary" />
#     <meta name="twitter:site" content="@whitmancollege" />
#     <meta name="twitter:creator" content="@whitmancollege" />
#     <meta name="twitter:title" property="og:title" content="Majors and Minors" />
#     <meta name="twitter:description" content="Whitman has 52 majors, 35 minors, and 1 concentration as well as the opportunity to plan your own major." />
#     <meta name="twitter:image" property="og:image" content="https://www.whitman.edu/images/Global/Thumbnails/Summer-Memorial-Rainbow.jpg" />
#
#     <meta property="og:type" content="article" />
#     <meta property="og:url" content="https://www.whitman.edu/academics/majors-and-minors" />
#     <meta property="og:site_name" content="Whitman College" />
#     <meta property="fb:admins" content="536191522" />
#
#     <!--for siteimprove-->
#     <meta name="PageID" content="x40801" />
#
#             <base href="https://www.whitman.edu" />
#
#
#     <!-- whitman styles -->
#     <link href="/prebuilt/v9/dist/css/wc-style.css?v=20210310_1" rel="stylesheet" />
#     <link href="/prebuilt/v9/dist/css/wc-style-2019.css?v=20210310_1" rel="stylesheet" />
#
#     <!-- Fonts -->
#     <link href="https://fonts.googleapis.com/css?family=Merriweather:400,400i,&amp;subset=latin-ext" rel="stylesheet">
#     <link href="https://fonts.googleapis.com/css?family=Raleway:300,300i,400,400i,500,500i,700,700i" rel="stylesheet">
#
#
#
#     <!-- jquery -->
#     <script src="/prebuilt/v9/dist/js/jquery.min.js"></script>
#
#
#
#
#     <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#     <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#     <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#     <link rel="manifest" href="/prebuilt/v9/site.webmanifest">
#
#     <link rel="mask-icon" href="/safari-pinned-tab.svg" color="#5bbad5">
#     <meta name="msapplication-TileColor" content="#002868">
#     <meta name="theme-color" content="#ffffff">
#
#
#     <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
#     <!--[if lt IE 9]>
#         <script src="https://oss.maxcdn.com/html5shiv/3.7.2/html5shiv.min.js"></script>
#         <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
#
# </head>
# <body>
#
#             <!-- Google Tag Manager (noscript) -->
#             <noscript>
#                 <iframe title="Google Tag Manager" src="https://www.googletagmanager.com/ns.html?id=GTM-PN449F"
#                         height="0" width="0" style="display:none;visibility:hidden"></iframe>
#             </noscript>
#             <!-- End Google Tag Manager (noscript) -->
#
#
# 		<a class="wc-skip-to-content-link" href="/academics/majors-and-minors#wc-reader-content">Skip to main content</a>
#     <!-- Header -->
#     <header class="wc-header" id="wc-site-header">
#         <!-- Header Row 1 -->
#         <div class="wc-header-row1" id="wc-header-row1" role="navigation">
#             <div class="wc-container">
#                 <!-- Logo -->
#                 <a href="/" class="wc-header-logo-link" title="Whitman College home">
#                     <!-- Desktop Logo -->
#                     <img class="wc-desktop-header-logo" alt="Clocktower Logo" src="/prebuilt/v9/images/svg/whitman-logo-header.svg" onerror="this.src='/prebuilt/v9/images/misc/whitman-logo-header.png'" />
#
#                     <!-- Mobile Logo-->
#                     <svg class="wc-mobile-header-logo" viewBox="0 0 180 15">
# 						<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#logo-whitman-nc-flat"></use>
#                     </svg>
#                 </a>
#                 <div class="wc-right-box">
#                     <!-- Constituent Links -->
#                     <div class="wc-constituent-links">
#                                 <ul role="menubar">
# 											<li>
# 												    <a href="/admission-and-aid/applying-to-whitman"  class="wc-clickable"  title="Apply" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - Apply" >
#         Apply</a>
#
# <span class="wc-bullet" aria-hidden="true">&bull;</span>
# 											</li>
# 											<li>
# 												    <a href="/alumni"  class="wc-clickable"  title="Alumni" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - Alumni" >
#         Alumni</a>
#
# <span class="wc-bullet" aria-hidden="true">&bull;</span>
# 											</li>
# 											<li>
# 												    <a href="/campus-life/diversity-and-inclusion"  class="wc-clickable"  title="Diversity" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - Diversity" >
#         Diversity</a>
#
# <span class="wc-bullet" aria-hidden="true">&bull;</span>
# 											</li>
# 											<li>
# 												    <a href="https://library.whitman.edu/"  class="wc-clickable"  title="Library" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - Library" >
#         Library</a>
#
# <span class="wc-bullet" aria-hidden="true">&bull;</span>
# 											</li>
# 											<li>
# 												    <a href="https://my.whitman.edu/"  class="wc-clickable"  title="MyWhitman" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - MyWhitman" >
#         MyWhitman</a>
#
# <span class="wc-bullet" aria-hidden="true">&bull;</span>
# 											</li>
# 											<li>
# 												    <a href="/families"  class="wc-clickable"  title="Families" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link - Families" >
#         Families</a>
#
#
# 											</li>
#
#                                 </ul>
#
#                     </div>
#
#     <a href="https://www.givecampus.com/campaigns/7878/donations/new" target="_blank" class="wc-special-button wc-box-button wc-white"  title="Make A Gift"
#          >
#         Make A Gift</a>
#
#
#                     <!-- Quick Links - Button -->
#                     <button class="wc-quick-links-button collapsed" data-toggle="collapse" data-target="#wc-quick-links-links" id="wc-quick-links-button" role="button" aria-haspopup="true" aria-label="Quick Links Menu">
#                             <svg class="wc-svg-box wc-spins" viewbox="0 0 32 32">
#                                 <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-circle-down"></use>
#                             </svg>
#                         <span class="wc-text" id="quicklinks">Quick Links</span>
#                     </button>
#
#                     <!-- Mobile Buttons -->
#                     <button class="wc-toggle wc-mobile-button wc-collapsed" id="wc-mobile-nav-button" aria-label="Menu" aria-expanded="false" >
#                         <svg class="wc-not-toggled-icon" viewbox="0 0 32 32"><use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-menu-mobile-a"></use></svg>
# 						<svg class="wc-toggled-icon" viewbox="0 0 32 32"><use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-menu-mobile-b"></use></svg>
#                     </button>
#                     <button class="wc-toggle wc-mobile-button wc-collapsed" id="wc-mobile-search-button" aria-label="Search" aria-expanded="false" >
#                         <svg class="wc-not-toggled-icon" viewbox="0 0 32 32"><use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-search-mobile-a"></use></svg>
#                         <svg class="wc-toggled-icon" viewbox="0 0 32 32"><use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-search-mobile-b"></use></svg>
#                     </button>
#
#                 </div>
#             </div>
#
#             <!-- Quick Links - Links -->
#             <div class="wc-quick-links-links wc-container collapse" id="wc-quick-links-links" role="navigation" aria-label="Quick Links">
#                 <div class="wc-quick-links-section">
#
#                     <ul class="wc-quick-link-columns-text" aria-labelledby="quicklinks" role="menu">
#                                         <li >    <a href="https://whitman-advocate.symplicity.com/public_report/index.php"    title="Bias Reporting" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Bias Reporting" >
#         Bias Reporting</a>
# </li>
#                                         <li >    <a href="http://bookstore.whitman.edu/home.aspx"    title="Bookstore" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Bookstore" >
#         Bookstore</a>
# </li>
#                                         <li >    <a href="/dean-of-students/care-team"    title="CARE Team" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - CARE Team" >
#         CARE Team</a>
# </li>
#                                         <li >    <a href="/after-whitman/career-and-community-engagement-center/job-and-career-resources"    title="Career Services" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Career Services" >
#         Career Services</a>
# </li>
#                                         <li >    <a href="/communications"    title="Communications" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Communications" >
#         Communications</a>
# </li>
#                                         <li >    <a href="/human-resources"    title="Employment Opportunities" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Employment Opportunities" >
#         Employment Opportunities</a>
# </li>
#                                         <li >    <a href="/giving"    title="Giving" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Giving" >
#         Giving</a>
# </li>
#                                         <li >    <a href="/human-resources/grievance-policy"    title="Grievance Policy" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Grievance Policy" >
#         Grievance Policy</a>
# </li>
#                                         <li >    <a href="/newsroom"    title="Newsroom" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Newsroom" >
#         Newsroom</a>
# </li>
#                                         <li >    <a href="/campus-life/diversity-and-inclusion/nondiscrimination-policy"    title="Nondiscrimination Policy" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Nondiscrimination Policy" >
#         Nondiscrimination Policy</a>
# </li>
#                                         <li >    <a href="/dean-of-students/right-to-know"    title="Right to Know" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Right to Know" >
#         Right to Know</a>
# </li>
#                                         <li >    <a href="/campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct"    title="Sexual Misconduct & Title IX" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Sexual Misconduct & Title IX" >
#         Sexual Misconduct & Title IX</a>
# </li>
#                                         <li >    <a href="/communications/social-media"    title="Social Media " data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Social Media " >
#         Social Media </a>
# </li>
#                                         <li >    <a href="/academics/the-center-for-writing-and-speaking"    title="The Center for Writing and Speaking (COWS)" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - The Center for Writing and Speaking (COWS)" >
#         The Center for Writing and Speaking (COWS)</a>
# </li>
#                                         <li >    <a href="/website-privacy-policy"    title="Website Privacy Policy" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Website Privacy Policy" >
#         Website Privacy Policy</a>
# </li>
#                                         <li >    <a href="/welty-student-health-center"    title="Welty Student Health Center" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Quick Link - Welty Student Health Center" >
#         Welty Student Health Center</a>
# </li>
#
#                     </ul>
#                 </div>
# 						<div class="wc-quick-links-section" role="menubar">
# 									<a class="wc-icon-quick-link" href="a-to-z-index"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - A to Z Index">
# 										<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 											<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-a-to-z"></use>
# 										</svg>
# 										<span class="wc-text">
# 											A to Z Index
#
# 										</span>
# 									</a>
# 									<a class="wc-icon-quick-link" href="campus-map"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Map">
# 										<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 											<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-map-pin"></use>
# 										</svg>
# 										<span class="wc-text">
# 											Map
#
# 										</span>
# 									</a>
# 									<a class="wc-icon-quick-link" href="http://calendar.whitman.edu"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Events Calendar">
# 										<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 											<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-calendar-no-circle"></use>
# 										</svg>
# 										<span class="wc-text">
# 											Events Calendar
#
# 										</span>
# 									</a>
# 									<a class="wc-icon-quick-link" href="https://library.whitman.edu/"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Penrose Library">
# 										<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 											<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-library"></use>
# 										</svg>
# 										<span class="wc-text">
# 											Penrose Library
#
# 										</span>
# 									</a>
# 									<a class="wc-icon-quick-link" href="https://my.whitman.edu"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - myWhitman">
# 										<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 											<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-mywhitman-cog"></use>
# 										</svg>
# 										<span class="wc-text">
# 											myWhitman
# 													<svg class="wc-icon-inline" viewbox="0 0 32 32" aria-hidden="true">
# 														<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-lock"></use>
# 													</svg>
#
# 										</span>
# 									</a>
#
# 						</div>
#
#             </div>
#         </div>
#         <!-- Header Row 2 -->
#         <div class="wc-header-row2" id="wc-header-row2">
#             <div class="wc-container">
#                 <!-- Main Nav-->
#                 <nav class="wc-main-nav wc-sm-collapse" id="wc-main-nav" aria-label="main navigation">
# 							<div class="wc-mobile-only wc-mobile-quick-links" role="menu">
# 										<a class="wc-icon-quick-link" href="a-to-z-index"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - A to Z Index">
# 											<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-a-to-z"></use>
# 											</svg>
# 											<span class="wc-text">
# 												A to Z
#
# 											</span>
# 										</a>
# 										<a class="wc-icon-quick-link" href="campus-map"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Map">
# 											<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-map-pin"></use>
# 											</svg>
# 											<span class="wc-text">
# 												Map
#
# 											</span>
# 										</a>
# 										<a class="wc-icon-quick-link" href="http://calendar.whitman.edu"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Events Calendar">
# 											<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-calendar-no-circle"></use>
# 											</svg>
# 											<span class="wc-text">
# 												Events
#
# 											</span>
# 										</a>
# 										<a class="wc-icon-quick-link" href="https://library.whitman.edu/"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - Penrose Library">
# 											<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-library"></use>
# 											</svg>
# 											<span class="wc-text">
# 												Library
#
# 											</span>
# 										</a>
# 										<a class="wc-icon-quick-link" href="https://my.whitman.edu"  data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Quick Link Icon - myWhitman">
# 											<svg class="wc-icon" viewbox="0 0 32 32" aria-hidden="true">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-mywhitman-cog"></use>
# 											</svg>
# 											<span class="wc-text">
# 												myWhitman
# 														<svg class="wc-icon-inline" viewbox="0 0 32 32" aria-hidden="true">
# 															<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-lock"></use>
# 														</svg>
#
# 											</span>
# 										</a>
#
# 							</div>
#
#                     <ul class="wc-main-nav-level-1">
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="about" id="main-1" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="About">About</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-1-box" aria-label="Expand About submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-1-box">
#                                         <ul role="menu" aria-labelledby="main-1">
# 													<li >    <a href="/about/contact-us"    title="Contact Us & Building Hours" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Contact Us & Building Hours" >
#         Contact Us & Building Hours</a>
# </li>
# 													<li >    <a href="/campus-map"    title="Interactive Map" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Interactive Map" >
#         Interactive Map</a>
# </li>
# 													<li >    <a href="/about/leadership-and-organization"    title="Leadership and Organization" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Leadership and Organization" >
#         Leadership and Organization</a>
# </li>
# 													<li >    <a href="/about/mission-constitution-and-bylaws"    title="Mission, Constitution and Bylaws" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Mission, Constitution and Bylaws" >
#         Mission, Constitution and Bylaws</a>
# </li>
# 													<li >    <a href="/newsroom"    title="Newsroom" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Newsroom" >
#         Newsroom</a>
# </li>
# 													<li >    <a href="/president"    title="Office of the President" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Office of the President" >
#         Office of the President</a>
# </li>
# 													<li >    <a href="/about/our-campus"    title="Our Campus" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Our Campus" >
#         Our Campus</a>
# </li>
# 													<li >    <a href="/about/our-community"    title="Our Community" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Our Community" >
#         Our Community</a>
# </li>
# 													<li >    <a href="/about/rankings"    title="Rankings and Top Lists" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Rankings and Top Lists" >
#         Rankings and Top Lists</a>
# </li>
# 													<li >    <a href="/president/strategic-planning"    title="Strategic Planning" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="About - Strategic Planning" >
#         Strategic Planning</a>
# </li>
#
#                                         </ul>
#
#                                     </div>
#                                 </li>
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="academics" id="main-2" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Academics">Academics</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-2-box" aria-label="Expand Academics submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-2-box">
#                                         <ul role="menu" aria-labelledby="main-2">
# 													<li >    <a href="/academics/academic-calendar"    title="Academic Calendar" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Academic Calendar" >
#         Academic Calendar</a>
# </li>
# 													<li >    <a href="/academics/academic-resource-center"    title="Academic Resource Center" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Academic Resource Center" >
#         Academic Resource Center</a>
# </li>
# 													<li >    <a href="/academics/academic-theme"    title="Academic Theme" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Academic Theme" >
#         Academic Theme</a>
# </li>
# 													<li >    <a href="/academics/careers-professions-and-the-liberal-arts"    title="Careers, Professions and the Liberal Arts" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Careers, Professions and the Liberal Arts" >
#         Careers, Professions and the Liberal Arts</a>
# </li>
# 													<li >    <a href="/academics/catalog"    title="Catalog" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Catalog" >
#         Catalog</a>
# </li>
# 													<li >    <a href="/academics/center-for-global-studies"    title="Center for Global Studies" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Center for Global Studies" >
#         Center for Global Studies</a>
# </li>
# 													<li >    <a href="/academics/community-outreach"    title="Community Outreach" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Community Outreach" >
#         Community Outreach</a>
# </li>
# 													<li >    <a href="/after-whitman/fellowships-and-grants"    title="Fellowships and Grants" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Fellowships and Grants" >
#         Fellowships and Grants</a>
# </li>
# 													<li >    <a href="/academics/honor-societies"    title="Honor Societies" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Honor Societies" >
#         Honor Societies</a>
# </li>
# 													<li >    <a href="/academics/majors-and-minors"    title="Majors and Minors" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Majors and Minors" >
#         Majors and Minors</a>
# </li>
# 													<li >    <a href="/academics/maxey-museum"    title="Maxey Museum" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Maxey Museum" >
#         Maxey Museum</a>
# </li>
# 													<li >    <a href="/off-campus-studies"    title="Off-Campus Studies" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Off-Campus Studies" >
#         Off-Campus Studies</a>
# </li>
# 													<li >    <a href="https://library.whitman.edu/"    title="Penrose Library" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Penrose Library" >
#         Penrose Library</a>
# </li>
# 													<li >    <a href="/provost"    title="Provost and Dean of the Faculty" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Provost and Dean of the Faculty" >
#         Provost and Dean of the Faculty</a>
# </li>
# 													<li >    <a href="/registrar"    title="Registrar's Office" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Registrar's Office" >
#         Registrar's Office</a>
# </li>
# 													<li >    <a href="/academics/stem-hub"    title="STEM Hub" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - STEM Hub" >
#         STEM Hub</a>
# </li>
# 													<li >    <a href="/academics/research/whitman-undergraduate-conference"    title="Whitman Undergraduate Conference" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Whitman Undergraduate Conference" >
#         Whitman Undergraduate Conference</a>
# </li>
# 													<li >    <a href="/academics/the-faculty"    title="Whitman's Faculty" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Academics - Whitman's Faculty" >
#         Whitman's Faculty</a>
# </li>
#
#                                         </ul>
# 												<div class="wc-feature">
#     <a href="/after-whitman/fellowships-and-grants" >    <img   src="/images/Academics/Fellowships%20%26%20Grants/hunter-conservatory-250.jpg" alt="Fellowships and Grants"  width="150"  />
# </a>
# 														<div class="wc-feature-text">
# 															<p>Learn how to pursue a fellowship, scholarship or grant opportunity.</p>
# 															    <a href="/after-whitman/fellowships-and-grants"  class="wc-box-button wc-bb-more-link wc-white"  title="Fellowships and Grants"
#          >
#         Fellowships and Grants</a>
#
# 														</div>
#
# 												</div>
#
#                                     </div>
#                                 </li>
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="admission-and-aid" id="main-3" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Admission &amp; Aid">Admission &amp; Aid</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-3-box" aria-label="Expand Admission &amp; Aid submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-3-box">
#                                         <ul role="menu" aria-labelledby="main-3">
# 													<li >    <a href="/admission-and-aid/contact-us"    title="Admission & Financial Aid Contacts" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Admission & Financial Aid Contacts" >
#         Admission & Financial Aid Contacts</a>
# </li>
# 													<li >    <a href="/admission-and-aid/applying-to-whitman"    title="Applying to Whitman" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Applying to Whitman" >
#         Applying to Whitman</a>
# </li>
# 													<li >    <a href="/admission-and-aid/applying-to-whitman/early-decision"    title="Early Decision" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Early Decision" >
#         Early Decision</a>
# </li>
# 													<li >    <a href="/admission-and-aid/early-financial-aid-guarantee"    title="Early Financial Aid Guarantee" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Early Financial Aid Guarantee" >
#         Early Financial Aid Guarantee</a>
# </li>
# 													<li >    <a href="/admission-and-aid/financial-aid-and-costs"    title="Financial Aid & Costs" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Financial Aid & Costs" >
#         Financial Aid & Costs</a>
# </li>
# 													<li >    <a href="/admission-and-aid/learn-more-about-whitman"    title="Learn More About Whitman" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Learn More About Whitman" >
#         Learn More About Whitman</a>
# </li>
# 													<li >    <a href="/admission-and-aid/financial-aid-and-costs/merit-and-talent-awards"    title="Merit and Talent Awards" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Merit and Talent Awards" >
#         Merit and Talent Awards</a>
# </li>
# 													<li >    <a href="/admission-and-aid/request-information"    title="Request Information" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Request Information" >
#         Request Information</a>
# </li>
# 													<li >    <a href="/admission-and-aid/virtual-tours"    title="Virtual Tours" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Virtual Tours" >
#         Virtual Tours</a>
# </li>
# 													<li >    <a href="/admission-and-aid/visit-whitman"    title="Visiting Whitman College" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Visiting Whitman College" >
#         Visiting Whitman College</a>
# </li>
# 													<li >    <a href="/admission-and-aid/class-of-2027"    title="Welcome Class of 2027" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Welcome Class of 2027" >
#         Welcome Class of 2027</a>
# </li>
# 													<li >    <a href="/admission-and-aid/whitman-on-the-road"    title="Whitman on the Road" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Whitman on the Road" >
#         Whitman on the Road</a>
# </li>
# 													<li >    <a href="/admission-and-aid/why-whitman"    title="Why Whitman?" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Admission & Aid - Why Whitman?" >
#         Why Whitman?</a>
# </li>
#
#                                         </ul>
# 												<div class="wc-feature">
#     <a href="/admission-and-aid/visit-whitman" >    <img   src="/images/Admission%20and%20Aid/Thumbnail/campus-fall-250.jpg" alt="Whitman&#39;s campus in the fall"  width="150"  />
# </a>
# 														<div class="wc-feature-text">
# 															<p>Join us on campus to experience the Whitman community in action!</p>
# 															    <a href="/admission-and-aid/visit-whitman"  class="wc-box-button wc-bb-more-link wc-white"  title="Visit Whitman"
#          >
#         Visit Whitman</a>
#
# 														</div>
#
# 												</div>
#
#                                     </div>
#                                 </li>
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="after-whitman" id="main-4" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="After Whitman">After Whitman</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-4-box" aria-label="Expand After Whitman submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-4-box">
#                                         <ul role="menu" aria-labelledby="main-4">
# 													<li >    <a href="/after-whitman/career-and-community-engagement-center"    title="Career and Community Engagement Center" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Career and Community Engagement Center" >
#         Career and Community Engagement Center</a>
# </li>
# 													<li >    <a href="/academics/careers-professions-and-the-liberal-arts"    title="Careers, Professions and the Liberal Arts" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Careers, Professions and the Liberal Arts" >
#         Careers, Professions and the Liberal Arts</a>
# </li>
# 													<li >    <a href="/after-whitman/fellowships-and-grants"    title="Fellowships and Grants" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Fellowships and Grants" >
#         Fellowships and Grants</a>
# </li>
# 													<li >    <a href="/after-whitman/graduate-schools-and-pre-professional-programs"    title="Graduate Schools and Pre-Professional Programs" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Graduate Schools and Pre-Professional Programs" >
#         Graduate Schools and Pre-Professional Programs</a>
# </li>
# 													<li >    <a href="/after-whitman/career-and-community-engagement-center/internships"    title="Internships" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Internships" >
#         Internships</a>
# </li>
# 													<li >    <a href="/after-whitman/life-after-whitman-stories"    title="Life After Whitman Stories" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Life After Whitman Stories" >
#         Life After Whitman Stories</a>
# </li>
# 													<li >    <a href="/academics/research/whitman-undergraduate-conference"    title="Whitman Undergraduate Conference" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Whitman Undergraduate Conference" >
#         Whitman Undergraduate Conference</a>
# </li>
# 													<li >    <a href="/after-whitman/whitties-helping-whitties"    title="Whitties Helping Whitties" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="After Whitman - Whitties Helping Whitties" >
#         Whitties Helping Whitties</a>
# </li>
#
#                                         </ul>
#
#                                     </div>
#                                 </li>
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="athletics" id="main-5" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Athletics">Athletics</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-5-box" aria-label="Expand Athletics submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-5-box">
#                                         <ul role="menu" aria-labelledby="main-5">
# 													<li >    <a href="https://athletics.whitman.edu/news/2020/10/6/general-student-access-to-buildings-or-other-campus-resources.aspx"    title="Athletic Facility Hours" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - Athletic Facility Hours" >
#         Athletic Facility Hours</a>
# </li>
# 													<li >    <a href="/athletics/club-sports"    title="Club Sports" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - Club Sports" >
#         Club Sports</a>
# </li>
# 													<li >    <a href="/athletics/intramural-sports"    title="Intramural Sports" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - Intramural Sports" >
#         Intramural Sports</a>
# </li>
# 													<li >    <a href="/academics/majors-and-minors/sports-studies-recreation-and-athletics"    title="Sports Studies, Recreation and Athletics" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - Sports Studies, Recreation and Athletics" >
#         Sports Studies, Recreation and Athletics</a>
# </li>
# 													<li >    <a href="http://athletics.whitman.edu/"    title="Varsity Athletics" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - Varsity Athletics" >
#         Varsity Athletics</a>
# </li>
# 													<li >    <a href="https://athletics.whitman.edu/news/2020/11/30/general-join-the-w-club.aspx"    title="W Club" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Athletics - W Club" >
#         W Club</a>
# </li>
#
#                                         </ul>
# 												<div class="wc-feature">
#     <a href="http://athletics2.whitman.edu/calendar.aspx" >    <img   src="/images/About/sort/womens-soccer-250.jpg" alt="Women&#39;s Soccer"  width="150"  />
# </a>
# 														<div class="wc-feature-text">
# 															<p>See when Whitman&#39;s teams are playing this spring.</p>
# 															    <a href="http://athletics2.whitman.edu/calendar.aspx"  class="wc-box-button wc-bb-more-link wc-white"  title="Varsity Athletics Calendar"
#          >
#         Varsity Athletics Calendar</a>
#
# 														</div>
#
# 												</div>
#
#                                     </div>
#                                 </li>
#                                 <li>
# 											<a class="wc-main-nav-primary-category wc-clickable" href="campus-life" id="main-6" data-tracking-category="Header Link" data-tracking-action="Click" data-tracking-label="Campus Life">Campus Life</a>
# 										<button class="wc-main-nav-expander collapsed" data-toggle="collapse" data-target="#main-6-box" aria-label="Expand Campus Life submenu" aria-expanded="false">
# 											<svg viewbox="0 0 32 32">
# 												<use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-down"></use>
# 											</svg>
# 										</button>
#
# 									<div class="wc-sub-menu wc-container wc-about-sub-menu wc-mobile-collapse-box" id="main-6-box">
#                                         <ul role="menu" aria-labelledby="main-6">
# 													<li >    <a href="/after-whitman/career-and-community-engagement-center"    title="Career and Community Engagement Center" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Career and Community Engagement Center" >
#         Career and Community Engagement Center</a>
# </li>
# 													<li >    <a href="/campus-life/diversity-and-inclusion"    title="Diversity & Inclusion" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Diversity & Inclusion" >
#         Diversity & Inclusion</a>
# </li>
# 													<li >    <a href="/campus-life/international-student-and-scholar-services"    title="International Student & Scholar Services" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - International Student & Scholar Services" >
#         International Student & Scholar Services</a>
# </li>
# 													<li >    <a href="/campus-life/orientation"    title="New Student Orientation" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - New Student Orientation" >
#         New Student Orientation</a>
# </li>
# 													<li >    <a href="/campus-life/outdoor-program"    title="Outdoor Program" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Outdoor Program" >
#         Outdoor Program</a>
# </li>
# 													<li >    <a href="/campus-life/pathways-leadership-program"    title="Pathways Leadership Program" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Pathways Leadership Program" >
#         Pathways Leadership Program</a>
# </li>
# 													<li >    <a href="/campus-life/reid-campus-center"    title="Reid Campus Center" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Reid Campus Center" >
#         Reid Campus Center</a>
# </li>
# 													<li >    <a href="/campus-life/residence-life"    title="Residence Life" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Residence Life" >
#         Residence Life</a>
# </li>
# 													<li >    <a href="/campus-life/sorority-and-fraternity-life"    title="Sorority & Fraternity Life" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Sorority & Fraternity Life" >
#         Sorority & Fraternity Life</a>
# </li>
# 													<li >    <a href="/campus-life/student-activities"    title="Student Activities" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Activities" >
#         Student Activities</a>
# </li>
# 													<li >    <a href="/dean-of-students/student-affairs"    title="Student Affairs" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Affairs" >
#         Student Affairs</a>
# </li>
# 													<li >    <a href="/campus-life/student-employment"    title="Student Employment" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Employment" >
#         Student Employment</a>
# </li>
# 													<li >    <a href="/campus-life/sustainability"    title="Sustainability" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Sustainability" >
#         Sustainability</a>
# </li>
# 													<li >    <a href="/campus-life/student-activities/virtual-campus"    title="Virtual Campus" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Virtual Campus" >
#         Virtual Campus</a>
# </li>
# 													<li >    <a href="https://whitman.presence.io/"    title="WhitLife" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - WhitLife" >
#         WhitLife</a>
# </li>
#
#                                         </ul>
#
#                                     </div>
#                                 </li>
#  <!--end code section-->
#                                     <li class="wc-mobile-only">
# 										<span class="wc-main-nav-primary-category wc-clickable wc-mobile-only">
# 											<span class="wc-center-line">
# 												<span id="mobile-menu-1">Audiences</span>
# 											</span>
# 										</span>
#
#                                         <div class="wc-sub-menu wc-indented">
#                                         <ul aria-labelledby="mobile-menu-1" role="menu">
#                                             <li >
#                                                     <a href="/admission-and-aid/applying-to-whitman"  class="wc-clickable"  title="Apply" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link Mobile - Apply" >
#         Apply</a>
#
#                                             </li>
#                                             <li >
#                                                     <a href="/alumni"  class="wc-clickable"  title="Alumni" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link Mobile - Alumni" >
#         Alumni</a>
#
#                                             </li>
#                                             <li >
#                                                     <a href="/campus-life/diversity-and-inclusion"  class="wc-clickable"  title="Diversity" data-tracking-category="Header Link"
#        data-tracking-action="Click" data-tracking-label="Constituent Link Mobile - Diversity" >
#         Diversity</a>
#
#                                             </li>
#                                             <li >
# ...
#        data-tracking-action="Click" data-tracking-label="Campus Life - Diversity & Inclusion" >
#         Diversity & Inclusion</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/international-student-and-scholar-services"    title="International Student & Scholar Services" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - International Student & Scholar Services" >
#         International Student & Scholar Services</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/orientation"    title="New Student Orientation" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - New Student Orientation" >
#         New Student Orientation</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/outdoor-program"    title="Outdoor Program" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Outdoor Program" >
#         Outdoor Program</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/pathways-leadership-program"    title="Pathways Leadership Program" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Pathways Leadership Program" >
#         Pathways Leadership Program</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/reid-campus-center"    title="Reid Campus Center" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Reid Campus Center" >
#         Reid Campus Center</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/residence-life"    title="Residence Life" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Residence Life" >
#         Residence Life</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/sorority-and-fraternity-life"    title="Sorority & Fraternity Life" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Sorority & Fraternity Life" >
#         Sorority & Fraternity Life</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/student-activities"    title="Student Activities" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Activities" >
#         Student Activities</a>
# </li>
#                                     <li role="menuitem">    <a href="/dean-of-students/student-affairs"    title="Student Affairs" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Affairs" >
#         Student Affairs</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/student-employment"    title="Student Employment" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Student Employment" >
#         Student Employment</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/sustainability"    title="Sustainability" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Sustainability" >
#         Sustainability</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/student-activities/virtual-campus"    title="Virtual Campus" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - Virtual Campus" >
#         Virtual Campus</a>
# </li>
#                                     <li role="menuitem">    <a href="https://whitman.presence.io/"    title="WhitLife" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Campus Life - WhitLife" >
#         WhitLife</a>
# </li>
#
#                         </ul>
#                     </div>
#                     <div class="wc-footer-list-box">
#                         <h4 class="wc-list-header" id="footer-menu-5">Quick Links</h4>
#                         <ul class="wc-no-style-list" role="menu" aria-labelledby="footer-menu-5">
#                                     <li role="menuitem">    <a href="/a-to-z-index"    title="A to Z Index" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - A to Z Index" >
#         A to Z Index</a>
# </li>
#                                     <li role="menuitem">    <a href="https://whitman-advocate.symplicity.com/public_report/index.php"    title="Bias Reporting" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Bias Reporting" >
#         Bias Reporting</a>
# </li>
#                                     <li role="menuitem">    <a href="http://bookstore.whitman.edu/home.aspx"    title="Bookstore" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Bookstore" >
#         Bookstore</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-map"    title="Campus Map" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Campus Map" >
#         Campus Map</a>
# </li>
#                                     <li role="menuitem">    <a href="/dean-of-students/care-team"    title="CARE Team" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - CARE Team" >
#         CARE Team</a>
# </li>
#                                     <li role="menuitem">    <a href="/after-whitman/career-and-community-engagement-center/job-and-career-resources"    title="Career Services" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Career Services" >
#         Career Services</a>
# </li>
#                                     <li role="menuitem">    <a href="/communications"    title="Communications" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Communications" >
#         Communications</a>
# </li>
#                                     <li role="menuitem">    <a href="/human-resources"    title="Employment Opportunities" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Employment Opportunities" >
#         Employment Opportunities</a>
# </li>
#                                     <li role="menuitem">    <a href="/giving"    title="Giving" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Giving" >
#         Giving</a>
# </li>
#                                     <li role="menuitem">    <a href="/human-resources/grievance-policy"    title="Grievance Policy" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Grievance Policy" >
#         Grievance Policy</a>
# </li>
#                                     <li role="menuitem">    <a href="/newsroom"    title="Newsroom" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Newsroom" >
#         Newsroom</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/diversity-and-inclusion/nondiscrimination-policy"    title="Nondiscrimination Policy" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Nondiscrimination Policy" >
#         Nondiscrimination Policy</a>
# </li>
#                                     <li role="menuitem">    <a href="https://library.whitman.edu/"    title="Penrose Library" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Penrose Library" >
#         Penrose Library</a>
# </li>
#                                     <li role="menuitem">    <a href="/dean-of-students/right-to-know"    title="Right to Know" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Right to Know" >
#         Right to Know</a>
# </li>
#                                     <li role="menuitem">    <a href="/campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct"    title="Sexual Misconduct & Title IX" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Sexual Misconduct & Title IX" >
#         Sexual Misconduct & Title IX</a>
# </li>
#                                     <li role="menuitem">    <a href="/communications/social-media"    title="Social Media " data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Social Media " >
#         Social Media </a>
# </li>
#                                     <li role="menuitem">    <a href="/academics/the-center-for-writing-and-speaking"    title="The Center for Writing and Speaking (COWS)" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - The Center for Writing and Speaking (COWS)" >
#         The Center for Writing and Speaking (COWS)</a>
# </li>
#                                     <li role="menuitem">    <a href="/website-privacy-policy"    title="Website Privacy Policy" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Website Privacy Policy" >
#         Website Privacy Policy</a>
# </li>
#                                     <li role="menuitem">    <a href="/welty-student-health-center"    title="Welty Student Health Center" data-tracking-category="Footer Link"
#        data-tracking-action="Click" data-tracking-label="Quick Links - Welty Student Health Center" >
#         Welty Student Health Center</a>
# </li>
#
#                         </ul>
#                     </div>
#
#
#         </div>
#
#         <!-- Logo -->
#         <div class="wc-row wc-footer-row2" aria-hidden="true">
#             <div class="wc-footer-row2-box-a" itemscope itemtype="http://schema.org/CollegeOrUniversity">
#                 <hr />
#                 <svg class="wc-footer-logo-flat" viewbox="0 0 180 15">
#                     <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#logo-whitman-nc-flat"></use>
#                 </svg>
#                 <svg class="wc-footer-logo-stacked" viewbox="0 0 164 60" aria-hidden="true">
#                     <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#logo-whitman-nc-stacked"></use>
#                 </svg>
#                 <hr />
#             </div>
#         </div>
#
#         <!-- Contact Info -->
#         <div class="wc-row wc-footer-row3" itemscope itemtype="http://schema.org/CollegeOrUniversity">
#             <div class="wc-footer-row3-box-a wc-footer-row3-box" itemprop="address" itemscope itemtype="http://schema.org/PostalAddress">
#
#
#                 <a href="https://www.google.com/maps/place/Whitman+College/@46.0717833,-118.3304355,16z/data=!4m2!3m1!1s0x0000000000000000:0x8704a8d5077eb801" target="_blank" class="wc-street-address">
#                         <svg class="" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-map-pin"></use>
#     </svg>
#
#                     <span class="wc-text">
#                         <span itemprop="streetAddress">345 Boyer Ave. </span>
#                         <span><span itemprop="addressLocality">Walla Walla</span>, <span itemprop="addressRegion">WA</span> <span itemprop="postalCode">99362</span></span>
#                     </span>
#                 </a>
#             </div>
#             <div class="wc-footer-row3-box-b wc-footer-row3-box">
#
#                 <span class="wc-phone-numbers">
#                         <svg class="" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-phone"></use>
#     </svg>
#
#                     <span class="wc-text">
#                             <span>General: <span itemprop="telephone">509-527-5111</span></span>
#                         <span class="wc-bullet">&bull;</span>
#
#                             <span>Admission: <span itemprop="telephone">509-527-5176</span></span>
#                     </span>
#                 </span>
#             </div>
#             <div class="wc-footer-row3-box-c wc-footer-row3-box">
#
#                 <link itemprop="url" href="https://www.whitman.edu">
#                 <link itemprop="sameAs" href="https://en.wikipedia.org/wiki/Whitman_College">
# <a href="https://facebook.com/whitmancollege" class="wc-social-link" title="Whitman College Facebook Page" target="_blank" aria-label="Whitman College Facebook Page">
#         <span class="visually-hidden">visually-hidden text</span>
#             <svg class="wc-icon" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-facebook"></use>
#     </svg>
#
#     </a>
# <a href="https://twitter.com/whitmancollege" class="wc-social-link" title="Whitman College Twitter Page" target="_blank" aria-label="Whitman College Twitter Page">
#         <span class="visually-hidden">visually-hidden text</span>
#             <svg class="wc-icon" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-twitter"></use>
#     </svg>
#
#     </a>
# <a href="https://instagram.com/whitmancollege" class="wc-social-link" title="Whitman College Instagram Page" target="_blank" aria-label="Whitman College Instagram Page">
#         <span class="visually-hidden">visually-hidden text</span>
#             <svg class="wc-icon" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-instagram"></use>
#     </svg>
#
#     </a>
# <a href="https://youtube.com/whitmancollege" class="wc-social-link" title="Whitman College YouTube Page" target="_blank" aria-label="Whitman College YouTube Page">
#         <span class="visually-hidden">visually-hidden text</span>
#             <svg class="wc-icon" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-youtube"></use>
#     </svg>
#
#     </a>
#                         <a title="Social Media at Whitman" class="wc-more-social-links" href="communications/social-media/social-media-links" data-tracking-category="Footer Link" data-tracking-action="Click" data-tracking-label="Social Media at Whitman" aria-label="Social Media at Whitman">
#                                 <svg class="" viewbox="0 0 32 32" aria-hidden=true>
#         <use xlink:href="/prebuilt/v9/dist/svg/svg-defs.svg?v=12#icon-arrow-right"></use>
#     </svg>
#
#                         </a>
#
#             </div>
#         </div>
#         <div class="wc-row wc-footer-row4">
#             <div class="wc-footer-row4-box-a" role="contentinfo">
#                 <span class="wc-copyright"></span>
#             </div>
#         </div>
#     </div>
# </footer>
#
#
#
#
#
#
#
#
#     <div class="wc-breakpoint-check-box">
#         <div id="wc-breakpoint-check-lg" class="wc-breakpoint-check"></div>
#         <div id="wc-breakpoint-check-md" class="wc-breakpoint-check"></div>
#         <div id="wc-breakpoint-check-sm" class="wc-breakpoint-check"></div>
#         <div id="wc-breakpoint-check-xs" class="wc-breakpoint-check"></div>
#     </div>
#     <span id="wc-svg-path" data-svg-path="/prebuilt/v9/dist/svg/svg-defs.svg?v=12"></span>
#     <script id="wc-scripts-tag" src="/prebuilt/v9/dist/js/wc-scripts.js?v=20220427_1"></script>
#     <script src="/prebuilt/v9/dist/js/wc-popup.js"></script>
#     <script src="/prebuilt/v9/dist/js/wc-scripts-2019.js"></script>
#
#
# </body>
# </html>

# %%
majorminor_links = majorminorSoup.find_all('a')

# %%
# Let's examine -- notice how the links to the majors and minors aren't in this list!!!
for l in majorminor_links:
    print(l.get('href'))
# Out:
# /academics/majors-and-minors#wc-reader-content
# /
# /admission-and-aid/applying-to-whitman
# /alumni
# /campus-life/diversity-and-inclusion
# https://library.whitman.edu/
# https://my.whitman.edu/
# /families
# https://www.givecampus.com/campaigns/7878/donations/new
# https://whitman-advocate.symplicity.com/public_report/index.php
# http://bookstore.whitman.edu/home.aspx
# /dean-of-students/care-team
# /after-whitman/career-and-community-engagement-center/job-and-career-resources
# /communications
# /human-resources
# /giving
# /human-resources/grievance-policy
# /newsroom
# /campus-life/diversity-and-inclusion/nondiscrimination-policy
# /dean-of-students/right-to-know
# /campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct
# /communications/social-media
# /academics/the-center-for-writing-and-speaking
# /website-privacy-policy
# /welty-student-health-center
# a-to-z-index
# campus-map
# http://calendar.whitman.edu
# https://library.whitman.edu/
# https://my.whitman.edu
# a-to-z-index
# campus-map
# http://calendar.whitman.edu
# https://library.whitman.edu/
# https://my.whitman.edu
# about
# /about/contact-us
# /campus-map
# /about/leadership-and-organization
# /about/mission-constitution-and-bylaws
# /newsroom
# /president
# /about/our-campus
# /about/our-community
# /about/rankings
# /president/strategic-planning
# academics
# /academics/academic-calendar
# /academics/academic-resource-center
# /academics/academic-theme
# /academics/careers-professions-and-the-liberal-arts
# /academics/catalog
# /academics/center-for-global-studies
# /academics/community-outreach
# /after-whitman/fellowships-and-grants
# /academics/honor-societies
# /academics/majors-and-minors
# /academics/maxey-museum
# /off-campus-studies
# https://library.whitman.edu/
# /provost
# /registrar
# /academics/stem-hub
# /academics/research/whitman-undergraduate-conference
# /academics/the-faculty
# /after-whitman/fellowships-and-grants
# /after-whitman/fellowships-and-grants
# admission-and-aid
# /admission-and-aid/contact-us
# /admission-and-aid/applying-to-whitman
# /admission-and-aid/applying-to-whitman/early-decision
# /admission-and-aid/early-financial-aid-guarantee
# /admission-and-aid/financial-aid-and-costs
# /admission-and-aid/learn-more-about-whitman
# /admission-and-aid/financial-aid-and-costs/merit-and-talent-awards
# /admission-and-aid/request-information
# /admission-and-aid/virtual-tours
# /admission-and-aid/visit-whitman
# /admission-and-aid/class-of-2027
# /admission-and-aid/whitman-on-the-road
# /admission-and-aid/why-whitman
# /admission-and-aid/visit-whitman
# /admission-and-aid/visit-whitman
# after-whitman
# /after-whitman/career-and-community-engagement-center
# /academics/careers-professions-and-the-liberal-arts
# /after-whitman/fellowships-and-grants
# /after-whitman/graduate-schools-and-pre-professional-programs
# /after-whitman/career-and-community-engagement-center/internships
# /after-whitman/life-after-whitman-stories
# /academics/research/whitman-undergraduate-conference
# /after-whitman/whitties-helping-whitties
# athletics
# https://athletics.whitman.edu/news/2020/10/6/general-student-access-to-buildings-or-other-campus-resources.aspx
# /athletics/club-sports
# /athletics/intramural-sports
# /academics/majors-and-minors/sports-studies-recreation-and-athletics
# http://athletics.whitman.edu/
# https://athletics.whitman.edu/news/2020/11/30/general-join-the-w-club.aspx
# http://athletics2.whitman.edu/calendar.aspx
# http://athletics2.whitman.edu/calendar.aspx
# campus-life
# /after-whitman/career-and-community-engagement-center
# /campus-life/diversity-and-inclusion
# /campus-life/international-student-and-scholar-services
# /campus-life/orientation
# /campus-life/outdoor-program
# /campus-life/pathways-leadership-program
# /campus-life/reid-campus-center
# /campus-life/residence-life
# /campus-life/sorority-and-fraternity-life
# /campus-life/student-activities
# /dean-of-students/student-affairs
# /campus-life/student-employment
# /campus-life/sustainability
# /campus-life/student-activities/virtual-campus
# https://whitman.presence.io/
# /admission-and-aid/applying-to-whitman
# /alumni
# /campus-life/diversity-and-inclusion
# https://library.whitman.edu/
# https://my.whitman.edu/
# /families
# https://whitman-advocate.symplicity.com/public_report/index.php
# http://bookstore.whitman.edu/home.aspx
# /dean-of-students/care-team
# /after-whitman/career-and-community-engagement-center/job-and-career-resources
# /communications
# /human-resources
# /giving
# /human-resources/grievance-policy
# /newsroom
# /campus-life/diversity-and-inclusion/nondiscrimination-policy
# /dean-of-students/right-to-know
# /campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct
# /communications/social-media
# /academics/the-center-for-writing-and-speaking
# /website-privacy-policy
# /welty-student-health-center
# None
# None
#
# /academics
#
# None
# None
# /academics
# /academics
# /academics/academic-theme
# /academics/academic-theme/academic-theme-2021
# /academics/academic-theme/academic-theme-2020
# /academics/academic-theme/academic-theme-2020/2020-events
# /academics/general-studies
# /academics/general-studies/first-year-seminars
# /academics/general-studies/first-year-seminars/exploring-complex-questions
# /academics/general-studies/first-year-seminars/making-powerful-arguments
# /academics/general-studies/first-year-seminars/learning-outcomes
# /academics/general-studies/distribution-requirements
# /academics/stem-hub
# /academics/stem-hub/resources-opportunities
# /academics/stem-hub/stem-stories
# /academics/the-center-for-writing-and-speaking
# /academics/the-center-for-writing-and-speaking/cows-staff
# /academics/the-center-for-writing-and-speaking/resources
# /academics/the-center-for-writing-and-speaking/resources/citation-and-online-resources
# /academics/the-center-for-writing-and-speaking/resources/cows-handouts
# /academics/the-center-for-writing-and-speaking/resources/subject-guides
# /academics/the-center-for-writing-and-speaking/courses-in-writing-and-speaking
# /academics/catalog
# /academics/catalog/catalog-archives
# /academics/the-faculty
# /newsroom/faculty-books
# /academics/research
# /academics/research/whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/guidelines-for-presenters
# /academics/research/whitman-undergraduate-conference/guidelines-for-presenters/general-guidelines-and-instructions
# /academics/research/whitman-undergraduate-conference/guidelines-for-presenters/guidelines-for-poster-presenters
# /academics/research/whitman-undergraduate-conference/guidelines-for-presenters/guidelines-for-group-presentations
# /academics/research/whitman-undergraduate-conference/guidelines-for-presenters/logos-for-presentations
# /academics/research/whitman-undergraduate-conference/timeline
# /academics/research/whitman-undergraduate-conference/committee-members
# /academics/research/whitman-undergraduate-conference/past-events
# /academics/research/whitman-undergraduate-conference/past-events/2022-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2021-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2020-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2019-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2018-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2017-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2016-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2015-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2014-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2013-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2012-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2011-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2010-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2009-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2008-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2006-whitman-undergraduate-conference
# /academics/research/whitman-undergraduate-conference/past-events/2005-whitman-undergraduate-conference
# /academics/research/beckman-scholars
# /academics/research/beckman-scholars/application-process
# /academics/research/fred-hutch-summer-research
# /academics/research/fred-hutch-summer-research/2011-summer-research-interns
# /academics/research/fred-hutch-summer-research/2010-summer-research-interns
# /academics/research/fred-hutch-summer-research/2009-summer-research-interns
# /academics/research/mayo-surf-program
# /after-whitman/fellowships-and-grants
# /off-campus-studies
# /academics/center-for-global-studies
# /academics/center-for-global-studies/global-studies-concentration
# /academics/center-for-global-studies/global-studies-concentration/center-for-global-studies-faq
# /academics/center-for-global-studies/eportfolio
# /academics/center-for-global-studies/odonnell-visiting-educators
# /academics/center-for-global-studies/odonnell-visiting-educators/past-years
# /academics/center-for-global-studies/odonnell-visiting-educators/about-the-odonnells
# /academics/center-for-global-studies/odonnell-visiting-educators/about-the-odonnells/in-memoriam-ash-odonnell
# /academics/academic-calendar
# /academics/academic-calendar/convocation
# /academics/academic-calendar/convocation/convocation-history
# /academics/academic-calendar/convocation/convocation-history/convocation-2021
# /academics/academic-calendar/convocation/convocation-history/convocation-2020
# /academics/academic-calendar/convocation/convocation-history/convocation-2018
# /academics/academic-calendar/convocation/convocation-history/convocation-2017
# /academics/academic-calendar/convocation/convocation-history/convocation-2016
# /academics/academic-calendar/convocation/convocation-history/convocation-2015
# /academics/academic-calendar/convocation/convocation-history/convocation-2014
# /academics/academic-calendar/convocation/convocation-history/convocation-2013
# /academics/academic-calendar/convocation/convocation-history/convocation-2012
# /academics/academic-calendar/convocation/convocation-history/convocation-2011
# /academics/academic-calendar/convocation/convocation-history/convocation-2010
# /academics/academic-calendar/convocation/convocation-history/convocation-2009
# /academics/academic-calendar/convocation/convocation-history/convocation-2008
# /academics/academic-calendar/convocation/convocation-history/convocation-2007
# /registrar/final-exam-schedules
# /academics/academic-calendar/commencement
# /academics/academic-calendar/commencement/baccalaureate
# /academics/academic-calendar/commencement/graduating-seniors
# /academics/academic-calendar/commencement/graduating-seniors/graduating-senior-checklist
# /documents/Offices/Registrar/Sort/Key%20information%20for%20degree%20completion.pdf
# /academics/academic-calendar/commencement/graduating-seniors/photos
# /academics/academic-calendar/commencement/graduating-seniors/flowers
# /academics/academic-calendar/commencement/weekend-events-schedule
# /academics/academic-calendar/commencement/parents-visitors-and-families
# /academics/academic-calendar/commencement/accessibility
# /academics/academic-calendar/commencement/frequently-asked-questions
# /academics/academic-calendar/commencement/extreme-weather-plan
# /academics/academic-calendar/commencement/commencement-history
# /academics/academic-calendar/commencement/commencement-history/commencement-2022
# /academics/academic-calendar/commencement/commencement-history/commencement-2021
# /academics/academic-calendar/commencement/commencement-history/commencement-2020
# /academics/academic-calendar/commencement/commencement-history/commencement-2019
# /academics/academic-calendar/commencement/commencement-history/commencement-2018
# /academics/academic-calendar/commencement/commencement-history/commencement-2017
# /academics/academic-calendar/commencement/commencement-history/commencement-2016
# /academics/academic-calendar/commencement/commencement-history/commencement-2015
# /academics/academic-calendar/commencement/commencement-history/commencement-2014
# /academics/academic-calendar/commencement/commencement-history/commencement-2013
# /academics/academic-calendar/commencement/commencement-history/commencement-2012
# /academics/academic-calendar/commencement/commencement-history/commencement-2011
# /academics/academic-calendar/commencement/commencement-history/commencement-2010
# /academics/academic-calendar/commencement/commencement-history/commencement-2009
# /academics/academic-calendar/commencement/commencement-history/commencement-2008
# /academics/academic-calendar/commencement/commencement-history/commencement-2007
# /academics/academic-calendar/commencement/commencement-history/commencement-2006
# /academics/academic-calendar/commencement/commencement-history/honorary-degrees
# /academics/academic-resource-center
# /academics/academic-resource-center/meet-the-staff
# /academics/academic-resource-center/tutoring-at-whitman
# /academics/academic-resource-center/tutoring-at-whitman/arc-peer-tutors-and-coaches
# /academics/academic-resource-center/tutoring-at-whitman/current-and-prospective-tutors
# /academics/academic-resource-center/disability-support-services
# /academics/academic-resource-center/disability-support-services/incoming-and-prospective-students-and-families
# /academics/academic-resource-center/disability-support-services/current-students
# /academics/academic-resource-center/disability-support-services/current-students/testing-information
# /academics/academic-resource-center/disability-support-services/current-students/technology-resources
# /academics/academic-resource-center/disability-support-services/current-students/assistive-animals
# /academics/academic-resource-center/disability-support-services/current-students/injury-accommodations
# /academics/academic-resource-center/disability-support-services/faculty-resources
# /academics/academic-resource-center/academic-coaching
# /academics/academic-resource-center/academic-coaching/your-learning-toolbox
# /academics/academic-resource-center/wall-of-resources
# /academics/academic-resource-center/student-department-liaisons
# /academics/academic-resource-center/student-department-liaisons/division-i-social-sciences
# /academics/academic-resource-center/student-department-liaisons/division-ii-humanities-and-arts
# /academics/academic-resource-center/student-department-liaisons/division-iii-natural-sciences-and-mathematics
# https://library.whitman.edu/
# /academics/maxey-museum
# /academics/maxey-museum/our-collection
# /academics/maxey-museum/hours-of-operation
# /academics/maxey-museum/current-exhibits
# /about/facilities/maxey-museum/past-exhibits
# /academics/maxey-museum/past-exhibits/along-the-nci-wana-(columbia-river)
# /academics/maxey-museum/past-exhibits/a-proper-monument
# /academics/maxey-museum/past-exhibits/righteous-dopefiend
# /academics/maxey-museum/past-exhibits/righteous-dopefiend/the-reception-photos
# /academics/maxey-museum/past-exhibits/righteous-dopefiend/the-exhibit-photos
# /academics/maxey-museum/past-exhibits/money-talks-coins-and-imperial-image-in-the-late-roman-empire
# /academics/maxey-museum/past-exhibits/a-legacy-of-ethnocentric-tourism
# /academics/maxey-museum/past-exhibits/from-memorials-to-mascots-the-whitmans-in-the-20th-century
# /academics/maxey-museum/past-exhibits/science-atrium-exhibit-on-doctor-thibodo
# /academics/maxey-museum/past-exhibits/curators-choice
# /academics/maxey-museum/past-exhibits/narratives-of-expansion-and-empire
# /academics/maxey-museum/past-exhibits/eastern-shoes-of-the-20th-century
# /academics/maxey-museum/past-exhibits/money-of-the-world
# /academics/maxey-museum/past-exhibits
# /academics/maxey-museum/past-exhibits/nuclear-deferral
# /academics/maxey-museum/past-exhibits/trove/trope
# /academics/maxey-museum/past-exhibits/community-and-culture
# /academics/maxey-museum/past-exhibits/iroquoia-illustrated-image-and-text-in-haudenosaunee-literary-history
# /academics/maxey-museum/past-exhibits/walla-wallas-chinatown-an-international-archaeology-day-pop-up-exhibit
# /academics/maxey-museum/past-exhibits/undergraduate-conference-2015-pop-up-museum
# /academics/maxey-museum/past-exhibits/particles-on-the-wall
# /academics/maxey-museum/past-exhibits/particles-on-the-wall/exhibit-photos
# /academics/maxey-museum/past-exhibits/particles-on-the-wall/exhibition-events
# /academics/maxey-museum/past-exhibits/hand-and-the-machine
# /academics/maxey-museum/past-exhibits/rods-reels-and-canoes
# /academics/maxey-museum/past-exhibits/weapons-of-the-world
# /academics/maxey-museum/past-exhibits/dc-graham
# /academics/maxey-museum/past-exhibits/life-in-the-ancient-near-east
# /academics/maxey-museum/past-exhibits/eells-collection
# /academics/maxey-museum/past-exhibits/encounter-and-exchange-the-american-west
# /academics/maxey-museum/past-exhibits/changes-in-music-technology
# /academics/maxey-museum/past-exhibits/lewis-and-clark-on-the-columbia-river
# /academics/maxey-museum/staff
# https://arminda.whitman.edu/islandora/maxey-collection
# /academics/community-outreach
# /after-whitman/career-and-community-engagement-center
# /after-whitman/career-and-community-engagement-center/community-engagement/build-a-volunteer-opportunity
# /academics/community-outreach/science-at-home
# /academics/community-outreach/andrew-w-mellon-foundation-grants
# /academics/placement-tests
# /academics/placement-tests/chinese-guidelines
# /academics/placement-tests/japanese-guidelines
# /academics/placement-tests/classics-guidelines
# /academics/placement-tests/language-tests
# /academics/honor-societies
# /academics/honor-societies/phi-beta-kappa
# /academics/honor-societies/phi-beta-kappa/standards-for-election
# /academics/honor-societies/phi-beta-kappa/new-members
# /academics/honor-societies/phi-beta-kappa/local-chapter
# /academics/majors-and-minors/german-studies/german-honor-society
# /academics/careers-professions-and-the-liberal-arts
# /academics/careers-professions-and-the-liberal-arts/business-management
# /academics/careers-professions-and-the-liberal-arts/education
# /academics/careers-professions-and-the-liberal-arts/education/while-at-whitman
# /academics/careers-professions-and-the-liberal-arts/education/expand-your-horizons
# /academics/careers-professions-and-the-liberal-arts/education/beyond-whitman
# /academics/careers-professions-and-the-liberal-arts/foreign-service
# /academics/careers-professions-and-the-liberal-arts/health-professions
# /academics/careers-professions-and-the-liberal-arts/health-professions/office-of-health-professions-advising
# /academics/careers-professions-and-the-liberal-arts/health-professions/announcements-and-upcoming-events
# /academics/careers-professions-and-the-liberal-arts/health-professions/what-are-the-health-professions
# /academics/careers-professions-and-the-liberal-arts/health-professions/dentistry
# /academics/careers-professions-and-the-liberal-arts/health-professions/medicine
# /academics/careers-professions-and-the-liberal-arts/health-professions/nursing
# /academics/careers-professions-and-the-liberal-arts/health-professions/occupational-therapy
# /academics/careers-professions-and-the-liberal-arts/health-professions/pharmacy
# /academics/careers-professions-and-the-liberal-arts/health-professions/physical-therapy
# /academics/careers-professions-and-the-liberal-arts/health-professions/physician-assistant
# /academics/careers-professions-and-the-liberal-arts/health-professions/public-health
# /academics/careers-professions-and-the-liberal-arts/health-professions/veterinary-medicine
# /academics/careers-professions-and-the-liberal-arts/health-professions/health-professions-advisory-committee
# /academics/careers-professions-and-the-liberal-arts/health-professions/becoming-a-competitive-applicant
# /academics/careers-professions-and-the-liberal-arts/law
# /academics/careers-professions-and-the-liberal-arts/library-and-information-science
# /academics/careers-professions-and-the-liberal-arts/ministry
# /academics/careers-professions-and-the-liberal-arts/public-service
# /academics/careers-professions-and-the-liberal-arts/social-work-and-human-services
# /academics/careers-professions-and-the-liberal-arts/sports-studies-recreation-and-athletics
# /academics/careers-professions-and-the-liberal-arts/theatre
# /provost
# /registrar
# /about/rankings
# /admission-and-aid
# /about/contact-us
# /campus-map
# /about/leadership-and-organization
# /about/mission-constitution-and-bylaws
# /newsroom
# /about/our-campus
# /about/our-community
# /president
# /about/rankings
# /president/strategic-planning
# /academics/academic-calendar
# /academics/academic-resource-center
# /academics/academic-theme
# /academics/careers-professions-and-the-liberal-arts
# /academics/catalog
# /academics/center-for-global-studies
# /academics/community-outreach
# /after-whitman/fellowships-and-grants
# /academics/honor-societies
# /academics/majors-and-minors
# /academics/maxey-museum
# /off-campus-studies
# https://library.whitman.edu/
# /provost
# /registrar
# /academics/stem-hub
# /academics/the-faculty
# /academics/research/whitman-undergraduate-conference
# /admission-and-aid/applying-to-whitman
# /admission-and-aid/class-of-2027
# /admission-and-aid/contact-us
# /admission-and-aid/applying-to-whitman/early-decision
# /admission-and-aid/early-financial-aid-guarantee
# /admission-and-aid/financial-aid-and-costs
# /admission-and-aid/learn-more-about-whitman
# /admission-and-aid/financial-aid-and-costs/merit-and-talent-awards
# /admission-and-aid/request-information
# /admission-and-aid/virtual-tours
# /admission-and-aid/visit-whitman
# /admission-and-aid/whitman-on-the-road
# /admission-and-aid/why-whitman
# /after-whitman/career-and-community-engagement-center
# /campus-life/diversity-and-inclusion
# /campus-life/international-student-and-scholar-services
# /campus-life/orientation
# /campus-life/outdoor-program
# /campus-life/pathways-leadership-program
# /campus-life/reid-campus-center
# /campus-life/residence-life
# /campus-life/sorority-and-fraternity-life
# /campus-life/student-activities
# /dean-of-students/student-affairs
# /campus-life/student-employment
# /campus-life/sustainability
# /campus-life/student-activities/virtual-campus
# https://whitman.presence.io/
# /a-to-z-index
# https://whitman-advocate.symplicity.com/public_report/index.php
# http://bookstore.whitman.edu/home.aspx
# /campus-map
# /dean-of-students/care-team
# /after-whitman/career-and-community-engagement-center/job-and-career-resources
# /communications
# /human-resources
# /giving
# /human-resources/grievance-policy
# /newsroom
# /campus-life/diversity-and-inclusion/nondiscrimination-policy
# https://library.whitman.edu/
# /dean-of-students/right-to-know
# /campus-life/diversity-and-inclusion/title-ix-and-sexual-misconduct
# /communications/social-media
# /academics/the-center-for-writing-and-speaking
# /website-privacy-policy
# /welty-student-health-center
# https://www.google.com/maps/place/Whitman+College/@46.0717833,-118.3304355,16z/data=!4m2!3m1!1s0x0000000000000000:0x8704a8d5077eb801
# https://facebook.com/whitmancollege
# https://twitter.com/whitmancollege
# https://instagram.com/whitmancollege
# https://youtube.com/whitmancollege
# communications/social-media/social-media-links

# %% [markdown]
# The links to the majors and minors aren't in this list. What is going on?!?! Let's take a closer look at the HTML above.
#
# Notice how the info we want is contained in Javascript, which is another programming language that fuels the web.
#
# Never fear!
#
# Javascript is contained inside of a <script> tag. So let's see if we can find it:

# %%
scripts = majorminorSoup.find_all("script")

# %%
# The particular chunk of Javascript we are interested in is in the 3rd script tag:
print(scripts[2])
# Out:
# <script>
# 				(function(){
# 					var catList = [{id:'2642',name:'Majors'},{id:'373',name:'Minors'},{id:'818',name:'Other'}];
# 					var pageList = [{"xid":"x52057","title":"‘Forever Yuck,’ a Collaboration Rooted in Disgust","tags":"#2834,#2835,#370,#2418,#373,#2642,#658,#888,#252,#1045,#249,#250","url":"newsroom/armstrong-disgust-study"},{"xid":"x36361","title":"Anthropology","tags":"#339,#373,#2642","url":"academics/majors-and-minors/anthropology"},{"xid":"x40869","title":"Anthropology - Environmental Studies","tags":"#339,#2642","url":"academics/majors-and-minors/environmental-studies/environmental-studies-major/anthropology-environmental-studies"},{"xid":"x36373","title":"Art","tags":"#339,#373,#2642","url":"academics/majors-and-minors/art"},{"xid":"x49065","title":"Art - Environmental Studies","tags":"#339,#2642","url":"academics/majors-and-minors/environmental-studies/environmental-studies-major/art-environmental-studies"},{"xid":"x36397","title":"Art History","tags":"#339,#373,#2642","url":"academics/majors-and-minors/art-history"},{"xid":"x10537","title":"Astronomy","tags":"#339,#373,#2642","url":"academics/majors-and-minors/astronomy"},{"xid":"x9816","title":"Biochemistry, Biophysics and Molecular Biology","tags":"#339,#2642","url":"academics/majors-and-minors/biochemistry-biophysics-and-molecular-biology"},{"xid":"x7147","title":"Biology","tags":"#339,#373,#2642","url":"academics/majors-and-minors/biology"},{"xid":"x32838","title":"Biology - Environmental Studies","tags":"#339,#2642","url":"academics/majors-and-minors/environmental-studies/environmental-studies-major/biology-environmental-studies"},{"xid":"x20065","title":"Biology - Geology","tags":"#339,#2642","url":"academics/majors-and-minors/interdisciplinary-majors/biology-geology"},{"xid":"x36437","title":"Chemistry","tags":"#339,#373,#2642","url":"academics/majors-and-minors/chemistry"},{"xid":"x32859","title":"Chemistry - Environmental Studies","tags":"#339,#2642","url":"academics/majors-and-minors/environmental-studies/environmental-studies-major/chemistry-environmental-studies"},{"xid":"x20063","title":"Chemistry - Geology","tags":"#339,#2642","url":"academics/majors-and-minors/interdisciplinary-majors/chemistry-geology"},{"xid":"x9834","title":"Chinese","tags":"#339,#373,#2642","url":"academics/majors-and-minors/chinese"},{"xid":"x33577","title":"Classical Studies","tags":"#339,#373,#2642","url":"academics/majors-and-minors/classics-and-classical-studies"},{"xid":"x51378","title":"Classics","tags":"#2642","url":"academics/majors-and-minors/classics-and-classical-studies"},{"xid":"x43188","title":"Computer Science","tags":"#339,#373,#2642","url":"academics/majors-and-minors/computer-science"},{"xid":"x46005","title":"Creative Writing","tags":"#373","url":"academics/majors-and-minors/english/major-in-english/creative-writing"},{"xid":"x37195","title":"Dance","tags":"#339,#373","url":"academics/majors-and-minors/theater-and-dance/dance"},{"xid":"x49207","title":"Data Science","tags":"#373","url":"academics/majors-and-minors/mathematics-and-statistics/data-science"},{"xid":"x36444","title":"Economics","tags":"#339,#373,#2642","url":"academics/majors-and-minors/economics"},{"xid":"x32860","title":"Economics - Environmental Studies","tags":"#339,#2642","url":"academics/majors-and-minors/environmental-studies/environmental-studies-major/economics-environmental-studies"},{"xid":"x20061","title":"Economics - Mathematics","tags":"#339,#2642","url":"academics/majors-and-minors/interdisciplinary-majors/economics-mathematics"},{"xid":"x49442","title":"Engineering (3-2 Combined Plan)","tags":"#339,#2642,#818","url":"academics/majors-and-minors/engineering-(combined-plan)"},{"xid":"x5336","title":"English","tags":"#339,#373,#2642","url":"academics/majors-and-minors/english"},{"xid":"x32861","title":"Environmental Humanities","tags":"#339,#2642","url":"academics/majors-and-minors/environmental-studies/environmental-studies-major/environmental-humanities"},{"xid":"x36455","title":"Environmental Studies","tags":"#339,#818","url":"academics/majors-and-minors/environmental-studies"},{"xid":"x9870","ti ...
#
# 					var params = {
# 						catList:catList,
# 						pageList:pageList,
# 						catSelectType:'RadioButtons',
# 						alphaSort: 'false',
# 						alphaGroup: 'true',
# 						useUrlParams: 'false',
# 						catAllTitle:'All',
# 						collapse:'false'
# 					};
#
# 					if(catList.length > 0 && pageList.length > 0){
# 						$('#wc-taxonomy-index-component_').data('tnParams', params);
# 					}
# 				})();
# 			</script>

# %% [markdown]
# What do you notice about the structure of it?
#
# It looks like a dictionary! We can work with that...
#
# Here is how we can parse it and turn it into JSON (which is another data format we'll learn more about soon):

# %%
# This is the piece we want!
good_stuff = scripts[2].text.split('[')[2].split(']')[0]

# Now turn it into JSON
import json

good_json = json.loads("[" + good_stuff + ']')

good_json
# Out:
# [{'xid': 'x52057',
#   'title': '‘Forever Yuck,’ a Collaboration Rooted in Disgust',
#   'tags': '#2834,#2835,#370,#2418,#373,#2642,#658,#888,#252,#1045,#249,#250',
#   'url': 'newsroom/armstrong-disgust-study'},
#  {'xid': 'x36361',
#   'title': 'Anthropology',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/anthropology'},
#  {'xid': 'x40869',
#   'title': 'Anthropology - Environmental Studies',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/anthropology-environmental-studies'},
#  {'xid': 'x36373',
#   'title': 'Art',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/art'},
#  {'xid': 'x49065',
#   'title': 'Art - Environmental Studies',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/art-environmental-studies'},
#  {'xid': 'x36397',
#   'title': 'Art History',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/art-history'},
#  {'xid': 'x10537',
#   'title': 'Astronomy',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/astronomy'},
#  {'xid': 'x9816',
#   'title': 'Biochemistry, Biophysics and Molecular Biology',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/biochemistry-biophysics-and-molecular-biology'},
#  {'xid': 'x7147',
#   'title': 'Biology',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/biology'},
#  {'xid': 'x32838',
#   'title': 'Biology - Environmental Studies',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/biology-environmental-studies'},
#  {'xid': 'x20065',
#   'title': 'Biology - Geology',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/interdisciplinary-majors/biology-geology'},
#  {'xid': 'x36437',
#   'title': 'Chemistry',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/chemistry'},
#  {'xid': 'x32859',
#   'title': 'Chemistry - Environmental Studies',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/chemistry-environmental-studies'},
#  {'xid': 'x20063',
#   'title': 'Chemistry - Geology',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/interdisciplinary-majors/chemistry-geology'},
#  {'xid': 'x9834',
#   'title': 'Chinese',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/chinese'},
#  {'xid': 'x33577',
#   'title': 'Classical Studies',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/classics-and-classical-studies'},
#  {'xid': 'x51378',
#   'title': 'Classics',
#   'tags': '#2642',
#   'url': 'academics/majors-and-minors/classics-and-classical-studies'},
#  {'xid': 'x43188',
#   'title': 'Computer Science',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/computer-science'},
#  {'xid': 'x46005',
#   'title': 'Creative Writing',
#   'tags': '#373',
#   'url': 'academics/majors-and-minors/english/major-in-english/creative-writing'},
#  {'xid': 'x37195',
#   'title': 'Dance',
#   'tags': '#339,#373',
#   'url': 'academics/majors-and-minors/theater-and-dance/dance'},
#  {'xid': 'x49207',
#   'title': 'Data Science',
#   'tags': '#373',
#   'url': 'academics/majors-and-minors/mathematics-and-statistics/data-science'},
#  {'xid': 'x36444',
#   'title': 'Economics',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/economics'},
#  {'xid': 'x32860',
#   'title': 'Economics - Environmental Studies',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/economics-environmental-studies'},
#  {'xid': 'x20061',
#   'title': 'Economics - Mathematics',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/interdisciplinary-majors/economics-mathematics'},
#  {'xid': 'x49442',
#   'title': 'Engineering (3-2 Combined Plan)',
#   'tags': '#339,#2642,#818',
#   'url': 'academics/majors-and-minors/engineering-(combined-plan)'},
#  {'xid': 'x5336',
#   'title': 'English',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/english'},
#  {'xid': 'x32861',
#   'title': 'Environmental Humanities',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/environmental-humanities'},
#  {'xid': 'x36455',
#   'title': 'Environmental Studies',
#   'tags': '#339,#818',
#   'url': 'academics/majors-and-minors/environmental-studies'},
#  {'xid': 'x9870',
#   'title': 'Film and Media Studies',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/film-and-media-studies'},
#  {'xid': 'x40866',
#   'title': 'Forestry and Environmental Management (Combined Plan)',
#   'tags': '#818',
#   'url': '/documents/Offices/Registrar/Catalog/Combined-Plans.pdf'},
#  {'xid': 'x9876',
#   'title': 'French and Francophone Studies',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/french-and-francophone-studies'},
#  {'xid': 'x9882',
#   'title': 'Gender Studies',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/gender-studies'},
#  {'xid': 'x43613',
#   'title': 'General Studies Program',
#   'tags': '#818',
#   'url': 'academics/general-studies'},
#  {'xid': 'x36466',
#   'title': 'Geology',
#   'tags': '#373,#2642',
#   'url': 'academics/majors-and-minors/geology'},
#  {'xid': 'x20060',
#   'title': 'Geology - Astronomy',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/interdisciplinary-majors/geology-astronomy'},
#  {'xid': 'x52523',
#   'title': 'Geology - Computer Science ',
#   'tags': '#2642',
#   'url': 'academics/majors-and-minors/interdisciplinary-majors/geology-computer-science'},
#  {'xid': 'x32863',
#   'title': 'Geology - Environmental Studies',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/geology-environmental-studies'},
#  {'xid': 'x20058',
#   'title': 'Geology - Physics',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/interdisciplinary-majors/geology-physics'},
#  {'xid': 'x9900',
#   'title': 'German Studies',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/german-studies'},
#  {'xid': 'x40016',
#   'title': 'Global Literatures',
#   'tags': '#339,#373',
#   'url': 'academics/majors-and-minors/global-literatures'},
#  {'xid': 'x44009',
#   'title': 'Global Studies Concentration',
#   'tags': '#339,#818',
#   'url': 'academics/center-for-global-studies/global-studies-concentration'},
#  {'xid': 'x9984',
#   'title': 'Hispanic Studies',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/hispanic-studies'},
#  {'xid': 'x9906',
#   'title': 'History',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/history'},
#  {'xid': 'x39064',
#   'title': 'History - Environmental Studies',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/history-environmental-studies'},
#  {'xid': 'x40863',
#   'title': 'Individually Planned Majors',
#   'tags': '#818',
#   'url': 'registrar/services-for-students-and-alumni/forms/individually-planned-major/guidelines'},
#  {'xid': 'x9912',
#   'title': 'Japanese',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/japanese'},
#  {'xid': 'x9918',
#   'title': 'Latin American Studies',
#   'tags': '#339,#373',
#   'url': 'academics/majors-and-minors/latin-american-studies'},
#  {'xid': 'x36488',
#   'title': 'Mathematics',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/mathematics-and-statistics'},
#  {'xid': 'x20057',
#   'title': 'Mathematics - Physics',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/interdisciplinary-majors/mathematics-physics'},
#  {'xid': 'x27982',
#   'title': 'Music',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/music'},
#  {'xid': 'x40867',
#   'title': 'Oceanography (Combined Plan)',
#   'tags': '#818',
#   'url': '/documents/Offices/Registrar/Catalog/Combined-Plans.pdf'},
#  {'xid': 'x9936',
#   'title': 'Philosophy',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/philosophy'},
#  {'xid': 'x20103',
#   'title': 'Physics',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/physics'},
#  {'xid': 'x20056',
#   'title': 'Physics - Astronomy',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/interdisciplinary-majors/physics-astronomy'},
#  {'xid': 'x32865',
#   'title': 'Physics - Environmental Studies',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/physics-environmental-studies'},
#  {'xid': 'x7079',
#   'title': 'Politics',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/politics'},
#  {'xid': 'x32866',
#   'title': 'Politics - Environmental Studies',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/politics-environmental-studies'},
#  {'xid': 'x9954',
#   'title': 'Psychology',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/psychology'},
#  {'xid': 'x9960',
#   'title': 'Race and Ethnic Studies',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/race-and-ethnic-studies'},
#  {'xid': 'x37152',
#   'title': 'Religion',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/religion'},
#  {'xid': 'x9972',
#   'title': 'Rhetoric, Writing and Public Discourse',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/rhetoric-writing-and-public-discourse'},
#  {'xid': 'x26459',
#   'title': 'Sociology',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/majors-and-minors/sociology'},
#  {'xid': 'x32869',
#   'title': 'Sociology - Environmental Studies',
#   'tags': '#339,#2642',
#   'url': 'academics/majors-and-minors/environmental-studies/environmental-studies-major/sociology-environmental-studies'},
#  {'xid': 'x51910',
#   'title': 'South Asian and Middle Eastern Studies',
#   'tags': '#2642',
#   'url': 'academics/majors-and-minors/asian-and-middle-eastern-studies/south-asian-and-middle-eastern-studies'},
#  {'xid': 'x9990',
#   'title': 'Sports Studies, Recreation and Athletics',
#   'tags': '#309,#818',
#   'url': 'academics/majors-and-minors/sports-studies-recreation-and-athletics'},
#  {'xid': 'x38989',
#   'title': 'Theater and Dance',
#   'tags': '#339,#373,#2642',
#   'url': 'academics/departments-and-programs/theatre-and-dance'}]

# %%
good_json[0]["url"]
# Out:
# 'newsroom/armstrong-disgust-study'

# %%
for item in good_json:
    print(item['url'])
# Out:
# newsroom/armstrong-disgust-study
# academics/majors-and-minors/anthropology
# academics/majors-and-minors/environmental-studies/environmental-studies-major/anthropology-environmental-studies
# academics/majors-and-minors/art
# academics/majors-and-minors/environmental-studies/environmental-studies-major/art-environmental-studies
# academics/majors-and-minors/art-history
# academics/majors-and-minors/astronomy
# academics/majors-and-minors/biochemistry-biophysics-and-molecular-biology
# academics/majors-and-minors/biology
# academics/majors-and-minors/environmental-studies/environmental-studies-major/biology-environmental-studies
# academics/majors-and-minors/interdisciplinary-majors/biology-geology
# academics/majors-and-minors/chemistry
# academics/majors-and-minors/environmental-studies/environmental-studies-major/chemistry-environmental-studies
# academics/majors-and-minors/interdisciplinary-majors/chemistry-geology
# academics/majors-and-minors/chinese
# academics/majors-and-minors/classics-and-classical-studies
# academics/majors-and-minors/classics-and-classical-studies
# academics/majors-and-minors/computer-science
# academics/majors-and-minors/english/major-in-english/creative-writing
# academics/majors-and-minors/theater-and-dance/dance
# academics/majors-and-minors/mathematics-and-statistics/data-science
# academics/majors-and-minors/economics
# academics/majors-and-minors/environmental-studies/environmental-studies-major/economics-environmental-studies
# academics/majors-and-minors/interdisciplinary-majors/economics-mathematics
# academics/majors-and-minors/engineering-(combined-plan)
# academics/majors-and-minors/english
# academics/majors-and-minors/environmental-studies/environmental-studies-major/environmental-humanities
# academics/majors-and-minors/environmental-studies
# academics/majors-and-minors/film-and-media-studies
# /documents/Offices/Registrar/Catalog/Combined-Plans.pdf
# academics/majors-and-minors/french-and-francophone-studies
# academics/majors-and-minors/gender-studies
# academics/general-studies
# academics/majors-and-minors/geology
# academics/majors-and-minors/interdisciplinary-majors/geology-astronomy
# academics/majors-and-minors/interdisciplinary-majors/geology-computer-science
# academics/majors-and-minors/environmental-studies/environmental-studies-major/geology-environmental-studies
# academics/majors-and-minors/interdisciplinary-majors/geology-physics
# academics/majors-and-minors/german-studies
# academics/majors-and-minors/global-literatures
# academics/center-for-global-studies/global-studies-concentration
# academics/majors-and-minors/hispanic-studies
# academics/majors-and-minors/history
# academics/majors-and-minors/environmental-studies/environmental-studies-major/history-environmental-studies
# registrar/services-for-students-and-alumni/forms/individually-planned-major/guidelines
# academics/majors-and-minors/japanese
# academics/majors-and-minors/latin-american-studies
# academics/majors-and-minors/mathematics-and-statistics
# academics/majors-and-minors/interdisciplinary-majors/mathematics-physics
# academics/majors-and-minors/music
# /documents/Offices/Registrar/Catalog/Combined-Plans.pdf
# academics/majors-and-minors/philosophy
# academics/majors-and-minors/physics
# academics/majors-and-minors/interdisciplinary-majors/physics-astronomy
# academics/majors-and-minors/environmental-studies/environmental-studies-major/physics-environmental-studies
# academics/majors-and-minors/politics
# academics/majors-and-minors/environmental-studies/environmental-studies-major/politics-environmental-studies
# academics/majors-and-minors/psychology
# academics/majors-and-minors/race-and-ethnic-studies
# academics/majors-and-minors/religion
# academics/majors-and-minors/rhetoric-writing-and-public-discourse
# academics/majors-and-minors/sociology
# academics/majors-and-minors/environmental-studies/environmental-studies-major/sociology-environmental-studies
# academics/majors-and-minors/asian-and-middle-eastern-studies/south-asian-and-middle-eastern-studies
# academics/majors-and-minors/sports-studies-recreation-and-athletics
# academics/departments-and-programs/theatre-and-dance

# %% [markdown]
# ### Challenge
# Now that you have this list of URLs, you could write a web scraper to:
# * Visit each department's page
# * Go to the faculty page
# * Collect the information on each faculty member
#
# How might you do this? Start figuring out what the process would be.

# %% [markdown]
# ### Challenge
# Think about another websites you might interested in scraping. Take a look at it, both with your browser's inspector and with BeautifulSoup, and see what sorts of challenges and opportunities exist for scraping this page's data.
